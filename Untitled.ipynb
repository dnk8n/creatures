# %%
from creatures.simulate import *

# %%
main(save_path="/tmp/environment.pickle")

# %%
env = Environment.load("/tmp/environment.pickle")

# %%
len(env.state.hp_by_strategy)
# Out:
# 1000

# %%
env.state.hp_by_strategy[0]
# Out:
# {'AttackStrategy': 12602,
#  'RetreatStrategy': 23380,
#  'RetaliateStrategy': 13423,
#  'ExploitStrategy': 23310}

# %%
env.state.hp_by_strategy[-1]
# Out:
# {'AttackStrategy': 11883,
#  'RetreatStrategy': 0,
#  'RetaliateStrategy': 0,
#  'ExploitStrategy': 46098}

# %%
env.state.xp_by_strategy[0]
# Out:
# {'AttackStrategy': 4983,
#  'RetreatStrategy': 1410,
#  'RetaliateStrategy': 4571,
#  'ExploitStrategy': 1634}

# %%
env.state.xp_by_strategy[-1]
# Out:
# {'AttackStrategy': 13796,
#  'RetreatStrategy': 0,
#  'RetaliateStrategy': 0,
#  'ExploitStrategy': 45839}

# %%
env.state.population_by_strategy[0]
# Out:
# {'AttackStrategy': 250,
#  'RetreatStrategy': 250,
#  'RetaliateStrategy': 250,
#  'ExploitStrategy': 250}

# %%
env.state.population_by_strategy
# Out:
# [{'AttackStrategy': 250,
#   'RetreatStrategy': 250,
#   'RetaliateStrategy': 250,
#   'ExploitStrategy': 250},
#  {'AttackStrategy': 234,
#   'RetreatStrategy': 268,
#   'RetaliateStrategy': 241,
#   'ExploitStrategy': 257},
#  {'AttackStrategy': 205,
#   'RetreatStrategy': 282,
#   'RetaliateStrategy': 232,
#   'ExploitStrategy': 281},
#  {'AttackStrategy': 188,
#   'RetreatStrategy': 302,
#   'RetaliateStrategy': 216,
#   'ExploitStrategy': 294},
#  {'AttackStrategy': 169,
#   'RetreatStrategy': 312,
#   'RetaliateStrategy': 205,
#   'ExploitStrategy': 314},
#  {'AttackStrategy': 160,
#   'RetreatStrategy': 326,
#   'RetaliateStrategy': 179,
#   'ExploitStrategy': 335},
#  {'AttackStrategy': 151,
#   'RetreatStrategy': 334,
#   'RetaliateStrategy': 174,
#   'ExploitStrategy': 341},
#  {'AttackStrategy': 143,
#   'RetreatStrategy': 341,
#   'RetaliateStrategy': 157,
#   'ExploitStrategy': 359},
#  {'AttackStrategy': 136,
#   'RetreatStrategy': 348,
#   'RetaliateStrategy': 147,
#   'ExploitStrategy': 369},
#  {'AttackStrategy': 126,
#   'RetreatStrategy': 352,
#   'RetaliateStrategy': 133,
#   'ExploitStrategy': 389},
#  {'AttackStrategy': 124,
#   'RetreatStrategy': 349,
#   'RetaliateStrategy': 121,
#   'ExploitStrategy': 406},
#  {'AttackStrategy': 112,
#   'RetreatStrategy': 355,
#   'RetaliateStrategy': 117,
#   'ExploitStrategy': 416},
#  {'AttackStrategy': 108,
#   'RetreatStrategy': 353,
#   'RetaliateStrategy': 117,
#   'ExploitStrategy': 422},
#  {'AttackStrategy': 103,
#   'RetreatStrategy': 351,
#   'RetaliateStrategy': 115,
#   'ExploitStrategy': 431},
#  {'AttackStrategy': 104,
#   'RetreatStrategy': 349,
#   'RetaliateStrategy': 105,
#   'ExploitStrategy': 442},
#  {'AttackStrategy': 102,
#   'RetreatStrategy': 345,
#   'RetaliateStrategy': 103,
#   'ExploitStrategy': 450},
#  {'AttackStrategy': 102,
#   'RetreatStrategy': 341,
#   'RetaliateStrategy': 99,
#   'ExploitStrategy': 458},
#  {'AttackStrategy': 105,
#   'RetreatStrategy': 327,
#   'RetaliateStrategy': 95,
#   'ExploitStrategy': 473},
#  {'AttackStrategy': 100,
#   'RetreatStrategy': 321,
#   'RetaliateStrategy': 98,
#   'ExploitStrategy': 481},
#  {'AttackStrategy': 98,
#   'RetreatStrategy': 312,
#   'RetaliateStrategy': 100,
#   'ExploitStrategy': 490},
#  {'AttackStrategy': 98,
#   'RetreatStrategy': 304,
#   'RetaliateStrategy': 93,
#   'ExploitStrategy': 505},
#  {'AttackStrategy': 100,
#   'RetreatStrategy': 296,
#   'RetaliateStrategy': 86,
#   'ExploitStrategy': 518},
#  {'AttackStrategy': 98,
#   'RetreatStrategy': 288,
#   'RetaliateStrategy': 85,
#   'ExploitStrategy': 529},
#  {'AttackStrategy': 100,
#   'RetreatStrategy': 284,
#   'RetaliateStrategy': 80,
#   'ExploitStrategy': 536},
#  {'AttackStrategy': 95,
#   'RetreatStrategy': 279,
#   'RetaliateStrategy': 74,
#   'ExploitStrategy': 552},
#  {'AttackStrategy': 97,
#   'RetreatStrategy': 263,
#   'RetaliateStrategy': 70,
#   'ExploitStrategy': 570},
#  {'AttackStrategy': 107,
#   'RetreatStrategy': 244,
#   'RetaliateStrategy': 64,
#   'ExploitStrategy': 585},
#  {'AttackStrategy': 107,
#   'RetreatStrategy': 224,
#   'RetaliateStrategy': 59,
#   'ExploitStrategy': 610},
#  {'AttackStrategy': 113,
#   'RetreatStrategy': 210,
#   'RetaliateStrategy': 58,
#   'ExploitStrategy': 619},
#  {'AttackStrategy': 112,
#   'RetreatStrategy': 195,
#   'RetaliateStrategy': 61,
#   'ExploitStrategy': 632},
#  {'AttackStrategy': 111,
#   'RetreatStrategy': 192,
#   'RetaliateStrategy': 57,
#   'ExploitStrategy': 640},
#  {'AttackStrategy': 110,
#   'RetreatStrategy': 179,
#   'RetaliateStrategy': 52,
#   'ExploitStrategy': 659},
#  {'AttackStrategy': 109,
#   'RetreatStrategy': 162,
#   'RetaliateStrategy': 48,
#   'ExploitStrategy': 681},
#  {'AttackStrategy': 110,
#   'RetreatStrategy': 153,
#   'RetaliateStrategy': 41,
#   'ExploitStrategy': 696},
#  {'AttackStrategy': 118,
#   'RetreatStrategy': 145,
#   'RetaliateStrategy': 38,
#   'ExploitStrategy': 699},
#  {'AttackStrategy': 117,
#   'RetreatStrategy': 135,
#   'RetaliateStrategy': 34,
#   'ExploitStrategy': 714},
#  {'AttackStrategy': 117,
#   'RetreatStrategy': 124,
#   'RetaliateStrategy': 36,
#   'ExploitStrategy': 723},
#  {'AttackStrategy': 128,
#   'RetreatStrategy': 111,
#   'RetaliateStrategy': 33,
#   'ExploitStrategy': 728},
#  {'AttackStrategy': 131,
#   'RetreatStrategy': 98,
#   'RetaliateStrategy': 29,
#   'ExploitStrategy': 742},
#  {'AttackStrategy': 132,
#   'RetreatStrategy': 81,
#   'RetaliateStrategy': 32,
#   'ExploitStrategy': 755},
#  {'AttackStrategy': 130,
#   'RetreatStrategy': 75,
#   'RetaliateStrategy': 29,
#   'ExploitStrategy': 766},
#  {'AttackStrategy': 122,
#   'RetreatStrategy': 60,
#   'RetaliateStrategy': 24,
#   'ExploitStrategy': 794},
#  {'AttackStrategy': 122,
#   'RetreatStrategy': 55,
#   'RetaliateStrategy': 19,
#   'ExploitStrategy': 804},
#  {'AttackStrategy': 133,
#   'RetreatStrategy': 48,
#   'RetaliateStrategy': 15,
#   'ExploitStrategy': 804},
#  {'AttackStrategy': 134,
#   'RetreatStrategy': 39,
#   'RetaliateStrategy': 13,
#   'ExploitStrategy': 814},
#  {'AttackStrategy': 136,
#   'RetreatStrategy': 32,
#   'RetaliateStrategy': 14,
#   'ExploitStrategy': 818},
#  {'AttackStrategy': 130,
#   'RetreatStrategy': 30,
#   'RetaliateStrategy': 13,
#   'ExploitStrategy': 827},
#  {'AttackStrategy': 130,
#   'RetreatStrategy': 28,
#   'RetaliateStrategy': 12,
#   'ExploitStrategy': 830},
#  {'AttackStrategy': 132,
#   'RetreatStrategy': 23,
#   'RetaliateStrategy': 12,
#   'ExploitStrategy': 833},
#  {'AttackStrategy': 139,
#   'RetreatStrategy': 17,
#   'RetaliateStrategy': 11,
#   'ExploitStrategy': 833},
#  {'AttackStrategy': 140,
#   'RetreatStrategy': 15,
#   'RetaliateStrategy': 11,
#   'ExploitStrategy': 834},
#  {'AttackStrategy': 148,
#   'RetreatStrategy': 14,
#   'RetaliateStrategy': 11,
#   'ExploitStrategy': 827},
#  {'AttackStrategy': 152,
#   'RetreatStrategy': 11,
#   'RetaliateStrategy': 10,
#   'ExploitStrategy': 827},
#  {'AttackStrategy': 159,
#   'RetreatStrategy': 10,
#   'RetaliateStrategy': 9,
#   'ExploitStrategy': 822},
#  {'AttackStrategy': 155,
#   'RetreatStrategy': 9,
#   'RetaliateStrategy': 8,
#   'ExploitStrategy': 828},
#  {'AttackStrategy': 158,
#   'RetreatStrategy': 7,
#   'RetaliateStrategy': 6,
#   'ExploitStrategy': 829},
#  {'AttackStrategy': 167,
#   'RetreatStrategy': 5,
#   'RetaliateStrategy': 5,
#   'ExploitStrategy': 823},
#  {'AttackStrategy': 165,
#   'RetreatStrategy': 5,
#   'RetaliateStrategy': 5,
#   'ExploitStrategy': 825},
#  {'AttackStrategy': 158,
#   'RetreatStrategy': 4,
#   'RetaliateStrategy': 3,
#   'ExploitStrategy': 835},
#  {'AttackStrategy': 160,
#   'RetreatStrategy': 3,
#   'RetaliateStrategy': 3,
#   'ExploitStrategy': 834},
#  {'AttackStrategy': 158,
#   'RetreatStrategy': 3,
#   'RetaliateStrategy': 2,
#   'ExploitStrategy': 837},
#  {'AttackStrategy': 169,
#   'RetreatStrategy': 3,
#   'RetaliateStrategy': 2,
#   'ExploitStrategy': 826},
#  {'AttackStrategy': 171,
#   'RetreatStrategy': 3,
#   'RetaliateStrategy': 3,
#   'ExploitStrategy': 823},
#  {'AttackStrategy': 165,
#   'RetreatStrategy': 2,
#   'RetaliateStrategy': 3,
#   'ExploitStrategy': 830},
#  {'AttackStrategy': 165,
#   'RetreatStrategy': 2,
#   'RetaliateStrategy': 2,
#   'ExploitStrategy': 831},
#  {'AttackStrategy': 167,
#   'RetreatStrategy': 1,
#   'RetaliateStrategy': 2,
#   'ExploitStrategy': 830},
#  {'AttackStrategy': 159,
#   'RetreatStrategy': 1,
#   'RetaliateStrategy': 2,
#   'ExploitStrategy': 838},
#  {'AttackStrategy': 169,
#   'RetreatStrategy': 1,
#   'RetaliateStrategy': 2,
#   'ExploitStrategy': 828},
#  {'AttackStrategy': 165,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 2,
#   'ExploitStrategy': 833},
#  {'AttackStrategy': 157,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 2,
#   'ExploitStrategy': 841},
#  {'AttackStrategy': 160,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 1,
#   'ExploitStrategy': 839},
#  {'AttackStrategy': 158,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 2,
#   'ExploitStrategy': 840},
#  {'AttackStrategy': 157,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 2,
#   'ExploitStrategy': 841},
#  {'AttackStrategy': 154,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 2,
#   'ExploitStrategy': 844},
#  {'AttackStrategy': 156,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 2,
#   'ExploitStrategy': 842},
#  {'AttackStrategy': 159,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 1,
#   'ExploitStrategy': 840},
#  {'AttackStrategy': 163,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 1,
#   'ExploitStrategy': 836},
#  {'AttackStrategy': 162,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 1,
#   'ExploitStrategy': 837},
#  {'AttackStrategy': 168,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 1,
#   'ExploitStrategy': 831},
#  {'AttackStrategy': 169,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 1,
#   'ExploitStrategy': 830},
#  {'AttackStrategy': 175,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 1,
#   'ExploitStrategy': 824},
#  {'AttackStrategy': 175,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 1,
#   'ExploitStrategy': 824},
#  {'AttackStrategy': 179,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 1,
#   'ExploitStrategy': 820},
#  {'AttackStrategy': 184,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 1,
#   'ExploitStrategy': 815},
#  {'AttackStrategy': 187,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 1,
#   'ExploitStrategy': 812},
#  {'AttackStrategy': 190,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 1,
#   'ExploitStrategy': 809},
#  {'AttackStrategy': 196,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 804},
#  {'AttackStrategy': 196,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 804},
#  {'AttackStrategy': 194,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 806},
#  {'AttackStrategy': 189,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 811},
#  {'AttackStrategy': 191,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 809},
#  {'AttackStrategy': 179,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 821},
#  {'AttackStrategy': 185,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 815},
#  {'AttackStrategy': 192,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 808},
#  {'AttackStrategy': 187,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 813},
#  {'AttackStrategy': 187,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 813},
#  {'AttackStrategy': 194,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 806},
#  {'AttackStrategy': 193,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 807},
#  {'AttackStrategy': 194,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 806},
#  {'AttackStrategy': 194,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 806},
#  {'AttackStrategy': 185,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 815},
#  {'AttackStrategy': 186,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 814},
#  {'AttackStrategy': 183,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 817},
#  {'AttackStrategy': 189,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 811},
#  {'AttackStrategy': 196,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 804},
#  {'AttackStrategy': 191,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 809},
#  {'AttackStrategy': 183,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 817},
#  {'AttackStrategy': 185,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 815},
#  {'AttackStrategy': 181,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 819},
#  {'AttackStrategy': 181,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 819},
#  {'AttackStrategy': 184,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 816},
#  {'AttackStrategy': 196,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 804},
#  {'AttackStrategy': 194,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 806},
#  {'AttackStrategy': 197,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 803},
#  {'AttackStrategy': 189,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 811},
#  {'AttackStrategy': 194,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 806},
#  {'AttackStrategy': 198,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 802},
#  {'AttackStrategy': 203,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 797},
#  {'AttackStrategy': 203,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 797},
#  {'AttackStrategy': 200,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 800},
#  {'AttackStrategy': 203,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 797},
#  {'AttackStrategy': 204,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 796},
#  {'AttackStrategy': 207,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 793},
#  {'AttackStrategy': 208,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 792},
#  {'AttackStrategy': 207,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 793},
#  {'AttackStrategy': 208,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 792},
#  {'AttackStrategy': 211,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 789},
#  {'AttackStrategy': 215,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 785},
#  {'AttackStrategy': 218,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 782},
#  {'AttackStrategy': 216,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 784},
#  {'AttackStrategy': 203,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 797},
#  {'AttackStrategy': 192,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 808},
#  {'AttackStrategy': 189,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 811},
#  {'AttackStrategy': 188,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 812},
#  {'AttackStrategy': 189,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 811},
#  {'AttackStrategy': 184,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 816},
#  {'AttackStrategy': 185,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 815},
#  {'AttackStrategy': 188,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 812},
#  {'AttackStrategy': 191,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 809},
#  {'AttackStrategy': 184,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 816},
#  {'AttackStrategy': 178,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 822},
#  {'AttackStrategy': 181,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 819},
#  {'AttackStrategy': 178,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 822},
#  {'AttackStrategy': 172,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 828},
#  {'AttackStrategy': 177,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 823},
#  {'AttackStrategy': 179,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 821},
#  {'AttackStrategy': 180,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 820},
#  {'AttackStrategy': 171,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 829},
#  {'AttackStrategy': 177,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 823},
#  {'AttackStrategy': 177,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 823},
#  {'AttackStrategy': 171,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 829},
#  {'AttackStrategy': 164,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 836},
#  {'AttackStrategy': 174,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 826},
#  {'AttackStrategy': 171,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 829},
#  {'AttackStrategy': 168,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 832},
#  {'AttackStrategy': 176,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 824},
#  {'AttackStrategy': 185,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 815},
#  {'AttackStrategy': 184,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 816},
#  {'AttackStrategy': 186,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 814},
#  {'AttackStrategy': 177,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 823},
#  {'AttackStrategy': 179,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 821},
#  {'AttackStrategy': 173,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 827},
#  {'AttackStrategy': 167,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 833},
#  {'AttackStrategy': 171,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 829},
#  {'AttackStrategy': 174,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 826},
#  {'AttackStrategy': 181,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 819},
#  {'AttackStrategy': 189,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 811},
#  {'AttackStrategy': 189,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 811},
#  {'AttackStrategy': 186,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 814},
#  {'AttackStrategy': 181,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 819},
#  {'AttackStrategy': 170,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 830},
#  {'AttackStrategy': 168,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 832},
#  {'AttackStrategy': 173,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 827},
#  {'AttackStrategy': 173,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 827},
#  {'AttackStrategy': 177,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 823},
#  {'AttackStrategy': 173,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 827},
#  {'AttackStrategy': 170,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 830},
#  {'AttackStrategy': 174,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 826},
#  {'AttackStrategy': 170,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 830},
#  {'AttackStrategy': 175,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 825},
#  {'AttackStrategy': 168,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 832},
#  {'AttackStrategy': 169,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 831},
#  {'AttackStrategy': 171,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 829},
#  {'AttackStrategy': 180,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 820},
#  {'AttackStrategy': 169,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 831},
#  {'AttackStrategy': 170,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 830},
#  {'AttackStrategy': 174,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 826},
#  {'AttackStrategy': 182,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 818},
#  {'AttackStrategy': 191,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 809},
#  {'AttackStrategy': 192,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 808},
#  {'AttackStrategy': 187,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 813},
#  {'AttackStrategy': 186,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 814},
#  {'AttackStrategy': 191,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 809},
#  {'AttackStrategy': 194,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 806},
#  {'AttackStrategy': 197,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 803},
#  {'AttackStrategy': 190,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 810},
#  {'AttackStrategy': 187,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 813},
#  {'AttackStrategy': 188,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 812},
#  {'AttackStrategy': 190,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 810},
#  {'AttackStrategy': 191,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 809},
#  {'AttackStrategy': 188,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 812},
#  {'AttackStrategy': 179,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 821},
#  {'AttackStrategy': 172,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 828},
#  {'AttackStrategy': 174,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 826},
#  {'AttackStrategy': 171,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 829},
#  {'AttackStrategy': 173,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 827},
#  {'AttackStrategy': 182,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 818},
#  {'AttackStrategy': 183,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 817},
#  {'AttackStrategy': 186,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 814},
#  {'AttackStrategy': 181,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 819},
#  {'AttackStrategy': 184,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 816},
#  {'AttackStrategy': 181,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 819},
#  {'AttackStrategy': 184,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 816},
#  {'AttackStrategy': 182,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 818},
#  {'AttackStrategy': 189,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 811},
#  {'AttackStrategy': 190,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 810},
#  {'AttackStrategy': 194,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 806},
#  {'AttackStrategy': 189,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 811},
#  {'AttackStrategy': 200,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 800},
#  {'AttackStrategy': 199,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 801},
#  {'AttackStrategy': 198,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 802},
#  {'AttackStrategy': 197,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 803},
#  {'AttackStrategy': 199,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 801},
#  {'AttackStrategy': 194,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 806},
#  {'AttackStrategy': 191,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 809},
#  {'AttackStrategy': 195,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 805},
#  {'AttackStrategy': 188,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 812},
#  {'AttackStrategy': 198,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 802},
#  {'AttackStrategy': 197,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 803},
#  {'AttackStrategy': 204,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 796},
#  {'AttackStrategy': 203,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 797},
#  {'AttackStrategy': 203,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 797},
#  {'AttackStrategy': 208,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 792},
#  {'AttackStrategy': 206,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 794},
#  {'AttackStrategy': 206,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 794},
#  {'AttackStrategy': 200,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 800},
#  {'AttackStrategy': 198,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 802},
#  {'AttackStrategy': 191,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 809},
#  {'AttackStrategy': 191,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 809},
#  {'AttackStrategy': 204,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 796},
#  {'AttackStrategy': 206,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 794},
#  {'AttackStrategy': 203,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 797},
#  {'AttackStrategy': 207,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 793},
#  {'AttackStrategy': 209,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 791},
#  {'AttackStrategy': 205,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 795},
#  {'AttackStrategy': 200,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 800},
#  {'AttackStrategy': 204,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 796},
#  {'AttackStrategy': 199,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 801},
#  {'AttackStrategy': 194,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 806},
#  {'AttackStrategy': 199,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 801},
#  {'AttackStrategy': 212,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 788},
#  {'AttackStrategy': 208,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 792},
#  {'AttackStrategy': 210,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 790},
#  {'AttackStrategy': 212,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 788},
#  {'AttackStrategy': 209,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 791},
#  {'AttackStrategy': 211,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 789},
#  {'AttackStrategy': 212,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 788},
#  {'AttackStrategy': 216,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 784},
#  {'AttackStrategy': 207,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 793},
#  {'AttackStrategy': 218,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 782},
#  {'AttackStrategy': 212,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 788},
#  {'AttackStrategy': 211,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 789},
#  {'AttackStrategy': 208,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 792},
#  {'AttackStrategy': 208,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 792},
#  {'AttackStrategy': 207,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 793},
#  {'AttackStrategy': 202,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 798},
#  {'AttackStrategy': 208,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 792},
#  {'AttackStrategy': 203,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 797},
#  {'AttackStrategy': 200,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 800},
#  {'AttackStrategy': 201,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 799},
#  {'AttackStrategy': 194,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 806},
#  {'AttackStrategy': 197,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 803},
#  {'AttackStrategy': 195,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 805},
#  {'AttackStrategy': 200,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 800},
#  {'AttackStrategy': 201,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 799},
#  {'AttackStrategy': 204,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 796},
#  {'AttackStrategy': 205,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 795},
#  {'AttackStrategy': 200,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 800},
#  {'AttackStrategy': 191,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 809},
#  {'AttackStrategy': 190,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 810},
#  {'AttackStrategy': 194,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 806},
#  {'AttackStrategy': 198,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 802},
#  {'AttackStrategy': 199,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 801},
#  {'AttackStrategy': 196,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 804},
#  {'AttackStrategy': 192,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 808},
#  {'AttackStrategy': 187,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 813},
#  {'AttackStrategy': 185,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 815},
#  {'AttackStrategy': 183,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 817},
#  {'AttackStrategy': 185,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 815},
#  {'AttackStrategy': 194,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 806},
#  {'AttackStrategy': 196,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 804},
#  {'AttackStrategy': 199,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 801},
#  {'AttackStrategy': 197,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 803},
#  {'AttackStrategy': 193,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 807},
#  {'AttackStrategy': 194,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 806},
#  {'AttackStrategy': 190,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 810},
#  {'AttackStrategy': 190,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 810},
#  {'AttackStrategy': 194,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 806},
#  {'AttackStrategy': 187,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 813},
#  {'AttackStrategy': 183,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 817},
#  {'AttackStrategy': 185,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 815},
#  {'AttackStrategy': 191,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 809},
#  {'AttackStrategy': 195,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 805},
#  {'AttackStrategy': 197,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 803},
#  {'AttackStrategy': 200,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 800},
#  {'AttackStrategy': 194,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 806},
#  {'AttackStrategy': 187,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 813},
#  {'AttackStrategy': 181,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 819},
#  {'AttackStrategy': 182,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 818},
#  {'AttackStrategy': 177,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 823},
#  {'AttackStrategy': 174,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 826},
#  {'AttackStrategy': 179,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 821},
#  {'AttackStrategy': 175,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 825},
#  {'AttackStrategy': 183,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 817},
#  {'AttackStrategy': 178,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 822},
#  {'AttackStrategy': 184,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 816},
#  {'AttackStrategy': 169,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 831},
#  {'AttackStrategy': 168,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 832},
#  {'AttackStrategy': 177,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 823},
#  {'AttackStrategy': 180,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 820},
#  {'AttackStrategy': 185,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 815},
#  {'AttackStrategy': 183,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 817},
#  {'AttackStrategy': 185,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 815},
#  {'AttackStrategy': 177,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 823},
#  {'AttackStrategy': 176,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 824},
#  {'AttackStrategy': 181,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 819},
#  {'AttackStrategy': 182,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 818},
#  {'AttackStrategy': 194,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 806},
#  {'AttackStrategy': 192,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 808},
#  {'AttackStrategy': 199,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 801},
#  {'AttackStrategy': 198,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 802},
#  {'AttackStrategy': 204,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 796},
#  {'AttackStrategy': 201,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 799},
#  {'AttackStrategy': 204,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 796},
#  {'AttackStrategy': 205,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 795},
#  {'AttackStrategy': 200,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 800},
#  {'AttackStrategy': 202,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 798},
#  {'AttackStrategy': 211,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 789},
#  {'AttackStrategy': 208,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 792},
#  {'AttackStrategy': 208,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 792},
#  {'AttackStrategy': 213,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 787},
#  {'AttackStrategy': 204,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 796},
#  {'AttackStrategy': 206,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 794},
#  {'AttackStrategy': 207,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 793},
#  {'AttackStrategy': 210,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 790},
#  {'AttackStrategy': 217,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 783},
#  {'AttackStrategy': 220,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 780},
#  {'AttackStrategy': 224,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 776},
#  {'AttackStrategy': 220,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 780},
#  {'AttackStrategy': 225,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 775},
#  {'AttackStrategy': 217,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 783},
#  {'AttackStrategy': 222,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 778},
#  {'AttackStrategy': 216,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 784},
#  {'AttackStrategy': 213,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 787},
#  {'AttackStrategy': 218,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 782},
#  {'AttackStrategy': 222,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 778},
#  {'AttackStrategy': 214,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 786},
#  {'AttackStrategy': 204,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 796},
#  {'AttackStrategy': 204,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 796},
#  {'AttackStrategy': 212,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 788},
#  {'AttackStrategy': 213,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 787},
#  {'AttackStrategy': 214,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 786},
#  {'AttackStrategy': 219,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 781},
#  {'AttackStrategy': 207,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 793},
#  {'AttackStrategy': 201,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 799},
#  {'AttackStrategy': 207,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 793},
#  {'AttackStrategy': 199,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 801},
#  {'AttackStrategy': 198,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 802},
#  {'AttackStrategy': 204,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 796},
#  {'AttackStrategy': 204,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 796},
#  {'AttackStrategy': 203,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 797},
#  {'AttackStrategy': 204,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 796},
#  {'AttackStrategy': 202,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 798},
#  {'AttackStrategy': 191,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 809},
#  {'AttackStrategy': 196,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 804},
#  {'AttackStrategy': 197,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 803},
#  {'AttackStrategy': 190,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 810},
#  {'AttackStrategy': 190,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 810},
#  {'AttackStrategy': 192,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 808},
#  {'AttackStrategy': 193,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 807},
#  {'AttackStrategy': 195,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 805},
#  {'AttackStrategy': 187,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 813},
#  {'AttackStrategy': 198,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 802},
#  {'AttackStrategy': 195,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 805},
#  {'AttackStrategy': 204,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 796},
#  {'AttackStrategy': 202,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 798},
#  {'AttackStrategy': 196,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 804},
#  {'AttackStrategy': 203,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 797},
#  {'AttackStrategy': 194,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 806},
#  {'AttackStrategy': 197,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 803},
#  {'AttackStrategy': 194,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 806},
#  {'AttackStrategy': 196,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 804},
#  {'AttackStrategy': 191,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 809},
#  {'AttackStrategy': 184,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 816},
#  {'AttackStrategy': 177,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 823},
#  {'AttackStrategy': 171,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 829},
#  {'AttackStrategy': 180,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 820},
#  {'AttackStrategy': 190,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 810},
#  {'AttackStrategy': 188,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 812},
#  {'AttackStrategy': 181,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 819},
#  {'AttackStrategy': 197,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 803},
#  {'AttackStrategy': 189,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 811},
#  {'AttackStrategy': 183,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 817},
#  {'AttackStrategy': 182,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 818},
#  {'AttackStrategy': 180,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 820},
#  {'AttackStrategy': 185,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 815},
#  {'AttackStrategy': 188,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 812},
#  {'AttackStrategy': 187,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 813},
#  {'AttackStrategy': 183,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 817},
#  {'AttackStrategy': 190,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 810},
#  {'AttackStrategy': 191,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 809},
#  {'AttackStrategy': 200,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 800},
#  {'AttackStrategy': 197,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 803},
#  {'AttackStrategy': 205,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 795},
#  {'AttackStrategy': 207,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 793},
#  {'AttackStrategy': 205,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 795},
#  {'AttackStrategy': 194,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 806},
#  {'AttackStrategy': 197,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 803},
#  {'AttackStrategy': 203,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 797},
#  {'AttackStrategy': 198,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 802},
#  {'AttackStrategy': 206,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 794},
#  {'AttackStrategy': 210,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 790},
#  {'AttackStrategy': 208,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 792},
#  {'AttackStrategy': 203,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 797},
#  {'AttackStrategy': 216,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 784},
#  {'AttackStrategy': 206,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 794},
#  {'AttackStrategy': 201,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 799},
#  {'AttackStrategy': 216,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 784},
#  {'AttackStrategy': 209,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 791},
#  {'AttackStrategy': 204,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 796},
#  {'AttackStrategy': 201,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 799},
#  {'AttackStrategy': 189,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 811},
#  {'AttackStrategy': 191,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 809},
#  {'AttackStrategy': 190,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 810},
#  {'AttackStrategy': 185,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 815},
#  {'AttackStrategy': 188,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 812},
#  {'AttackStrategy': 197,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 803},
#  {'AttackStrategy': 201,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 799},
#  {'AttackStrategy': 194,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 806},
#  {'AttackStrategy': 201,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 799},
#  {'AttackStrategy': 202,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 798},
#  {'AttackStrategy': 206,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 794},
#  {'AttackStrategy': 205,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 795},
#  {'AttackStrategy': 204,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 796},
#  {'AttackStrategy': 202,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 798},
#  {'AttackStrategy': 195,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 805},
#  {'AttackStrategy': 193,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 807},
#  {'AttackStrategy': 193,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 807},
#  {'AttackStrategy': 185,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 815},
#  {'AttackStrategy': 184,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 816},
#  {'AttackStrategy': 195,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 805},
#  {'AttackStrategy': 197,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 803},
#  {'AttackStrategy': 199,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 801},
#  {'AttackStrategy': 200,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 800},
#  {'AttackStrategy': 205,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 795},
#  {'AttackStrategy': 202,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 798},
#  {'AttackStrategy': 201,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 799},
#  {'AttackStrategy': 200,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 800},
#  {'AttackStrategy': 199,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 801},
#  {'AttackStrategy': 200,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 800},
#  {'AttackStrategy': 203,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 797},
#  {'AttackStrategy': 205,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 795},
#  {'AttackStrategy': 197,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 803},
#  {'AttackStrategy': 197,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 803},
#  {'AttackStrategy': 187,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 813},
#  {'AttackStrategy': 188,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 812},
#  {'AttackStrategy': 186,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 814},
#  {'AttackStrategy': 192,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 808},
#  {'AttackStrategy': 187,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 813},
# ...
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 829},
#  {'AttackStrategy': 175,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 825},
#  {'AttackStrategy': 184,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 816},
#  {'AttackStrategy': 189,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 811},
#  {'AttackStrategy': 187,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 813},
#  {'AttackStrategy': 187,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 813},
#  {'AttackStrategy': 190,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 810},
#  {'AttackStrategy': 192,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 808},
#  {'AttackStrategy': 193,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 807},
#  {'AttackStrategy': 187,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 813},
#  {'AttackStrategy': 181,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 819},
#  {'AttackStrategy': 181,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 819},
#  {'AttackStrategy': 187,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 813},
#  {'AttackStrategy': 187,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 813},
#  {'AttackStrategy': 194,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 806},
#  {'AttackStrategy': 198,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 802},
#  {'AttackStrategy': 196,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 804},
#  {'AttackStrategy': 193,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 807},
#  {'AttackStrategy': 195,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 805},
#  {'AttackStrategy': 192,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 808},
#  {'AttackStrategy': 196,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 804},
#  {'AttackStrategy': 203,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 797},
#  {'AttackStrategy': 210,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 790},
#  {'AttackStrategy': 206,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 794},
#  {'AttackStrategy': 200,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 800},
#  {'AttackStrategy': 206,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 794},
#  {'AttackStrategy': 205,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 795},
#  {'AttackStrategy': 204,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 796},
#  {'AttackStrategy': 204,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 796},
#  {'AttackStrategy': 208,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 792},
#  {'AttackStrategy': 200,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 800},
#  {'AttackStrategy': 195,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 805},
#  {'AttackStrategy': 191,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 809},
#  {'AttackStrategy': 192,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 808},
#  {'AttackStrategy': 193,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 807},
#  {'AttackStrategy': 195,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 805},
#  {'AttackStrategy': 201,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 799},
#  {'AttackStrategy': 201,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 799},
#  {'AttackStrategy': 205,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 795},
#  {'AttackStrategy': 205,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 795},
#  {'AttackStrategy': 208,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 792},
#  {'AttackStrategy': 207,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 793},
#  {'AttackStrategy': 209,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 791},
#  {'AttackStrategy': 214,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 786},
#  {'AttackStrategy': 209,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 791},
#  {'AttackStrategy': 210,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 790},
#  {'AttackStrategy': 221,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 779},
#  {'AttackStrategy': 214,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 786},
#  {'AttackStrategy': 215,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 785},
#  {'AttackStrategy': 210,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 790},
#  {'AttackStrategy': 206,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 794},
#  {'AttackStrategy': 211,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 789},
#  {'AttackStrategy': 215,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 785},
#  {'AttackStrategy': 207,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 793},
#  {'AttackStrategy': 213,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 787},
#  {'AttackStrategy': 213,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 787},
#  {'AttackStrategy': 204,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 796},
#  {'AttackStrategy': 205,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 795},
#  {'AttackStrategy': 201,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 799},
#  {'AttackStrategy': 196,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 804},
#  {'AttackStrategy': 197,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 803},
#  {'AttackStrategy': 193,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 807},
#  {'AttackStrategy': 197,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 803},
#  {'AttackStrategy': 201,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 799},
#  {'AttackStrategy': 192,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 808},
#  {'AttackStrategy': 193,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 807},
#  {'AttackStrategy': 198,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 802},
#  {'AttackStrategy': 197,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 803},
#  {'AttackStrategy': 197,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 803},
#  {'AttackStrategy': 197,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 803},
#  {'AttackStrategy': 191,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 809},
#  {'AttackStrategy': 197,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 803},
#  {'AttackStrategy': 192,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 808},
#  {'AttackStrategy': 189,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 811},
#  {'AttackStrategy': 195,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 805},
#  {'AttackStrategy': 192,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 808},
#  {'AttackStrategy': 192,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 808},
#  {'AttackStrategy': 191,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 809},
#  {'AttackStrategy': 187,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 813},
#  {'AttackStrategy': 189,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 811},
#  {'AttackStrategy': 184,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 816},
#  {'AttackStrategy': 182,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 818},
#  {'AttackStrategy': 182,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 818},
#  {'AttackStrategy': 193,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 807},
#  {'AttackStrategy': 182,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 818},
#  {'AttackStrategy': 178,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 822},
#  {'AttackStrategy': 182,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 818},
#  {'AttackStrategy': 178,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 822},
#  {'AttackStrategy': 174,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 826},
#  {'AttackStrategy': 179,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 821},
#  {'AttackStrategy': 186,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 814},
#  {'AttackStrategy': 178,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 822},
#  {'AttackStrategy': 178,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 822},
#  {'AttackStrategy': 181,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 819},
#  {'AttackStrategy': 174,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 826},
#  {'AttackStrategy': 178,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 822},
#  {'AttackStrategy': 187,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 813},
#  {'AttackStrategy': 192,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 808},
#  {'AttackStrategy': 190,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 810},
#  {'AttackStrategy': 202,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 798},
#  {'AttackStrategy': 194,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 806},
#  {'AttackStrategy': 191,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 809},
#  {'AttackStrategy': 191,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 809},
#  {'AttackStrategy': 191,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 809},
#  {'AttackStrategy': 194,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 806},
#  {'AttackStrategy': 196,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 804},
#  {'AttackStrategy': 199,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 801},
#  {'AttackStrategy': 198,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 802},
#  {'AttackStrategy': 195,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 805},
#  {'AttackStrategy': 187,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 813},
#  {'AttackStrategy': 188,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 812},
#  {'AttackStrategy': 191,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 809},
#  {'AttackStrategy': 195,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 805},
#  {'AttackStrategy': 189,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 811},
#  {'AttackStrategy': 184,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 816},
#  {'AttackStrategy': 180,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 820},
#  {'AttackStrategy': 189,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 811},
#  {'AttackStrategy': 186,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 814},
#  {'AttackStrategy': 183,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 817},
#  {'AttackStrategy': 183,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 817},
#  {'AttackStrategy': 182,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 818},
#  {'AttackStrategy': 188,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 812},
#  {'AttackStrategy': 188,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 812},
#  {'AttackStrategy': 185,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 815},
#  {'AttackStrategy': 183,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 817},
#  {'AttackStrategy': 181,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 819},
#  {'AttackStrategy': 180,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 820},
#  {'AttackStrategy': 177,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 823},
#  {'AttackStrategy': 173,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 827},
#  {'AttackStrategy': 174,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 826},
#  {'AttackStrategy': 176,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 824},
#  {'AttackStrategy': 182,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 818},
#  {'AttackStrategy': 182,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 818},
#  {'AttackStrategy': 186,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 814},
#  {'AttackStrategy': 195,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 805},
#  {'AttackStrategy': 188,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 812},
#  {'AttackStrategy': 188,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 812},
#  {'AttackStrategy': 191,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 809},
#  {'AttackStrategy': 195,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 805},
#  {'AttackStrategy': 196,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 804},
#  {'AttackStrategy': 203,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 797},
#  {'AttackStrategy': 207,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 793},
#  {'AttackStrategy': 212,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 788},
#  {'AttackStrategy': 207,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 793},
#  {'AttackStrategy': 203,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 797},
#  {'AttackStrategy': 198,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 802},
#  {'AttackStrategy': 194,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 806},
#  {'AttackStrategy': 195,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 805},
#  {'AttackStrategy': 197,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 803},
#  {'AttackStrategy': 192,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 808},
#  {'AttackStrategy': 190,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 810},
#  {'AttackStrategy': 200,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 800},
#  {'AttackStrategy': 202,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 798},
#  {'AttackStrategy': 195,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 805},
#  {'AttackStrategy': 186,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 814},
#  {'AttackStrategy': 192,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 808},
#  {'AttackStrategy': 192,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 808}]

# %%
# %matplotlib inline
import matplotlib.pyplot as plt


def plot_strategy_counts(data):
    """Plot strategy counts for each iteration."""

    # Extract strategy names
    strategy_names = list(data[0].keys())

    # Create a color map for each strategy
    colors = ["blue", "orange", "green", "red"]
    color_map = dict(zip(strategy_names, colors))

    # Create lists to store data for each strategy
    strategy_counts = {}
    for strategy in strategy_names:
        strategy_counts[strategy] = []

    # Extract counts for each strategy for each iteration
    for iteration in data:
        for strategy in strategy_names:
            strategy_counts[strategy].append(iteration[strategy])

    # Create plot
    plt.figure(figsize=(10, 6))
    for strategy in strategy_names:
        plt.plot(
            range(len(data)),
            strategy_counts[strategy],
            label=strategy,
            color=color_map[strategy],
        )
    plt.xlabel("Iterations")
    plt.ylabel("Strategy Count")
    plt.legend()
    plt.show()

# %%
plot_strategy_counts(env.state.population_by_strategy)

# %%
plot_strategy_counts(env.state.hp_by_strategy)

# %%
plot_strategy_counts(env.state.xp_by_strategy)

# %%
len(env.state.agents_fallen[0])
# Out:
# 125

# %%
from collections import Counter

# %%
for i in range(env.num_rounds):
    print(
        "agents_fallen: "
        + str(Counter([a.strategy.__name__ for a in env.state.agents_fallen[i]]))
    )
    print(
        "agents_respawned: "
        + str(Counter([a.strategy.__name__ for a in env.state.agents_respawned[i]]))
    )
# Out:
# agents_fallen: Counter({'AttackStrategy': 68, 'RetaliateStrategy': 57})
# agents_respawned: Counter({'AttackStrategy': 52, 'RetaliateStrategy': 48, 'RetreatStrategy': 18, 'ExploitStrategy': 7})
# agents_fallen: Counter({'AttackStrategy': 61, 'RetaliateStrategy': 45, 'RetreatStrategy': 2})
# agents_respawned: Counter({'RetaliateStrategy': 36, 'AttackStrategy': 32, 'ExploitStrategy': 24, 'RetreatStrategy': 16})
# agents_fallen: Counter({'AttackStrategy': 50, 'RetaliateStrategy': 38, 'ExploitStrategy': 6, 'RetreatStrategy': 3})
# agents_respawned: Counter({'AttackStrategy': 33, 'RetreatStrategy': 23, 'RetaliateStrategy': 22, 'ExploitStrategy': 19})
# agents_fallen: Counter({'AttackStrategy': 39, 'RetaliateStrategy': 32, 'ExploitStrategy': 5, 'RetreatStrategy': 4})
# agents_respawned: Counter({'ExploitStrategy': 25, 'RetaliateStrategy': 21, 'AttackStrategy': 20, 'RetreatStrategy': 14})
# agents_fallen: Counter({'RetaliateStrategy': 43, 'AttackStrategy': 25, 'RetreatStrategy': 9, 'ExploitStrategy': 3})
# agents_respawned: Counter({'ExploitStrategy': 24, 'RetreatStrategy': 23, 'RetaliateStrategy': 17, 'AttackStrategy': 16})
# agents_fallen: Counter({'AttackStrategy': 28, 'RetaliateStrategy': 18, 'ExploitStrategy': 11, 'RetreatStrategy': 7})
# agents_respawned: Counter({'AttackStrategy': 19, 'ExploitStrategy': 17, 'RetreatStrategy': 15, 'RetaliateStrategy': 13})
# agents_fallen: Counter({'RetaliateStrategy': 25, 'AttackStrategy': 22, 'RetreatStrategy': 12, 'ExploitStrategy': 6})
# agents_respawned: Counter({'ExploitStrategy': 24, 'RetreatStrategy': 19, 'AttackStrategy': 14, 'RetaliateStrategy': 8})
# agents_fallen: Counter({'RetaliateStrategy': 19, 'AttackStrategy': 18, 'RetreatStrategy': 12, 'ExploitStrategy': 10})
# agents_respawned: Counter({'ExploitStrategy': 20, 'RetreatStrategy': 19, 'AttackStrategy': 11, 'RetaliateStrategy': 9})
# agents_fallen: Counter({'RetaliateStrategy': 24, 'AttackStrategy': 21, 'RetreatStrategy': 14, 'ExploitStrategy': 11})
# agents_respawned: Counter({'ExploitStrategy': 31, 'RetreatStrategy': 18, 'AttackStrategy': 11, 'RetaliateStrategy': 10})
# agents_fallen: Counter({'RetreatStrategy': 22, 'ExploitStrategy': 16, 'RetaliateStrategy': 15, 'AttackStrategy': 14})
# agents_respawned: Counter({'ExploitStrategy': 33, 'RetreatStrategy': 19, 'AttackStrategy': 12, 'RetaliateStrategy': 3})
# agents_fallen: Counter({'AttackStrategy': 15, 'ExploitStrategy': 12, 'RetaliateStrategy': 12, 'RetreatStrategy': 10})
# agents_respawned: Counter({'ExploitStrategy': 22, 'RetreatStrategy': 16, 'RetaliateStrategy': 8, 'AttackStrategy': 3})
# agents_fallen: Counter({'RetreatStrategy': 18, 'AttackStrategy': 9, 'ExploitStrategy': 8, 'RetaliateStrategy': 8})
# agents_respawned: Counter({'RetreatStrategy': 16, 'ExploitStrategy': 14, 'RetaliateStrategy': 8, 'AttackStrategy': 5})
# agents_fallen: Counter({'RetreatStrategy': 23, 'ExploitStrategy': 19, 'RetaliateStrategy': 13, 'AttackStrategy': 11})
# agents_respawned: Counter({'ExploitStrategy': 28, 'RetreatStrategy': 21, 'RetaliateStrategy': 11, 'AttackStrategy': 6})
# agents_fallen: Counter({'RetreatStrategy': 22, 'ExploitStrategy': 16, 'RetaliateStrategy': 16, 'AttackStrategy': 7})
# agents_respawned: Counter({'ExploitStrategy': 27, 'RetreatStrategy': 20, 'AttackStrategy': 8, 'RetaliateStrategy': 6})
# agents_fallen: Counter({'RetreatStrategy': 20, 'ExploitStrategy': 16, 'RetaliateStrategy': 10, 'AttackStrategy': 10})
# agents_respawned: Counter({'ExploitStrategy': 24, 'RetreatStrategy': 16, 'AttackStrategy': 8, 'RetaliateStrategy': 8})
# agents_fallen: Counter({'RetreatStrategy': 28, 'ExploitStrategy': 17, 'RetaliateStrategy': 12, 'AttackStrategy': 4})
# agents_respawned: Counter({'ExploitStrategy': 25, 'RetreatStrategy': 24, 'RetaliateStrategy': 8, 'AttackStrategy': 4})
# agents_fallen: Counter({'RetreatStrategy': 34, 'ExploitStrategy': 22, 'RetaliateStrategy': 11, 'AttackStrategy': 5})
# agents_respawned: Counter({'ExploitStrategy': 37, 'RetreatStrategy': 20, 'AttackStrategy': 8, 'RetaliateStrategy': 7})
# agents_fallen: Counter({'RetreatStrategy': 29, 'ExploitStrategy': 23, 'AttackStrategy': 14, 'RetaliateStrategy': 10})
# agents_respawned: Counter({'ExploitStrategy': 31, 'RetreatStrategy': 23, 'RetaliateStrategy': 13, 'AttackStrategy': 9})
# agents_fallen: Counter({'RetreatStrategy': 25, 'ExploitStrategy': 17, 'AttackStrategy': 7, 'RetaliateStrategy': 4})
# agents_respawned: Counter({'ExploitStrategy': 26, 'RetreatStrategy': 16, 'RetaliateStrategy': 6, 'AttackStrategy': 5})
# agents_fallen: Counter({'RetreatStrategy': 23, 'ExploitStrategy': 17, 'RetaliateStrategy': 9, 'AttackStrategy': 7})
# agents_respawned: Counter({'ExploitStrategy': 32, 'RetreatStrategy': 15, 'AttackStrategy': 7, 'RetaliateStrategy': 2})
# agents_fallen: Counter({'RetreatStrategy': 27, 'ExploitStrategy': 14, 'RetaliateStrategy': 13, 'AttackStrategy': 6})
# agents_respawned: Counter({'ExploitStrategy': 27, 'RetreatStrategy': 19, 'AttackStrategy': 8, 'RetaliateStrategy': 6})
# agents_fallen: Counter({'RetreatStrategy': 26, 'ExploitStrategy': 20, 'RetaliateStrategy': 9, 'AttackStrategy': 9})
# agents_respawned: Counter({'ExploitStrategy': 31, 'RetreatStrategy': 18, 'RetaliateStrategy': 8, 'AttackStrategy': 7})
# agents_fallen: Counter({'ExploitStrategy': 29, 'RetreatStrategy': 26, 'RetaliateStrategy': 11, 'AttackStrategy': 8})
# agents_respawned: Counter({'ExploitStrategy': 36, 'RetreatStrategy': 22, 'AttackStrategy': 10, 'RetaliateStrategy': 6})
# agents_fallen: Counter({'RetreatStrategy': 26, 'ExploitStrategy': 25, 'RetaliateStrategy': 9, 'AttackStrategy': 8})
# agents_respawned: Counter({'ExploitStrategy': 41, 'RetreatStrategy': 21, 'AttackStrategy': 3, 'RetaliateStrategy': 3})
# agents_fallen: Counter({'RetreatStrategy': 36, 'ExploitStrategy': 30, 'RetaliateStrategy': 8, 'AttackStrategy': 6})
# agents_respawned: Counter({'ExploitStrategy': 48, 'RetreatStrategy': 20, 'AttackStrategy': 8, 'RetaliateStrategy': 4})
# agents_fallen: Counter({'RetreatStrategy': 26, 'ExploitStrategy': 21, 'RetaliateStrategy': 10, 'AttackStrategy': 5})
# agents_respawned: Counter({'ExploitStrategy': 36, 'AttackStrategy': 15, 'RetreatStrategy': 7, 'RetaliateStrategy': 4})
# agents_fallen: Counter({'RetreatStrategy': 29, 'ExploitStrategy': 26, 'RetaliateStrategy': 10, 'AttackStrategy': 7})
# agents_respawned: Counter({'ExploitStrategy': 51, 'RetreatStrategy': 9, 'AttackStrategy': 7, 'RetaliateStrategy': 5})
# agents_fallen: Counter({'ExploitStrategy': 38, 'RetreatStrategy': 24, 'RetaliateStrategy': 10, 'AttackStrategy': 6})
# agents_respawned: Counter({'ExploitStrategy': 47, 'AttackStrategy': 12, 'RetreatStrategy': 10, 'RetaliateStrategy': 9})
# agents_fallen: Counter({'RetreatStrategy': 24, 'ExploitStrategy': 21, 'AttackStrategy': 10, 'RetaliateStrategy': 2})
# agents_respawned: Counter({'ExploitStrategy': 34, 'AttackStrategy': 9, 'RetreatStrategy': 9, 'RetaliateStrategy': 5})
# agents_fallen: Counter({'ExploitStrategy': 30, 'RetreatStrategy': 15, 'RetaliateStrategy': 8, 'AttackStrategy': 7})
# agents_respawned: Counter({'ExploitStrategy': 38, 'RetreatStrategy': 12, 'AttackStrategy': 6, 'RetaliateStrategy': 4})
# agents_fallen: Counter({'ExploitStrategy': 36, 'RetreatStrategy': 24, 'AttackStrategy': 6, 'RetaliateStrategy': 5})
# agents_respawned: Counter({'ExploitStrategy': 55, 'RetreatStrategy': 11, 'AttackStrategy': 5})
# agents_fallen: Counter({'ExploitStrategy': 24, 'RetreatStrategy': 23, 'AttackStrategy': 9, 'RetaliateStrategy': 6})
# agents_respawned: Counter({'ExploitStrategy': 46, 'AttackStrategy': 8, 'RetreatStrategy': 6, 'RetaliateStrategy': 2})
# agents_fallen: Counter({'ExploitStrategy': 48, 'RetreatStrategy': 24, 'RetaliateStrategy': 8, 'AttackStrategy': 8})
# agents_respawned: Counter({'ExploitStrategy': 63, 'RetreatStrategy': 15, 'AttackStrategy': 9, 'RetaliateStrategy': 1})
# agents_fallen: Counter({'ExploitStrategy': 35, 'RetreatStrategy': 15, 'AttackStrategy': 7, 'RetaliateStrategy': 5})
# agents_respawned: Counter({'ExploitStrategy': 38, 'AttackStrategy': 15, 'RetreatStrategy': 7, 'RetaliateStrategy': 2})
# agents_fallen: Counter({'ExploitStrategy': 26, 'RetreatStrategy': 14, 'AttackStrategy': 7, 'RetaliateStrategy': 5})
# agents_respawned: Counter({'ExploitStrategy': 41, 'AttackStrategy': 6, 'RetreatStrategy': 4, 'RetaliateStrategy': 1})
# agents_fallen: Counter({'ExploitStrategy': 45, 'RetreatStrategy': 20, 'AttackStrategy': 5, 'RetaliateStrategy': 2})
# agents_respawned: Counter({'ExploitStrategy': 54, 'RetreatStrategy': 9, 'AttackStrategy': 5, 'RetaliateStrategy': 4})
# agents_fallen: Counter({'ExploitStrategy': 46, 'RetreatStrategy': 16, 'AttackStrategy': 7, 'RetaliateStrategy': 5})
# agents_respawned: Counter({'ExploitStrategy': 51, 'AttackStrategy': 18, 'RetreatStrategy': 3, 'RetaliateStrategy': 2})
# agents_fallen: Counter({'ExploitStrategy': 39, 'RetreatStrategy': 18, 'RetaliateStrategy': 8, 'AttackStrategy': 7})
# agents_respawned: Counter({'ExploitStrategy': 53, 'AttackStrategy': 10, 'RetreatStrategy': 5, 'RetaliateStrategy': 4})
# agents_fallen: Counter({'ExploitStrategy': 50, 'RetreatStrategy': 19, 'AttackStrategy': 11, 'RetaliateStrategy': 5})
# agents_respawned: Counter({'ExploitStrategy': 63, 'AttackStrategy': 12, 'RetaliateStrategy': 8, 'RetreatStrategy': 2})
# agents_fallen: Counter({'ExploitStrategy': 40, 'AttackStrategy': 13, 'RetreatStrategy': 11, 'RetaliateStrategy': 4})
# agents_respawned: Counter({'ExploitStrategy': 51, 'AttackStrategy': 11, 'RetreatStrategy': 5, 'RetaliateStrategy': 1})
# agents_fallen: Counter({'ExploitStrategy': 45, 'AttackStrategy': 19, 'RetreatStrategy': 16, 'RetaliateStrategy': 6})
# agents_respawned: Counter({'ExploitStrategy': 73, 'AttackStrategy': 11, 'RetaliateStrategy': 1, 'RetreatStrategy': 1})
# agents_fallen: Counter({'ExploitStrategy': 52, 'RetreatStrategy': 8, 'AttackStrategy': 8, 'RetaliateStrategy': 5})
# agents_respawned: Counter({'ExploitStrategy': 62, 'AttackStrategy': 8, 'RetreatStrategy': 3})
# agents_fallen: Counter({'ExploitStrategy': 48, 'RetreatStrategy': 15, 'AttackStrategy': 5, 'RetaliateStrategy': 4})
# agents_respawned: Counter({'ExploitStrategy': 48, 'AttackStrategy': 16, 'RetreatStrategy': 8})
# agents_fallen: Counter({'ExploitStrategy': 48, 'RetreatStrategy': 9, 'AttackStrategy': 8, 'RetaliateStrategy': 3})
# agents_respawned: Counter({'ExploitStrategy': 58, 'AttackStrategy': 9, 'RetaliateStrategy': 1})
# agents_fallen: Counter({'ExploitStrategy': 53, 'AttackStrategy': 10, 'RetreatStrategy': 8})
# agents_respawned: Counter({'ExploitStrategy': 57, 'AttackStrategy': 12, 'RetaliateStrategy': 1, 'RetreatStrategy': 1})
# agents_fallen: Counter({'ExploitStrategy': 50, 'AttackStrategy': 9, 'RetreatStrategy': 4, 'RetaliateStrategy': 2})
# agents_respawned: Counter({'ExploitStrategy': 59, 'AttackStrategy': 3, 'RetreatStrategy': 2, 'RetaliateStrategy': 1})
# agents_fallen: Counter({'ExploitStrategy': 58, 'AttackStrategy': 10, 'RetaliateStrategy': 2, 'RetreatStrategy': 2})
# agents_respawned: Counter({'ExploitStrategy': 61, 'AttackStrategy': 10, 'RetaliateStrategy': 1})
# agents_fallen: Counter({'ExploitStrategy': 51, 'AttackStrategy': 8, 'RetreatStrategy': 5, 'RetaliateStrategy': 1})
# agents_respawned: Counter({'ExploitStrategy': 54, 'AttackStrategy': 10, 'RetaliateStrategy': 1})
# agents_fallen: Counter({'ExploitStrategy': 60, 'RetreatStrategy': 6, 'AttackStrategy': 4, 'RetaliateStrategy': 2})
# agents_respawned: Counter({'ExploitStrategy': 60, 'AttackStrategy': 11, 'RetaliateStrategy': 1})
# agents_fallen: Counter({'ExploitStrategy': 61, 'AttackStrategy': 10, 'RetreatStrategy': 4, 'RetaliateStrategy': 1})
# agents_respawned: Counter({'ExploitStrategy': 62, 'AttackStrategy': 11, 'RetreatStrategy': 2, 'RetaliateStrategy': 1})
# agents_fallen: Counter({'ExploitStrategy': 59, 'AttackStrategy': 5, 'RetreatStrategy': 3})
# agents_respawned: Counter({'ExploitStrategy': 52, 'AttackStrategy': 13, 'RetreatStrategy': 2})
# agents_fallen: Counter({'ExploitStrategy': 47, 'AttackStrategy': 12, 'RetreatStrategy': 3, 'RetaliateStrategy': 2})
# agents_respawned: Counter({'ExploitStrategy': 47, 'AttackStrategy': 16, 'RetaliateStrategy': 1})
# agents_fallen: Counter({'ExploitStrategy': 73, 'AttackStrategy': 14, 'RetaliateStrategy': 2, 'RetreatStrategy': 1})
# agents_respawned: Counter({'ExploitStrategy': 68, 'AttackStrategy': 21, 'RetaliateStrategy': 1})
# agents_fallen: Counter({'ExploitStrategy': 56, 'AttackStrategy': 13, 'RetreatStrategy': 2, 'RetaliateStrategy': 1})
# agents_respawned: Counter({'ExploitStrategy': 62, 'AttackStrategy': 9, 'RetreatStrategy': 1})
# agents_fallen: Counter({'ExploitStrategy': 68, 'AttackStrategy': 15, 'RetaliateStrategy': 3, 'RetreatStrategy': 2})
# agents_respawned: Counter({'ExploitStrategy': 69, 'AttackStrategy': 18, 'RetaliateStrategy': 1})
# agents_fallen: Counter({'ExploitStrategy': 53, 'AttackStrategy': 11, 'RetaliateStrategy': 2, 'RetreatStrategy': 2})
# agents_respawned: Counter({'ExploitStrategy': 47, 'AttackStrategy': 20, 'RetaliateStrategy': 1})
# agents_fallen: Counter({'ExploitStrategy': 68, 'AttackStrategy': 19, 'RetreatStrategy': 2})
# agents_respawned: Counter({'ExploitStrategy': 70, 'AttackStrategy': 17, 'RetreatStrategy': 2})
# agents_fallen: Counter({'ExploitStrategy': 54, 'AttackStrategy': 24, 'RetaliateStrategy': 2, 'RetreatStrategy': 1})
# agents_respawned: Counter({'ExploitStrategy': 64, 'AttackStrategy': 17})
# agents_fallen: Counter({'ExploitStrategy': 41, 'AttackStrategy': 13, 'RetreatStrategy': 1})
# agents_respawned: Counter({'ExploitStrategy': 40, 'AttackStrategy': 15})
# agents_fallen: Counter({'ExploitStrategy': 54, 'AttackStrategy': 13, 'RetaliateStrategy': 1})
# agents_respawned: Counter({'ExploitStrategy': 57, 'AttackStrategy': 11})
# agents_fallen: Counter({'ExploitStrategy': 83, 'AttackStrategy': 12, 'RetaliateStrategy': 1})
# agents_respawned: Counter({'ExploitStrategy': 72, 'AttackStrategy': 23, 'RetaliateStrategy': 1})
# agents_fallen: Counter({'ExploitStrategy': 66, 'AttackStrategy': 14})
# agents_respawned: Counter({'ExploitStrategy': 63, 'AttackStrategy': 16, 'RetaliateStrategy': 1})
# agents_fallen: Counter({'ExploitStrategy': 53, 'AttackStrategy': 14, 'RetreatStrategy': 1})
# agents_respawned: Counter({'ExploitStrategy': 60, 'AttackStrategy': 8})
# agents_fallen: Counter({'ExploitStrategy': 73, 'AttackStrategy': 18, 'RetaliateStrategy': 1})
# agents_respawned: Counter({'ExploitStrategy': 74, 'AttackStrategy': 18})
# agents_fallen: Counter({'ExploitStrategy': 68, 'AttackStrategy': 18, 'RetreatStrategy': 1})
# agents_respawned: Counter({'ExploitStrategy': 67, 'AttackStrategy': 20})
# agents_fallen: Counter({'ExploitStrategy': 68, 'AttackStrategy': 18})
# agents_respawned: Counter({'ExploitStrategy': 76, 'AttackStrategy': 10})
# agents_fallen: Counter({'ExploitStrategy': 58, 'AttackStrategy': 9})
# agents_respawned: Counter({'ExploitStrategy': 48, 'AttackStrategy': 19})
# agents_fallen: Counter({'ExploitStrategy': 53, 'AttackStrategy': 20, 'RetreatStrategy': 1})
# agents_respawned: Counter({'ExploitStrategy': 58, 'AttackStrategy': 16})
# agents_fallen: Counter({'ExploitStrategy': 58, 'AttackStrategy': 14})
# agents_respawned: Counter({'ExploitStrategy': 66, 'AttackStrategy': 6})
# agents_fallen: Counter({'ExploitStrategy': 57, 'AttackStrategy': 10, 'RetaliateStrategy': 1})
# agents_respawned: Counter({'ExploitStrategy': 55, 'AttackStrategy': 13})
# agents_fallen: Counter({'ExploitStrategy': 57, 'AttackStrategy': 17})
# agents_respawned: Counter({'ExploitStrategy': 58, 'AttackStrategy': 15, 'RetaliateStrategy': 1})
# agents_fallen: Counter({'ExploitStrategy': 63, 'AttackStrategy': 14})
# agents_respawned: Counter({'ExploitStrategy': 64, 'AttackStrategy': 13})
# agents_fallen: Counter({'ExploitStrategy': 57, 'AttackStrategy': 16})
# agents_respawned: Counter({'ExploitStrategy': 60, 'AttackStrategy': 13})
# agents_fallen: Counter({'ExploitStrategy': 52, 'AttackStrategy': 11})
# agents_respawned: Counter({'ExploitStrategy': 50, 'AttackStrategy': 13})
# agents_fallen: Counter({'ExploitStrategy': 63, 'AttackStrategy': 10, 'RetaliateStrategy': 1})
# agents_respawned: Counter({'ExploitStrategy': 61, 'AttackStrategy': 13})
# agents_fallen: Counter({'ExploitStrategy': 69, 'AttackStrategy': 12})
# agents_respawned: Counter({'ExploitStrategy': 65, 'AttackStrategy': 16})
# agents_fallen: Counter({'ExploitStrategy': 60, 'AttackStrategy': 13})
# agents_respawned: Counter({'ExploitStrategy': 61, 'AttackStrategy': 12})
# agents_fallen: Counter({'ExploitStrategy': 64, 'AttackStrategy': 8})
# agents_respawned: Counter({'ExploitStrategy': 58, 'AttackStrategy': 14})
# agents_fallen: Counter({'ExploitStrategy': 60, 'AttackStrategy': 17})
# agents_respawned: Counter({'ExploitStrategy': 59, 'AttackStrategy': 18})
# agents_fallen: Counter({'ExploitStrategy': 56, 'AttackStrategy': 14})
# agents_respawned: Counter({'ExploitStrategy': 50, 'AttackStrategy': 20})
# agents_fallen: Counter({'ExploitStrategy': 70, 'AttackStrategy': 19})
# agents_respawned: Counter({'ExploitStrategy': 70, 'AttackStrategy': 19})
# agents_fallen: Counter({'ExploitStrategy': 68, 'AttackStrategy': 13})
# agents_respawned: Counter({'ExploitStrategy': 64, 'AttackStrategy': 17})
# agents_fallen: Counter({'ExploitStrategy': 69, 'AttackStrategy': 12, 'RetaliateStrategy': 1})
# agents_respawned: Counter({'ExploitStrategy': 64, 'AttackStrategy': 17, 'RetaliateStrategy': 1})
# agents_fallen: Counter({'ExploitStrategy': 69, 'AttackStrategy': 13})
# agents_respawned: Counter({'ExploitStrategy': 66, 'AttackStrategy': 16})
# agents_fallen: Counter({'ExploitStrategy': 59, 'AttackStrategy': 12})
# agents_respawned: Counter({'ExploitStrategy': 56, 'AttackStrategy': 15})
# agents_fallen: Counter({'ExploitStrategy': 70, 'AttackStrategy': 13, 'RetaliateStrategy': 1})
# agents_respawned: Counter({'ExploitStrategy': 65, 'AttackStrategy': 19})
# agents_fallen: Counter({'ExploitStrategy': 55, 'AttackStrategy': 15})
# agents_respawned: Counter({'ExploitStrategy': 55, 'AttackStrategy': 15})
# agents_fallen: Counter({'ExploitStrategy': 52, 'AttackStrategy': 19})
# agents_respawned: Counter({'ExploitStrategy': 54, 'AttackStrategy': 17})
# agents_fallen: Counter({'ExploitStrategy': 63, 'AttackStrategy': 19})
# agents_respawned: Counter({'ExploitStrategy': 68, 'AttackStrategy': 14})
# agents_fallen: Counter({'ExploitStrategy': 63, 'AttackStrategy': 18})
# agents_respawned: Counter({'ExploitStrategy': 61, 'AttackStrategy': 20})
# agents_fallen: Counter({'ExploitStrategy': 51, 'AttackStrategy': 26})
# agents_respawned: Counter({'ExploitStrategy': 63, 'AttackStrategy': 14})
# agents_fallen: Counter({'ExploitStrategy': 75, 'AttackStrategy': 15})
# agents_respawned: Counter({'ExploitStrategy': 69, 'AttackStrategy': 21})
# agents_fallen: Counter({'ExploitStrategy': 61, 'AttackStrategy': 13})
# agents_respawned: Counter({'ExploitStrategy': 54, 'AttackStrategy': 20})
# agents_fallen: Counter({'ExploitStrategy': 62, 'AttackStrategy': 22})
# agents_respawned: Counter({'ExploitStrategy': 67, 'AttackStrategy': 17})
# agents_fallen: Counter({'ExploitStrategy': 57, 'AttackStrategy': 18})
# agents_respawned: Counter({'ExploitStrategy': 57, 'AttackStrategy': 18})
# agents_fallen: Counter({'ExploitStrategy': 67, 'AttackStrategy': 16})
# agents_respawned: Counter({'ExploitStrategy': 60, 'AttackStrategy': 23})
# agents_fallen: Counter({'ExploitStrategy': 67, 'AttackStrategy': 21})
# agents_respawned: Counter({'ExploitStrategy': 68, 'AttackStrategy': 20})
# agents_fallen: Counter({'ExploitStrategy': 65, 'AttackStrategy': 19})
# agents_respawned: Counter({'ExploitStrategy': 64, 'AttackStrategy': 20})
# agents_fallen: Counter({'ExploitStrategy': 61, 'AttackStrategy': 17})
# agents_respawned: Counter({'ExploitStrategy': 61, 'AttackStrategy': 17})
# agents_fallen: Counter({'ExploitStrategy': 50, 'AttackStrategy': 24})
# agents_respawned: Counter({'ExploitStrategy': 59, 'AttackStrategy': 15})
# agents_fallen: Counter({'ExploitStrategy': 70, 'AttackStrategy': 15})
# agents_respawned: Counter({'ExploitStrategy': 69, 'AttackStrategy': 16})
# agents_fallen: Counter({'ExploitStrategy': 53, 'AttackStrategy': 17})
# agents_respawned: Counter({'ExploitStrategy': 56, 'AttackStrategy': 14})
# agents_fallen: Counter({'ExploitStrategy': 63, 'AttackStrategy': 15})
# agents_respawned: Counter({'ExploitStrategy': 57, 'AttackStrategy': 21})
# agents_fallen: Counter({'ExploitStrategy': 59, 'AttackStrategy': 17})
# agents_respawned: Counter({'ExploitStrategy': 52, 'AttackStrategy': 24})
# agents_fallen: Counter({'ExploitStrategy': 60, 'AttackStrategy': 22})
# agents_respawned: Counter({'ExploitStrategy': 65, 'AttackStrategy': 17})
# agents_fallen: Counter({'ExploitStrategy': 62, 'AttackStrategy': 21})
# agents_respawned: Counter({'ExploitStrategy': 70, 'AttackStrategy': 13})
# agents_fallen: Counter({'ExploitStrategy': 65, 'AttackStrategy': 17})
# agents_respawned: Counter({'ExploitStrategy': 63, 'AttackStrategy': 19})
# agents_fallen: Counter({'ExploitStrategy': 62, 'AttackStrategy': 13})
# agents_respawned: Counter({'ExploitStrategy': 66, 'AttackStrategy': 9})
# agents_fallen: Counter({'ExploitStrategy': 64, 'AttackStrategy': 16})
# agents_respawned: Counter({'ExploitStrategy': 64, 'AttackStrategy': 16})
# agents_fallen: Counter({'ExploitStrategy': 64, 'AttackStrategy': 12})
# agents_respawned: Counter({'ExploitStrategy': 61, 'AttackStrategy': 15})
# agents_fallen: Counter({'ExploitStrategy': 71, 'AttackStrategy': 16})
# agents_respawned: Counter({'ExploitStrategy': 59, 'AttackStrategy': 28})
# agents_fallen: Counter({'ExploitStrategy': 62, 'AttackStrategy': 13})
# agents_respawned: Counter({'ExploitStrategy': 64, 'AttackStrategy': 11})
# agents_fallen: Counter({'ExploitStrategy': 74, 'AttackStrategy': 17})
# agents_respawned: Counter({'ExploitStrategy': 71, 'AttackStrategy': 20})
# agents_fallen: Counter({'ExploitStrategy': 53, 'AttackStrategy': 26})
# agents_respawned: Counter({'ExploitStrategy': 61, 'AttackStrategy': 18})
# agents_fallen: Counter({'ExploitStrategy': 68, 'AttackStrategy': 16})
# agents_respawned: Counter({'ExploitStrategy': 63, 'AttackStrategy': 21})
# agents_fallen: Counter({'ExploitStrategy': 61, 'AttackStrategy': 17})
# agents_respawned: Counter({'ExploitStrategy': 57, 'AttackStrategy': 21})
# agents_fallen: Counter({'ExploitStrategy': 60, 'AttackStrategy': 20})
# agents_respawned: Counter({'ExploitStrategy': 55, 'AttackStrategy': 25})
# agents_fallen: Counter({'ExploitStrategy': 56, 'AttackStrategy': 18})
# agents_respawned: Counter({'ExploitStrategy': 56, 'AttackStrategy': 18})
# agents_fallen: Counter({'ExploitStrategy': 59, 'AttackStrategy': 20})
# agents_respawned: Counter({'ExploitStrategy': 62, 'AttackStrategy': 17})
# agents_fallen: Counter({'ExploitStrategy': 65, 'AttackStrategy': 19})
# agents_respawned: Counter({'ExploitStrategy': 62, 'AttackStrategy': 22})
# agents_fallen: Counter({'ExploitStrategy': 44, 'AttackStrategy': 14})
# agents_respawned: Counter({'ExploitStrategy': 43, 'AttackStrategy': 15})
# agents_fallen: Counter({'ExploitStrategy': 65, 'AttackStrategy': 19})
# agents_respawned: Counter({'ExploitStrategy': 62, 'AttackStrategy': 22})
# agents_fallen: Counter({'ExploitStrategy': 63, 'AttackStrategy': 22})
# agents_respawned: Counter({'ExploitStrategy': 62, 'AttackStrategy': 23})
# agents_fallen: Counter({'ExploitStrategy': 64, 'AttackStrategy': 21})
# agents_respawned: Counter({'ExploitStrategy': 65, 'AttackStrategy': 20})
# agents_fallen: Counter({'ExploitStrategy': 67, 'AttackStrategy': 23})
# agents_respawned: Counter({'ExploitStrategy': 66, 'AttackStrategy': 24})
# agents_fallen: Counter({'ExploitStrategy': 69, 'AttackStrategy': 21})
# agents_respawned: Counter({'ExploitStrategy': 66, 'AttackStrategy': 24})
# agents_fallen: Counter({'ExploitStrategy': 61, 'AttackStrategy': 17})
# agents_respawned: Counter({'ExploitStrategy': 57, 'AttackStrategy': 21})
# agents_fallen: Counter({'ExploitStrategy': 51, 'AttackStrategy': 22})
# agents_respawned: Counter({'ExploitStrategy': 48, 'AttackStrategy': 25})
# agents_fallen: Counter({'ExploitStrategy': 69, 'AttackStrategy': 26})
# agents_respawned: Counter({'ExploitStrategy': 71, 'AttackStrategy': 24})
# agents_fallen: Counter({'ExploitStrategy': 55, 'AttackStrategy': 26})
# agents_respawned: Counter({'ExploitStrategy': 68, 'AttackStrategy': 13})
# agents_fallen: Counter({'ExploitStrategy': 52, 'AttackStrategy': 31})
# agents_respawned: Counter({'ExploitStrategy': 63, 'AttackStrategy': 20})
# agents_fallen: Counter({'ExploitStrategy': 75, 'AttackStrategy': 17})
# agents_respawned: Counter({'ExploitStrategy': 78, 'AttackStrategy': 14})
# agents_fallen: Counter({'ExploitStrategy': 65, 'AttackStrategy': 16})
# agents_respawned: Counter({'ExploitStrategy': 66, 'AttackStrategy': 15})
# agents_fallen: Counter({'ExploitStrategy': 58, 'AttackStrategy': 20})
# agents_respawned: Counter({'ExploitStrategy': 57, 'AttackStrategy': 21})
# agents_fallen: Counter({'ExploitStrategy': 45, 'AttackStrategy': 19})
# agents_respawned: Counter({'ExploitStrategy': 50, 'AttackStrategy': 14})
# agents_fallen: Counter({'ExploitStrategy': 57, 'AttackStrategy': 15})
# agents_respawned: Counter({'ExploitStrategy': 56, 'AttackStrategy': 16})
# agents_fallen: Counter({'ExploitStrategy': 57, 'AttackStrategy': 10})
# agents_respawned: Counter({'ExploitStrategy': 54, 'AttackStrategy': 13})
# agents_fallen: Counter({'ExploitStrategy': 64, 'AttackStrategy': 21})
# agents_respawned: Counter({'ExploitStrategy': 61, 'AttackStrategy': 24})
# agents_fallen: Counter({'ExploitStrategy': 69, 'AttackStrategy': 21})
# agents_respawned: Counter({'ExploitStrategy': 76, 'AttackStrategy': 14})
# agents_fallen: Counter({'ExploitStrategy': 69, 'AttackStrategy': 25})
# agents_respawned: Counter({'ExploitStrategy': 75, 'AttackStrategy': 19})
# agents_fallen: Counter({'ExploitStrategy': 62, 'AttackStrategy': 14})
# agents_respawned: Counter({'ExploitStrategy': 59, 'AttackStrategy': 17})
# agents_fallen: Counter({'ExploitStrategy': 48, 'AttackStrategy': 18})
# agents_respawned: Counter({'ExploitStrategy': 51, 'AttackStrategy': 15})
# agents_fallen: Counter({'ExploitStrategy': 49, 'AttackStrategy': 15})
# agents_respawned: Counter({'ExploitStrategy': 55, 'AttackStrategy': 9})
# agents_fallen: Counter({'ExploitStrategy': 67, 'AttackStrategy': 13})
# agents_respawned: Counter({'ExploitStrategy': 62, 'AttackStrategy': 18})
# agents_fallen: Counter({'ExploitStrategy': 57, 'AttackStrategy': 13})
# agents_respawned: Counter({'ExploitStrategy': 55, 'AttackStrategy': 15})
# agents_fallen: Counter({'ExploitStrategy': 73, 'AttackStrategy': 16})
# agents_respawned: Counter({'ExploitStrategy': 72, 'AttackStrategy': 17})
# agents_fallen: Counter({'ExploitStrategy': 55, 'AttackStrategy': 19})
# agents_respawned: Counter({'ExploitStrategy': 64, 'AttackStrategy': 10})
# agents_fallen: Counter({'ExploitStrategy': 69, 'AttackStrategy': 15})
# agents_respawned: Counter({'ExploitStrategy': 63, 'AttackStrategy': 21})
# agents_fallen: Counter({'ExploitStrategy': 51, 'AttackStrategy': 16})
# agents_respawned: Counter({'ExploitStrategy': 51, 'AttackStrategy': 16})
# agents_fallen: Counter({'ExploitStrategy': 45, 'AttackStrategy': 25})
# agents_respawned: Counter({'ExploitStrategy': 51, 'AttackStrategy': 19})
# agents_fallen: Counter({'ExploitStrategy': 68, 'AttackStrategy': 26})
# agents_respawned: Counter({'ExploitStrategy': 75, 'AttackStrategy': 19})
# agents_fallen: Counter({'ExploitStrategy': 63, 'AttackStrategy': 11})
# agents_respawned: Counter({'ExploitStrategy': 53, 'AttackStrategy': 21})
# agents_fallen: Counter({'ExploitStrategy': 61, 'AttackStrategy': 15})
# agents_respawned: Counter({'ExploitStrategy': 64, 'AttackStrategy': 12})
# agents_fallen: Counter({'ExploitStrategy': 79, 'AttackStrategy': 21})
# agents_respawned: Counter({'ExploitStrategy': 82, 'AttackStrategy': 18})
# agents_fallen: Counter({'ExploitStrategy': 84, 'AttackStrategy': 14})
# agents_respawned: Counter({'ExploitStrategy': 76, 'AttackStrategy': 22})
# agents_fallen: Counter({'ExploitStrategy': 58, 'AttackStrategy': 13})
# agents_respawned: Counter({'ExploitStrategy': 49, 'AttackStrategy': 22})
# agents_fallen: Counter({'ExploitStrategy': 65, 'AttackStrategy': 16})
# agents_respawned: Counter({'ExploitStrategy': 66, 'AttackStrategy': 15})
# agents_fallen: Counter({'ExploitStrategy': 65, 'AttackStrategy': 17})
# agents_respawned: Counter({'ExploitStrategy': 63, 'AttackStrategy': 19})
# agents_fallen: Counter({'ExploitStrategy': 49, 'AttackStrategy': 24})
# agents_respawned: Counter({'ExploitStrategy': 58, 'AttackStrategy': 15})
# agents_fallen: Counter({'ExploitStrategy': 58, 'AttackStrategy': 13})
# agents_respawned: Counter({'ExploitStrategy': 56, 'AttackStrategy': 15})
# agents_fallen: Counter({'ExploitStrategy': 66, 'AttackStrategy': 21})
# agents_respawned: Counter({'ExploitStrategy': 72, 'AttackStrategy': 15})
# agents_fallen: Counter({'ExploitStrategy': 54, 'AttackStrategy': 18})
# agents_respawned: Counter({'ExploitStrategy': 60, 'AttackStrategy': 12})
# agents_fallen: Counter({'ExploitStrategy': 55, 'AttackStrategy': 11})
# agents_respawned: Counter({'ExploitStrategy': 51, 'AttackStrategy': 15})
# agents_fallen: Counter({'ExploitStrategy': 76, 'AttackStrategy': 10})
# agents_respawned: Counter({'ExploitStrategy': 73, 'AttackStrategy': 13})
# agents_fallen: Counter({'ExploitStrategy': 72, 'AttackStrategy': 19})
# agents_respawned: Counter({'ExploitStrategy': 65, 'AttackStrategy': 26})
# agents_fallen: Counter({'ExploitStrategy': 55, 'AttackStrategy': 12})
# agents_respawned: Counter({'ExploitStrategy': 47, 'AttackStrategy': 20})
# agents_fallen: Counter({'ExploitStrategy': 57, 'AttackStrategy': 16})
# agents_respawned: Counter({'ExploitStrategy': 57, 'AttackStrategy': 16})
# agents_fallen: Counter({'ExploitStrategy': 54, 'AttackStrategy': 22})
# agents_respawned: Counter({'ExploitStrategy': 57, 'AttackStrategy': 19})
# agents_fallen: Counter({'ExploitStrategy': 64, 'AttackStrategy': 20})
# agents_respawned: Counter({'ExploitStrategy': 69, 'AttackStrategy': 15})
# agents_fallen: Counter({'ExploitStrategy': 60, 'AttackStrategy': 21})
# agents_respawned: Counter({'ExploitStrategy': 71, 'AttackStrategy': 10})
# agents_fallen: Counter({'ExploitStrategy': 73, 'AttackStrategy': 15})
# agents_respawned: Counter({'ExploitStrategy': 75, 'AttackStrategy': 13})
# agents_fallen: Counter({'ExploitStrategy': 74, 'AttackStrategy': 16})
# agents_respawned: Counter({'ExploitStrategy': 69, 'AttackStrategy': 21})
# agents_fallen: Counter({'ExploitStrategy': 72, 'AttackStrategy': 19})
# agents_respawned: Counter({'ExploitStrategy': 72, 'AttackStrategy': 19})
# agents_fallen: Counter({'ExploitStrategy': 67, 'AttackStrategy': 10})
# agents_respawned: Counter({'ExploitStrategy': 63, 'AttackStrategy': 14})
# agents_fallen: Counter({'ExploitStrategy': 56, 'AttackStrategy': 13})
# agents_respawned: Counter({'ExploitStrategy': 60, 'AttackStrategy': 9})
# agents_fallen: Counter({'ExploitStrategy': 51, 'AttackStrategy': 15})
# agents_respawned: Counter({'ExploitStrategy': 54, 'AttackStrategy': 12})
# agents_fallen: Counter({'ExploitStrategy': 68, 'AttackStrategy': 14})
# agents_respawned: Counter({'ExploitStrategy': 64, 'AttackStrategy': 18})
# agents_fallen: Counter({'ExploitStrategy': 53, 'AttackStrategy': 20})
# agents_respawned: Counter({'ExploitStrategy': 57, 'AttackStrategy': 16})
# agents_fallen: Counter({'ExploitStrategy': 59, 'AttackStrategy': 18})
# agents_respawned: Counter({'ExploitStrategy': 54, 'AttackStrategy': 23})
# agents_fallen: Counter({'ExploitStrategy': 60, 'AttackStrategy': 19})
# agents_respawned: Counter({'ExploitStrategy': 67, 'AttackStrategy': 12})
# agents_fallen: Counter({'ExploitStrategy': 60, 'AttackStrategy': 20})
# agents_respawned: Counter({'ExploitStrategy': 59, 'AttackStrategy': 21})
# agents_fallen: Counter({'ExploitStrategy': 64, 'AttackStrategy': 16})
# agents_respawned: Counter({'ExploitStrategy': 62, 'AttackStrategy': 18})
# agents_fallen: Counter({'ExploitStrategy': 64, 'AttackStrategy': 9})
# agents_respawned: Counter({'ExploitStrategy': 55, 'AttackStrategy': 18})
# agents_fallen: Counter({'ExploitStrategy': 60, 'AttackStrategy': 26})
# agents_respawned: Counter({'ExploitStrategy': 71, 'AttackStrategy': 15})
# agents_fallen: Counter({'ExploitStrategy': 59, 'AttackStrategy': 17})
# agents_respawned: Counter({'ExploitStrategy': 58, 'AttackStrategy': 18})
# agents_fallen: Counter({'ExploitStrategy': 67, 'AttackStrategy': 14})
# agents_respawned: Counter({'ExploitStrategy': 63, 'AttackStrategy': 18})
# agents_fallen: Counter({'ExploitStrategy': 68, 'AttackStrategy': 13})
# agents_respawned: Counter({'ExploitStrategy': 60, 'AttackStrategy': 21})
# agents_fallen: Counter({'ExploitStrategy': 64, 'AttackStrategy': 16})
# agents_respawned: Counter({'ExploitStrategy': 55, 'AttackStrategy': 25})
# agents_fallen: Counter({'ExploitStrategy': 61, 'AttackStrategy': 19})
# agents_respawned: Counter({'ExploitStrategy': 60, 'AttackStrategy': 20})
# agents_fallen: Counter({'ExploitStrategy': 56, 'AttackStrategy': 14})
# agents_respawned: Counter({'ExploitStrategy': 61, 'AttackStrategy': 9})
# agents_fallen: Counter({'ExploitStrategy': 47, 'AttackStrategy': 18})
# agents_respawned: Counter({'ExploitStrategy': 48, 'AttackStrategy': 17})
# agents_fallen: Counter({'ExploitStrategy': 66, 'AttackStrategy': 19})
# agents_respawned: Counter({'ExploitStrategy': 61, 'AttackStrategy': 24})
# agents_fallen: Counter({'ExploitStrategy': 76, 'AttackStrategy': 19})
# agents_respawned: Counter({'ExploitStrategy': 73, 'AttackStrategy': 22})
# agents_fallen: Counter({'ExploitStrategy': 65, 'AttackStrategy': 22})
# agents_respawned: Counter({'ExploitStrategy': 62, 'AttackStrategy': 25})
# agents_fallen: Counter({'ExploitStrategy': 58, 'AttackStrategy': 22})
# agents_respawned: Counter({'ExploitStrategy': 65, 'AttackStrategy': 15})
# agents_fallen: Counter({'ExploitStrategy': 58, 'AttackStrategy': 21})
# agents_respawned: Counter({'ExploitStrategy': 61, 'AttackStrategy': 18})
# agents_fallen: Counter({'ExploitStrategy': 65, 'AttackStrategy': 16})
# agents_respawned: Counter({'ExploitStrategy': 64, 'AttackStrategy': 17})
# agents_fallen: Counter({'ExploitStrategy': 78, 'AttackStrategy': 22})
# agents_respawned: Counter({'ExploitStrategy': 76, 'AttackStrategy': 24})
# agents_fallen: Counter({'ExploitStrategy': 54, 'AttackStrategy': 16})
# agents_respawned: Counter({'ExploitStrategy': 53, 'AttackStrategy': 17})
# agents_fallen: Counter({'ExploitStrategy': 54, 'AttackStrategy': 16})
# agents_respawned: Counter({'ExploitStrategy': 57, 'AttackStrategy': 13})
# agents_fallen: Counter({'ExploitStrategy': 67, 'AttackStrategy': 21})
# agents_respawned: Counter({'ExploitStrategy': 76, 'AttackStrategy': 12})
# agents_fallen: Counter({'ExploitStrategy': 64, 'AttackStrategy': 25})
# agents_respawned: Counter({'ExploitStrategy': 71, 'AttackStrategy': 18})
# agents_fallen: Counter({'ExploitStrategy': 63, 'AttackStrategy': 13})
# agents_respawned: Counter({'ExploitStrategy': 61, 'AttackStrategy': 15})
# agents_fallen: Counter({'ExploitStrategy': 55, 'AttackStrategy': 16})
# agents_respawned: Counter({'ExploitStrategy': 58, 'AttackStrategy': 13})
# agents_fallen: Counter({'ExploitStrategy': 60, 'AttackStrategy': 21})
# agents_respawned: Counter({'ExploitStrategy': 58, 'AttackStrategy': 23})
# agents_fallen: Counter({'ExploitStrategy': 72, 'AttackStrategy': 16})
# agents_respawned: Counter({'ExploitStrategy': 63, 'AttackStrategy': 25})
# agents_fallen: Counter({'ExploitStrategy': 55, 'AttackStrategy': 22})
# agents_respawned: Counter({'ExploitStrategy': 54, 'AttackStrategy': 23})
# agents_fallen: Counter({'ExploitStrategy': 64, 'AttackStrategy': 15})
# agents_respawned: Counter({'ExploitStrategy': 61, 'AttackStrategy': 18})
# agents_fallen: Counter({'ExploitStrategy': 47, 'AttackStrategy': 21})
# agents_respawned: Counter({'ExploitStrategy': 52, 'AttackStrategy': 16})
# agents_fallen: Counter({'ExploitStrategy': 74, 'AttackStrategy': 14})
# agents_respawned: Counter({'ExploitStrategy': 71, 'AttackStrategy': 17})
# agents_fallen: Counter({'ExploitStrategy': 61, 'AttackStrategy': 19})
# agents_respawned: Counter({'ExploitStrategy': 64, 'AttackStrategy': 16})
# agents_fallen: Counter({'ExploitStrategy': 58, 'AttackStrategy': 15})
# agents_respawned: Counter({'ExploitStrategy': 55, 'AttackStrategy': 18})
# agents_fallen: Counter({'ExploitStrategy': 69, 'AttackStrategy': 14})
# agents_respawned: Counter({'ExploitStrategy': 71, 'AttackStrategy': 12})
# agents_fallen: Counter({'ExploitStrategy': 71, 'AttackStrategy': 12})
# agents_respawned: Counter({'ExploitStrategy': 64, 'AttackStrategy': 19})
# agents_fallen: Counter({'ExploitStrategy': 57, 'AttackStrategy': 15})
# agents_respawned: Counter({'ExploitStrategy': 56, 'AttackStrategy': 16})
# agents_fallen: Counter({'ExploitStrategy': 56, 'AttackStrategy': 14})
# agents_respawned: Counter({'ExploitStrategy': 52, 'AttackStrategy': 18})
# agents_fallen: Counter({'ExploitStrategy': 63, 'AttackStrategy': 18})
# agents_respawned: Counter({'ExploitStrategy': 68, 'AttackStrategy': 13})
# agents_fallen: Counter({'ExploitStrategy': 73, 'AttackStrategy': 12})
# agents_respawned: Counter({'ExploitStrategy': 62, 'AttackStrategy': 23})
# agents_fallen: Counter({'ExploitStrategy': 64, 'AttackStrategy': 20})
# agents_respawned: Counter({'ExploitStrategy': 65, 'AttackStrategy': 19})
# agents_fallen: Counter({'ExploitStrategy': 62, 'AttackStrategy': 19})
# agents_respawned: Counter({'ExploitStrategy': 63, 'AttackStrategy': 18})
# agents_fallen: Counter({'ExploitStrategy': 46, 'AttackStrategy': 13})
# agents_respawned: Counter({'ExploitStrategy': 47, 'AttackStrategy': 12})
# agents_fallen: Counter({'ExploitStrategy': 64, 'AttackStrategy': 25})
# agents_respawned: Counter({'ExploitStrategy': 62, 'AttackStrategy': 27})
# agents_fallen: Counter({'ExploitStrategy': 62, 'AttackStrategy': 24})
# agents_respawned: Counter({'ExploitStrategy': 67, 'AttackStrategy': 19})
# agents_fallen: Counter({'ExploitStrategy': 67, 'AttackStrategy': 21})
# agents_respawned: Counter({'ExploitStrategy': 70, 'AttackStrategy': 18})
# agents_fallen: Counter({'ExploitStrategy': 67, 'AttackStrategy': 15})
# agents_respawned: Counter({'ExploitStrategy': 63, 'AttackStrategy': 19})
# agents_fallen: Counter({'ExploitStrategy': 52, 'AttackStrategy': 21})
# agents_respawned: Counter({'ExploitStrategy': 59, 'AttackStrategy': 14})
# agents_fallen: Counter({'ExploitStrategy': 55, 'AttackStrategy': 13})
# agents_respawned: Counter({'ExploitStrategy': 45, 'AttackStrategy': 23})
# agents_fallen: Counter({'ExploitStrategy': 68, 'AttackStrategy': 17})
# agents_respawned: Counter({'ExploitStrategy': 69, 'AttackStrategy': 16})
# agents_fallen: Counter({'ExploitStrategy': 74, 'AttackStrategy': 16})
# agents_respawned: Counter({'ExploitStrategy': 67, 'AttackStrategy': 23})
# agents_fallen: Counter({'ExploitStrategy': 67, 'AttackStrategy': 19})
# agents_respawned: Counter({'ExploitStrategy': 68, 'AttackStrategy': 18})
# agents_fallen: Counter({'ExploitStrategy': 59, 'AttackStrategy': 24})
# agents_respawned: Counter({'ExploitStrategy': 59, 'AttackStrategy': 24})
# agents_fallen: Counter({'ExploitStrategy': 66, 'AttackStrategy': 23})
# agents_respawned: Counter({'ExploitStrategy': 61, 'AttackStrategy': 28})
# agents_fallen: Counter({'ExploitStrategy': 70, 'AttackStrategy': 20})
# agents_respawned: Counter({'ExploitStrategy': 72, 'AttackStrategy': 18})
# agents_fallen: Counter({'ExploitStrategy': 59, 'AttackStrategy': 17})
# agents_respawned: Counter({'ExploitStrategy': 59, 'AttackStrategy': 17})
# agents_fallen: Counter({'ExploitStrategy': 52, 'AttackStrategy': 22})
# agents_respawned: Counter({'ExploitStrategy': 58, 'AttackStrategy': 16})
# agents_fallen: Counter({'ExploitStrategy': 70, 'AttackStrategy': 26})
# agents_respawned: Counter({'ExploitStrategy': 72, 'AttackStrategy': 24})
# agents_fallen: Counter({'ExploitStrategy': 56, 'AttackStrategy': 24})
# agents_respawned: Counter({'ExploitStrategy': 63, 'AttackStrategy': 17})
# agents_fallen: Counter({'ExploitStrategy': 60, 'AttackStrategy': 17})
# agents_respawned: Counter({'ExploitStrategy': 60, 'AttackStrategy': 17})
# agents_fallen: Counter({'ExploitStrategy': 67, 'AttackStrategy': 14})
# agents_respawned: Counter({'ExploitStrategy': 54, 'AttackStrategy': 27})
# agents_fallen: Counter({'ExploitStrategy': 70, 'AttackStrategy': 24})
# agents_respawned: Counter({'ExploitStrategy': 68, 'AttackStrategy': 26})
# agents_fallen: Counter({'ExploitStrategy': 62, 'AttackStrategy': 14})
# agents_respawned: Counter({'ExploitStrategy': 65, 'AttackStrategy': 11})
# agents_fallen: Counter({'ExploitStrategy': 63, 'AttackStrategy': 20})
# agents_respawned: Counter({'ExploitStrategy': 59, 'AttackStrategy': 24})
# agents_fallen: Counter({'ExploitStrategy': 75, 'AttackStrategy': 18})
# agents_respawned: Counter({'ExploitStrategy': 73, 'AttackStrategy': 20})
# agents_fallen: Counter({'ExploitStrategy': 58, 'AttackStrategy': 22})
# agents_respawned: Counter({'ExploitStrategy': 62, 'AttackStrategy': 18})
# agents_fallen: Counter({'ExploitStrategy': 57, 'AttackStrategy': 26})
# agents_respawned: Counter({'ExploitStrategy': 62, 'AttackStrategy': 21})
# agents_fallen: Counter({'ExploitStrategy': 73, 'AttackStrategy': 23})
# agents_respawned: Counter({'ExploitStrategy': 69, 'AttackStrategy': 27})
# agents_fallen: Counter({'ExploitStrategy': 59, 'AttackStrategy': 23})
# agents_respawned: Counter({'ExploitStrategy': 64, 'AttackStrategy': 18})
# agents_fallen: Counter({'ExploitStrategy': 59, 'AttackStrategy': 18})
# agents_respawned: Counter({'ExploitStrategy': 64, 'AttackStrategy': 13})
# agents_fallen: Counter({'ExploitStrategy': 69, 'AttackStrategy': 17})
# agents_respawned: Counter({'ExploitStrategy': 64, 'AttackStrategy': 22})
# agents_fallen: Counter({'ExploitStrategy': 76, 'AttackStrategy': 18})
# agents_respawned: Counter({'ExploitStrategy': 63, 'AttackStrategy': 31})
# agents_fallen: Counter({'ExploitStrategy': 53, 'AttackStrategy': 19})
# agents_respawned: Counter({'ExploitStrategy': 57, 'AttackStrategy': 15})
# agents_fallen: Counter({'ExploitStrategy': 71, 'AttackStrategy': 17})
# agents_respawned: Counter({'ExploitStrategy': 69, 'AttackStrategy': 19})
# agents_fallen: Counter({'ExploitStrategy': 67, 'AttackStrategy': 19})
# agents_respawned: Counter({'ExploitStrategy': 65, 'AttackStrategy': 21})
# agents_fallen: Counter({'ExploitStrategy': 62, 'AttackStrategy': 22})
# agents_respawned: Counter({'ExploitStrategy': 65, 'AttackStrategy': 19})
# agents_fallen: Counter({'ExploitStrategy': 54, 'AttackStrategy': 18})
# agents_respawned: Counter({'ExploitStrategy': 52, 'AttackStrategy': 20})
# agents_fallen: Counter({'ExploitStrategy': 71, 'AttackStrategy': 20})
# agents_respawned: Counter({'ExploitStrategy': 70, 'AttackStrategy': 21})
# agents_fallen: Counter({'ExploitStrategy': 64, 'AttackStrategy': 27})
# agents_respawned: Counter({'ExploitStrategy': 60, 'AttackStrategy': 31})
# agents_fallen: Counter({'ExploitStrategy': 63, 'AttackStrategy': 23})
# agents_respawned: Counter({'ExploitStrategy': 72, 'AttackStrategy': 14})
# agents_fallen: Counter({'ExploitStrategy': 77, 'AttackStrategy': 16})
# agents_respawned: Counter({'ExploitStrategy': 66, 'AttackStrategy': 27})
# agents_fallen: Counter({'ExploitStrategy': 54, 'AttackStrategy': 28})
# agents_respawned: Counter({'ExploitStrategy': 60, 'AttackStrategy': 22})
# agents_fallen: Counter({'ExploitStrategy': 60, 'AttackStrategy': 22})
# agents_respawned: Counter({'ExploitStrategy': 61, 'AttackStrategy': 21})
# agents_fallen: Counter({'ExploitStrategy': 65, 'AttackStrategy': 21})
# agents_respawned: Counter({'ExploitStrategy': 68, 'AttackStrategy': 18})
# agents_fallen: Counter({'ExploitStrategy': 65, 'AttackStrategy': 24})
# agents_respawned: Counter({'ExploitStrategy': 65, 'AttackStrategy': 24})
# agents_fallen: Counter({'ExploitStrategy': 57, 'AttackStrategy': 22})
# agents_respawned: Counter({'ExploitStrategy': 58, 'AttackStrategy': 21})
# agents_fallen: Counter({'ExploitStrategy': 54, 'AttackStrategy': 26})
# agents_respawned: Counter({'ExploitStrategy': 59, 'AttackStrategy': 21})
# agents_fallen: Counter({'ExploitStrategy': 73, 'AttackStrategy': 12})
# agents_respawned: Counter({'ExploitStrategy': 67, 'AttackStrategy': 18})
# agents_fallen: Counter({'ExploitStrategy': 52, 'AttackStrategy': 29})
# agents_respawned: Counter({'ExploitStrategy': 57, 'AttackStrategy': 24})
# agents_fallen: Counter({'ExploitStrategy': 64, 'AttackStrategy': 22})
# agents_respawned: Counter({'ExploitStrategy': 67, 'AttackStrategy': 19})
# agents_fallen: Counter({'ExploitStrategy': 63, 'AttackStrategy': 19})
# agents_respawned: Counter({'ExploitStrategy': 62, 'AttackStrategy': 20})
# agents_fallen: Counter({'ExploitStrategy': 57, 'AttackStrategy': 18})
# agents_respawned: Counter({'ExploitStrategy': 64, 'AttackStrategy': 11})
# agents_fallen: Counter({'ExploitStrategy': 60, 'AttackStrategy': 21})
# agents_respawned: Counter({'ExploitStrategy': 57, 'AttackStrategy': 24})
# agents_fallen: Counter({'ExploitStrategy': 62, 'AttackStrategy': 22})
# agents_respawned: Counter({'ExploitStrategy': 64, 'AttackStrategy': 20})
# agents_fallen: Counter({'ExploitStrategy': 55, 'AttackStrategy': 18})
# agents_respawned: Counter({'ExploitStrategy': 50, 'AttackStrategy': 23})
# agents_fallen: Counter({'ExploitStrategy': 73, 'AttackStrategy': 16})
# agents_respawned: Counter({'ExploitStrategy': 72, 'AttackStrategy': 17})
# agents_fallen: Counter({'ExploitStrategy': 60, 'AttackStrategy': 20})
# agents_respawned: Counter({'ExploitStrategy': 57, 'AttackStrategy': 23})
# agents_fallen: Counter({'ExploitStrategy': 59, 'AttackStrategy': 21})
# agents_respawned: Counter({'ExploitStrategy': 58, 'AttackStrategy': 22})
# agents_fallen: Counter({'ExploitStrategy': 58, 'AttackStrategy': 29})
# agents_respawned: Counter({'ExploitStrategy': 63, 'AttackStrategy': 24})
# agents_fallen: Counter({'ExploitStrategy': 63, 'AttackStrategy': 26})
# agents_respawned: Counter({'ExploitStrategy': 72, 'AttackStrategy': 17})
# agents_fallen: Counter({'ExploitStrategy': 65, 'AttackStrategy': 18})
# agents_respawned: Counter({'ExploitStrategy': 66, 'AttackStrategy': 17})
# agents_fallen: Counter({'ExploitStrategy': 64, 'AttackStrategy': 11})
# agents_respawned: Counter({'ExploitStrategy': 60, 'AttackStrategy': 15})
# agents_fallen: Counter({'ExploitStrategy': 81, 'AttackStrategy': 22})
# agents_respawned: Counter({'ExploitStrategy': 77, 'AttackStrategy': 26})
# agents_fallen: Counter({'ExploitStrategy': 49, 'AttackStrategy': 19})
# agents_respawned: Counter({'ExploitStrategy': 48, 'AttackStrategy': 20})
# agents_fallen: Counter({'ExploitStrategy': 67, 'AttackStrategy': 20})
# agents_respawned: Counter({'ExploitStrategy': 70, 'AttackStrategy': 17})
# agents_fallen: Counter({'ExploitStrategy': 60, 'AttackStrategy': 21})
# agents_respawned: Counter({'ExploitStrategy': 64, 'AttackStrategy': 17})
# agents_fallen: Counter({'ExploitStrategy': 61, 'AttackStrategy': 20})
# agents_respawned: Counter({'ExploitStrategy': 66, 'AttackStrategy': 15})
# agents_fallen: Counter({'ExploitStrategy': 65, 'AttackStrategy': 19})
# agents_respawned: Counter({'ExploitStrategy': 67, 'AttackStrategy': 17})
# agents_fallen: Counter({'ExploitStrategy': 63, 'AttackStrategy': 23})
# agents_respawned: Counter({'ExploitStrategy': 65, 'AttackStrategy': 21})
# agents_fallen: Counter({'ExploitStrategy': 57, 'AttackStrategy': 16})
# agents_respawned: Counter({'ExploitStrategy': 55, 'AttackStrategy': 18})
# agents_fallen: Counter({'ExploitStrategy': 65, 'AttackStrategy': 11})
# agents_respawned: Counter({'ExploitStrategy': 56, 'AttackStrategy': 20})
# agents_fallen: Counter({'ExploitStrategy': 60, 'AttackStrategy': 18})
# agents_respawned: Counter({'ExploitStrategy': 58, 'AttackStrategy': 20})
# agents_fallen: Counter({'ExploitStrategy': 66, 'AttackStrategy': 19})
# agents_respawned: Counter({'ExploitStrategy': 63, 'AttackStrategy': 22})
# agents_fallen: Counter({'ExploitStrategy': 57, 'AttackStrategy': 17})
# agents_respawned: Counter({'ExploitStrategy': 59, 'AttackStrategy': 15})
# agents_fallen: Counter({'ExploitStrategy': 78, 'AttackStrategy': 23})
# agents_respawned: Counter({'ExploitStrategy': 82, 'AttackStrategy': 19})
# agents_fallen: Counter({'ExploitStrategy': 60, 'AttackStrategy': 18})
# agents_respawned: Counter({'ExploitStrategy': 59, 'AttackStrategy': 19})
# agents_fallen: Counter({'ExploitStrategy': 47, 'AttackStrategy': 20})
# agents_respawned: Counter({'ExploitStrategy': 51, 'AttackStrategy': 16})
# agents_fallen: Counter({'ExploitStrategy': 51, 'AttackStrategy': 13})
# agents_respawned: Counter({'ExploitStrategy': 51, 'AttackStrategy': 13})
# agents_fallen: Counter({'ExploitStrategy': 71, 'AttackStrategy': 20})
# agents_respawned: Counter({'ExploitStrategy': 67, 'AttackStrategy': 24})
# agents_fallen: Counter({'ExploitStrategy': 66, 'AttackStrategy': 23})
# agents_respawned: Counter({'ExploitStrategy': 73, 'AttackStrategy': 16})
# agents_fallen: Counter({'ExploitStrategy': 57, 'AttackStrategy': 16})
# agents_respawned: Counter({'ExploitStrategy': 61, 'AttackStrategy': 12})
# ...
# agents_respawned: Counter({'ExploitStrategy': 56, 'AttackStrategy': 34})
# agents_fallen: Counter({'ExploitStrategy': 57, 'AttackStrategy': 26})
# agents_respawned: Counter({'ExploitStrategy': 64, 'AttackStrategy': 19})
# agents_fallen: Counter({'ExploitStrategy': 59, 'AttackStrategy': 17})
# agents_respawned: Counter({'ExploitStrategy': 58, 'AttackStrategy': 18})
# agents_fallen: Counter({'ExploitStrategy': 55, 'AttackStrategy': 20})
# agents_respawned: Counter({'ExploitStrategy': 60, 'AttackStrategy': 15})
# agents_fallen: Counter({'ExploitStrategy': 60, 'AttackStrategy': 21})
# agents_respawned: Counter({'ExploitStrategy': 64, 'AttackStrategy': 17})
# agents_fallen: Counter({'ExploitStrategy': 59, 'AttackStrategy': 18})
# agents_respawned: Counter({'ExploitStrategy': 54, 'AttackStrategy': 23})
# agents_fallen: Counter({'ExploitStrategy': 85, 'AttackStrategy': 19})
# agents_respawned: Counter({'ExploitStrategy': 81, 'AttackStrategy': 23})
# agents_fallen: Counter({'ExploitStrategy': 69, 'AttackStrategy': 30})
# agents_respawned: Counter({'ExploitStrategy': 77, 'AttackStrategy': 22})
# agents_fallen: Counter({'ExploitStrategy': 60, 'AttackStrategy': 18})
# agents_respawned: Counter({'ExploitStrategy': 54, 'AttackStrategy': 24})
# agents_fallen: Counter({'ExploitStrategy': 66, 'AttackStrategy': 26})
# agents_respawned: Counter({'ExploitStrategy': 66, 'AttackStrategy': 26})
# agents_fallen: Counter({'ExploitStrategy': 43, 'AttackStrategy': 22})
# agents_respawned: Counter({'ExploitStrategy': 52, 'AttackStrategy': 13})
# agents_fallen: Counter({'ExploitStrategy': 67, 'AttackStrategy': 21})
# agents_respawned: Counter({'ExploitStrategy': 66, 'AttackStrategy': 22})
# agents_fallen: Counter({'ExploitStrategy': 59, 'AttackStrategy': 15})
# agents_respawned: Counter({'ExploitStrategy': 63, 'AttackStrategy': 11})
# agents_fallen: Counter({'ExploitStrategy': 62, 'AttackStrategy': 24})
# agents_respawned: Counter({'ExploitStrategy': 67, 'AttackStrategy': 19})
# agents_fallen: Counter({'ExploitStrategy': 54, 'AttackStrategy': 16})
# agents_respawned: Counter({'ExploitStrategy': 53, 'AttackStrategy': 17})
# agents_fallen: Counter({'ExploitStrategy': 49, 'AttackStrategy': 23})
# agents_respawned: Counter({'ExploitStrategy': 53, 'AttackStrategy': 19})
# agents_fallen: Counter({'ExploitStrategy': 71, 'AttackStrategy': 18})
# agents_respawned: Counter({'ExploitStrategy': 67, 'AttackStrategy': 22})
# agents_fallen: Counter({'ExploitStrategy': 58, 'AttackStrategy': 22})
# agents_respawned: Counter({'ExploitStrategy': 54, 'AttackStrategy': 26})
# agents_fallen: Counter({'ExploitStrategy': 50, 'AttackStrategy': 25})
# agents_respawned: Counter({'ExploitStrategy': 59, 'AttackStrategy': 16})
# agents_fallen: Counter({'ExploitStrategy': 66, 'AttackStrategy': 21})
# agents_respawned: Counter({'ExploitStrategy': 65, 'AttackStrategy': 22})
# agents_fallen: Counter({'ExploitStrategy': 75, 'AttackStrategy': 15})
# agents_respawned: Counter({'ExploitStrategy': 70, 'AttackStrategy': 20})
# agents_fallen: Counter({'ExploitStrategy': 45, 'AttackStrategy': 13})
# agents_respawned: Counter({'ExploitStrategy': 46, 'AttackStrategy': 12})
# agents_fallen: Counter({'ExploitStrategy': 65, 'AttackStrategy': 19})
# agents_respawned: Counter({'ExploitStrategy': 65, 'AttackStrategy': 19})
# agents_fallen: Counter({'ExploitStrategy': 61, 'AttackStrategy': 20})
# agents_respawned: Counter({'ExploitStrategy': 61, 'AttackStrategy': 20})
# agents_fallen: Counter({'ExploitStrategy': 62, 'AttackStrategy': 26})
# agents_respawned: Counter({'ExploitStrategy': 68, 'AttackStrategy': 20})
# agents_fallen: Counter({'ExploitStrategy': 62, 'AttackStrategy': 15})
# agents_respawned: Counter({'ExploitStrategy': 56, 'AttackStrategy': 21})
# agents_fallen: Counter({'ExploitStrategy': 54, 'AttackStrategy': 24})
# agents_respawned: Counter({'ExploitStrategy': 59, 'AttackStrategy': 19})
# agents_fallen: Counter({'ExploitStrategy': 61, 'AttackStrategy': 22})
# agents_respawned: Counter({'ExploitStrategy': 64, 'AttackStrategy': 19})
# agents_fallen: Counter({'ExploitStrategy': 54, 'AttackStrategy': 12})
# agents_respawned: Counter({'ExploitStrategy': 48, 'AttackStrategy': 18})
# agents_fallen: Counter({'ExploitStrategy': 73, 'AttackStrategy': 25})
# agents_respawned: Counter({'ExploitStrategy': 76, 'AttackStrategy': 22})
# agents_fallen: Counter({'ExploitStrategy': 79, 'AttackStrategy': 21})
# agents_respawned: Counter({'ExploitStrategy': 79, 'AttackStrategy': 21})
# agents_fallen: Counter({'ExploitStrategy': 66, 'AttackStrategy': 23})
# agents_respawned: Counter({'ExploitStrategy': 67, 'AttackStrategy': 22})
# agents_fallen: Counter({'ExploitStrategy': 56, 'AttackStrategy': 14})
# agents_respawned: Counter({'ExploitStrategy': 60, 'AttackStrategy': 10})
# agents_fallen: Counter({'ExploitStrategy': 64, 'AttackStrategy': 19})
# agents_respawned: Counter({'ExploitStrategy': 62, 'AttackStrategy': 21})
# agents_fallen: Counter({'ExploitStrategy': 64, 'AttackStrategy': 26})
# agents_respawned: Counter({'ExploitStrategy': 69, 'AttackStrategy': 21})
# agents_fallen: Counter({'ExploitStrategy': 60, 'AttackStrategy': 17})
# agents_respawned: Counter({'ExploitStrategy': 62, 'AttackStrategy': 15})
# agents_fallen: Counter({'ExploitStrategy': 61, 'AttackStrategy': 14})
# agents_respawned: Counter({'ExploitStrategy': 61, 'AttackStrategy': 14})
# agents_fallen: Counter({'ExploitStrategy': 61, 'AttackStrategy': 15})
# agents_respawned: Counter({'ExploitStrategy': 50, 'AttackStrategy': 26})
# agents_fallen: Counter({'ExploitStrategy': 48, 'AttackStrategy': 24})
# agents_respawned: Counter({'ExploitStrategy': 59, 'AttackStrategy': 13})
# agents_fallen: Counter({'ExploitStrategy': 69, 'AttackStrategy': 21})
# agents_respawned: Counter({'ExploitStrategy': 73, 'AttackStrategy': 17})
# agents_fallen: Counter({'ExploitStrategy': 65, 'AttackStrategy': 17})
# agents_respawned: Counter({'ExploitStrategy': 61, 'AttackStrategy': 21})
# agents_fallen: Counter({'ExploitStrategy': 56, 'AttackStrategy': 16})
# agents_respawned: Counter({'ExploitStrategy': 60, 'AttackStrategy': 12})
# agents_fallen: Counter({'ExploitStrategy': 54, 'AttackStrategy': 16})
# agents_respawned: Counter({'ExploitStrategy': 58, 'AttackStrategy': 12})
# agents_fallen: Counter({'ExploitStrategy': 68, 'AttackStrategy': 12})
# agents_respawned: Counter({'ExploitStrategy': 63, 'AttackStrategy': 17})
# agents_fallen: Counter({'ExploitStrategy': 64, 'AttackStrategy': 11})
# agents_respawned: Counter({'ExploitStrategy': 57, 'AttackStrategy': 18})
# agents_fallen: Counter({'ExploitStrategy': 63, 'AttackStrategy': 23})
# agents_respawned: Counter({'ExploitStrategy': 71, 'AttackStrategy': 15})
# agents_fallen: Counter({'ExploitStrategy': 62, 'AttackStrategy': 15})
# agents_respawned: Counter({'ExploitStrategy': 62, 'AttackStrategy': 15})
# agents_fallen: Counter({'ExploitStrategy': 69, 'AttackStrategy': 14})
# agents_respawned: Counter({'ExploitStrategy': 66, 'AttackStrategy': 17})
# agents_fallen: Counter({'ExploitStrategy': 49, 'AttackStrategy': 22})
# agents_respawned: Counter({'ExploitStrategy': 56, 'AttackStrategy': 15})
# agents_fallen: Counter({'ExploitStrategy': 69, 'AttackStrategy': 14})
# agents_respawned: Counter({'ExploitStrategy': 65, 'AttackStrategy': 18})
# agents_fallen: Counter({'ExploitStrategy': 58, 'AttackStrategy': 13})
# agents_respawned: Counter({'ExploitStrategy': 49, 'AttackStrategy': 22})
# agents_fallen: Counter({'ExploitStrategy': 64, 'AttackStrategy': 23})
# agents_respawned: Counter({'ExploitStrategy': 59, 'AttackStrategy': 28})
# agents_fallen: Counter({'ExploitStrategy': 55, 'AttackStrategy': 20})
# agents_respawned: Counter({'ExploitStrategy': 57, 'AttackStrategy': 18})
# agents_fallen: Counter({'ExploitStrategy': 69, 'AttackStrategy': 12})
# agents_respawned: Counter({'ExploitStrategy': 57, 'AttackStrategy': 24})
# agents_fallen: Counter({'ExploitStrategy': 60, 'AttackStrategy': 27})
# agents_respawned: Counter({'ExploitStrategy': 68, 'AttackStrategy': 19})
# agents_fallen: Counter({'ExploitStrategy': 73, 'AttackStrategy': 25})
# agents_respawned: Counter({'ExploitStrategy': 76, 'AttackStrategy': 22})
# agents_fallen: Counter({'ExploitStrategy': 55, 'AttackStrategy': 16})
# agents_respawned: Counter({'ExploitStrategy': 55, 'AttackStrategy': 16})
# agents_fallen: Counter({'ExploitStrategy': 66, 'AttackStrategy': 17})
# agents_respawned: Counter({'ExploitStrategy': 66, 'AttackStrategy': 17})
# agents_fallen: Counter({'ExploitStrategy': 62, 'AttackStrategy': 23})
# agents_respawned: Counter({'ExploitStrategy': 59, 'AttackStrategy': 26})
# agents_fallen: Counter({'ExploitStrategy': 65, 'AttackStrategy': 17})
# agents_respawned: Counter({'ExploitStrategy': 63, 'AttackStrategy': 19})
# agents_fallen: Counter({'ExploitStrategy': 67, 'AttackStrategy': 17})
# agents_respawned: Counter({'ExploitStrategy': 64, 'AttackStrategy': 20})
# agents_fallen: Counter({'ExploitStrategy': 62, 'AttackStrategy': 16})
# agents_respawned: Counter({'ExploitStrategy': 63, 'AttackStrategy': 15})
# agents_fallen: Counter({'ExploitStrategy': 67, 'AttackStrategy': 18})
# agents_respawned: Counter({'ExploitStrategy': 70, 'AttackStrategy': 15})
# agents_fallen: Counter({'ExploitStrategy': 50, 'AttackStrategy': 18})
# agents_respawned: Counter({'ExploitStrategy': 58, 'AttackStrategy': 10})
# agents_fallen: Counter({'ExploitStrategy': 68, 'AttackStrategy': 19})
# agents_respawned: Counter({'ExploitStrategy': 67, 'AttackStrategy': 20})
# agents_fallen: Counter({'ExploitStrategy': 65, 'AttackStrategy': 13})
# agents_respawned: Counter({'ExploitStrategy': 62, 'AttackStrategy': 16})
# agents_fallen: Counter({'ExploitStrategy': 68, 'AttackStrategy': 17})
# agents_respawned: Counter({'ExploitStrategy': 64, 'AttackStrategy': 21})
# agents_fallen: Counter({'ExploitStrategy': 40, 'AttackStrategy': 18})
# agents_respawned: Counter({'ExploitStrategy': 46, 'AttackStrategy': 12})
# agents_fallen: Counter({'ExploitStrategy': 66, 'AttackStrategy': 17})
# agents_respawned: Counter({'ExploitStrategy': 71, 'AttackStrategy': 12})
# agents_fallen: Counter({'ExploitStrategy': 61, 'AttackStrategy': 14})
# agents_respawned: Counter({'ExploitStrategy': 65, 'AttackStrategy': 10})
# agents_fallen: Counter({'ExploitStrategy': 64, 'AttackStrategy': 13})
# agents_respawned: Counter({'ExploitStrategy': 55, 'AttackStrategy': 22})
# agents_fallen: Counter({'ExploitStrategy': 55, 'AttackStrategy': 18})
# agents_respawned: Counter({'ExploitStrategy': 58, 'AttackStrategy': 15})
# agents_fallen: Counter({'ExploitStrategy': 62, 'AttackStrategy': 17})
# agents_respawned: Counter({'ExploitStrategy': 65, 'AttackStrategy': 14})
# agents_fallen: Counter({'ExploitStrategy': 59, 'AttackStrategy': 12})
# agents_respawned: Counter({'ExploitStrategy': 59, 'AttackStrategy': 12})
# agents_fallen: Counter({'ExploitStrategy': 70, 'AttackStrategy': 19})
# agents_respawned: Counter({'ExploitStrategy': 71, 'AttackStrategy': 18})
# agents_fallen: Counter({'ExploitStrategy': 61, 'AttackStrategy': 14})
# agents_respawned: Counter({'ExploitStrategy': 55, 'AttackStrategy': 20})
# agents_fallen: Counter({'ExploitStrategy': 64, 'AttackStrategy': 19})
# agents_respawned: Counter({'ExploitStrategy': 64, 'AttackStrategy': 19})
# agents_fallen: Counter({'ExploitStrategy': 67, 'AttackStrategy': 20})
# agents_respawned: Counter({'ExploitStrategy': 70, 'AttackStrategy': 17})
# agents_fallen: Counter({'ExploitStrategy': 54, 'AttackStrategy': 18})
# agents_respawned: Counter({'ExploitStrategy': 56, 'AttackStrategy': 16})
# agents_fallen: Counter({'ExploitStrategy': 54, 'AttackStrategy': 16})
# agents_respawned: Counter({'ExploitStrategy': 56, 'AttackStrategy': 14})
# agents_fallen: Counter({'ExploitStrategy': 78, 'AttackStrategy': 18})
# agents_respawned: Counter({'ExploitStrategy': 79, 'AttackStrategy': 17})
# agents_fallen: Counter({'ExploitStrategy': 57, 'AttackStrategy': 21})
# agents_respawned: Counter({'ExploitStrategy': 60, 'AttackStrategy': 18})
# agents_fallen: Counter({'ExploitStrategy': 63, 'AttackStrategy': 17})
# agents_respawned: Counter({'ExploitStrategy': 67, 'AttackStrategy': 13})
# agents_fallen: Counter({'ExploitStrategy': 55, 'AttackStrategy': 17})
# agents_respawned: Counter({'ExploitStrategy': 54, 'AttackStrategy': 18})
# agents_fallen: Counter({'ExploitStrategy': 67, 'AttackStrategy': 12})
# agents_respawned: Counter({'ExploitStrategy': 65, 'AttackStrategy': 14})
# agents_fallen: Counter({'ExploitStrategy': 87, 'AttackStrategy': 13})
# agents_respawned: Counter({'ExploitStrategy': 81, 'AttackStrategy': 19})
# agents_fallen: Counter({'ExploitStrategy': 61, 'AttackStrategy': 21})
# agents_respawned: Counter({'ExploitStrategy': 61, 'AttackStrategy': 21})
# agents_fallen: Counter({'ExploitStrategy': 60, 'AttackStrategy': 11})
# agents_respawned: Counter({'ExploitStrategy': 56, 'AttackStrategy': 15})
# agents_fallen: Counter({'ExploitStrategy': 59, 'AttackStrategy': 11})
# agents_respawned: Counter({'ExploitStrategy': 50, 'AttackStrategy': 20})
# agents_fallen: Counter({'ExploitStrategy': 64, 'AttackStrategy': 19})
# agents_respawned: Counter({'ExploitStrategy': 71, 'AttackStrategy': 12})
# agents_fallen: Counter({'ExploitStrategy': 57, 'AttackStrategy': 22})
# agents_respawned: Counter({'ExploitStrategy': 57, 'AttackStrategy': 22})
# agents_fallen: Counter({'ExploitStrategy': 63, 'AttackStrategy': 21})
# agents_respawned: Counter({'ExploitStrategy': 60, 'AttackStrategy': 24})
# agents_fallen: Counter({'ExploitStrategy': 64, 'AttackStrategy': 15})
# agents_respawned: Counter({'ExploitStrategy': 60, 'AttackStrategy': 19})
# agents_fallen: Counter({'ExploitStrategy': 66, 'AttackStrategy': 21})
# agents_respawned: Counter({'ExploitStrategy': 65, 'AttackStrategy': 22})
# agents_fallen: Counter({'ExploitStrategy': 55, 'AttackStrategy': 16})
# agents_respawned: Counter({'ExploitStrategy': 48, 'AttackStrategy': 23})
# agents_fallen: Counter({'ExploitStrategy': 66, 'AttackStrategy': 15})
# agents_respawned: Counter({'ExploitStrategy': 62, 'AttackStrategy': 19})
# agents_fallen: Counter({'ExploitStrategy': 60, 'AttackStrategy': 21})
# agents_respawned: Counter({'ExploitStrategy': 55, 'AttackStrategy': 26})
# agents_fallen: Counter({'ExploitStrategy': 61, 'AttackStrategy': 24})
# agents_respawned: Counter({'ExploitStrategy': 66, 'AttackStrategy': 19})
# agents_fallen: Counter({'ExploitStrategy': 60, 'AttackStrategy': 23})
# agents_respawned: Counter({'ExploitStrategy': 64, 'AttackStrategy': 19})
# agents_fallen: Counter({'ExploitStrategy': 70, 'AttackStrategy': 27})
# agents_respawned: Counter({'ExploitStrategy': 75, 'AttackStrategy': 22})
# agents_fallen: Counter({'ExploitStrategy': 57, 'AttackStrategy': 24})
# agents_respawned: Counter({'ExploitStrategy': 61, 'AttackStrategy': 20})
# agents_fallen: Counter({'ExploitStrategy': 51, 'AttackStrategy': 17})
# agents_respawned: Counter({'ExploitStrategy': 50, 'AttackStrategy': 18})
# agents_fallen: Counter({'ExploitStrategy': 68, 'AttackStrategy': 19})
# agents_respawned: Counter({'ExploitStrategy': 66, 'AttackStrategy': 21})
# agents_fallen: Counter({'ExploitStrategy': 58, 'AttackStrategy': 18})
# agents_respawned: Counter({'ExploitStrategy': 63, 'AttackStrategy': 13})
# agents_fallen: Counter({'ExploitStrategy': 72, 'AttackStrategy': 28})
# agents_respawned: Counter({'ExploitStrategy': 74, 'AttackStrategy': 26})
# agents_fallen: Counter({'ExploitStrategy': 49, 'AttackStrategy': 15})
# agents_respawned: Counter({'ExploitStrategy': 39, 'AttackStrategy': 25})
# agents_fallen: Counter({'ExploitStrategy': 57, 'AttackStrategy': 20})
# agents_respawned: Counter({'ExploitStrategy': 55, 'AttackStrategy': 22})
# agents_fallen: Counter({'ExploitStrategy': 52, 'AttackStrategy': 20})
# agents_respawned: Counter({'ExploitStrategy': 59, 'AttackStrategy': 13})
# agents_fallen: Counter({'ExploitStrategy': 76, 'AttackStrategy': 20})
# agents_respawned: Counter({'ExploitStrategy': 85, 'AttackStrategy': 11})
# agents_fallen: Counter({'ExploitStrategy': 76, 'AttackStrategy': 18})
# agents_respawned: Counter({'ExploitStrategy': 70, 'AttackStrategy': 24})
# agents_fallen: Counter({'ExploitStrategy': 64, 'AttackStrategy': 19})
# agents_respawned: Counter({'ExploitStrategy': 64, 'AttackStrategy': 19})
# agents_fallen: Counter({'ExploitStrategy': 74, 'AttackStrategy': 20})
# agents_respawned: Counter({'ExploitStrategy': 69, 'AttackStrategy': 25})
