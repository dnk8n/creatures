# %%
from creatures.simulate import *

# %%
main(save_path="/tmp/environment.pickle")
# Out:
# 2023-03-07 09:33:20.946 ERROR:	float division by zero
# 2023-03-07 09:33:21.426 ERROR:	float division by zero
# 2023-03-07 09:33:23.133 ERROR:	float division by zero
# 2023-03-07 09:33:23.501 ERROR:	float division by zero
# 2023-03-07 09:33:23.940 ERROR:	float division by zero
# 2023-03-07 09:33:23.988 ERROR:	float division by zero
# 2023-03-07 09:33:26.342 ERROR:	float division by zero
# 2023-03-07 09:33:26.786 ERROR:	float division by zero
# 2023-03-07 09:33:27.742 ERROR:	float division by zero
# 2023-03-07 09:33:28.765 ERROR:	float division by zero
# 2023-03-07 09:33:29.181 ERROR:	float division by zero
# 2023-03-07 09:33:29.312 ERROR:	float division by zero
# 2023-03-07 09:33:29.360 ERROR:	float division by zero
# 2023-03-07 09:33:30.195 ERROR:	float division by zero
# 2023-03-07 09:33:31.835 ERROR:	float division by zero
# 2023-03-07 09:33:33.412 ERROR:	float division by zero
# 2023-03-07 09:33:35.897 ERROR:	float division by zero
# 2023-03-07 09:33:36.648 ERROR:	float division by zero
# 2023-03-07 09:33:37.363 ERROR:	float division by zero
# 2023-03-07 09:33:39.521 ERROR:	float division by zero
# 2023-03-07 09:33:39.612 ERROR:	float division by zero
# 2023-03-07 09:33:39.942 ERROR:	float division by zero
# 2023-03-07 09:33:40.388 ERROR:	float division by zero
# 2023-03-07 09:33:40.558 ERROR:	float division by zero
# 2023-03-07 09:33:41.821 ERROR:	float division by zero
# 2023-03-07 09:33:41.821 ERROR:	float division by zero
# 2023-03-07 09:33:41.957 ERROR:	float division by zero
# 2023-03-07 09:33:42.248 ERROR:	float division by zero
# 2023-03-07 09:33:43.127 ERROR:	float division by zero
# 2023-03-07 09:33:44.168 ERROR:	float division by zero
# 2023-03-07 09:33:44.261 ERROR:	float division by zero
# 2023-03-07 09:33:44.507 ERROR:	float division by zero
# 2023-03-07 09:33:44.717 ERROR:	float division by zero
# 2023-03-07 09:33:44.802 ERROR:	float division by zero
# 2023-03-07 09:33:45.337 ERROR:	float division by zero
# 2023-03-07 09:33:45.388 ERROR:	float division by zero
# 2023-03-07 09:33:46.237 ERROR:	float division by zero
# 2023-03-07 09:33:47.782 ERROR:	float division by zero
# 2023-03-07 09:33:47.873 ERROR:	float division by zero
# 2023-03-07 09:33:47.964 ERROR:	float division by zero
# 2023-03-07 09:33:48.054 ERROR:	float division by zero
# 2023-03-07 09:33:48.867 ERROR:	float division by zero
# 2023-03-07 09:33:49.262 ERROR:	float division by zero
# 2023-03-07 09:33:49.351 ERROR:	float division by zero
# 2023-03-07 09:33:49.702 ERROR:	float division by zero
# 2023-03-07 09:33:49.703 ERROR:	float division by zero
# 2023-03-07 09:33:51.457 ERROR:	float division by zero
# 2023-03-07 09:33:52.079 ERROR:	float division by zero
# 2023-03-07 09:33:52.409 ERROR:	float division by zero
# 2023-03-07 09:33:53.819 ERROR:	float division by zero
# 2023-03-07 09:33:54.947 ERROR:	float division by zero
# 2023-03-07 09:33:55.173 ERROR:	float division by zero
# 2023-03-07 09:33:55.249 ERROR:	float division by zero
# 2023-03-07 09:33:56.317 ERROR:	float division by zero
# 2023-03-07 09:33:56.388 ERROR:	float division by zero
# 2023-03-07 09:33:56.901 ERROR:	float division by zero
# 2023-03-07 09:33:58.842 ERROR:	float division by zero
# 2023-03-07 09:34:00.434 ERROR:	float division by zero
# 2023-03-07 09:34:01.878 ERROR:	float division by zero
# 2023-03-07 09:34:02.088 ERROR:	float division by zero
# 2023-03-07 09:34:03.130 ERROR:	float division by zero
# 2023-03-07 09:34:03.131 ERROR:	float division by zero
# 2023-03-07 09:34:03.540 ERROR:	float division by zero
# 2023-03-07 09:34:03.968 ERROR:	float division by zero
# 2023-03-07 09:34:04.175 ERROR:	float division by zero
# 2023-03-07 09:34:04.421 ERROR:	float division by zero
# 2023-03-07 09:34:04.421 ERROR:	float division by zero
# 2023-03-07 09:34:06.224 ERROR:	float division by zero
# 2023-03-07 09:34:06.313 ERROR:	float division by zero

# %%
env = Environment.load("/tmp/environment.pickle")

# %%
len(env.state.hp_by_strategy)
# Out:
# 1000

# %%
env.state.hp_by_strategy[0]
# Out:
# {'AttackStrategy': 14840,
#  'RetreatStrategy': 22720,
#  'RetaliateStrategy': 19250,
#  'ExploitStrategy': 22830}

# %%
env.state.hp_by_strategy[-1]
# Out:
# {'AttackStrategy': 0,
#  'RetreatStrategy': 41457,
#  'RetaliateStrategy': 6815,
#  'ExploitStrategy': 98}

# %%
env.state.xp_by_strategy[0]
# Out:
# {'AttackStrategy': 9610,
#  'RetreatStrategy': 8074,
#  'RetaliateStrategy': 9327,
#  'ExploitStrategy': 7465}

# %%
env.state.xp_by_strategy[-1]
# Out:
# {'AttackStrategy': 0,
#  'RetreatStrategy': 1040836,
#  'RetaliateStrategy': 183227,
#  'ExploitStrategy': 11}

# %%
env.state.population_by_strategy[0]
# Out:
# {'AttackStrategy': 250,
#  'RetreatStrategy': 250,
#  'RetaliateStrategy': 250,
#  'ExploitStrategy': 250}

# %%
env.state.population_by_strategy[-2]
# Out:
# {'AttackStrategy': 0,
#  'RetreatStrategy': 852,
#  'RetaliateStrategy': 147,
#  'ExploitStrategy': 1}

# %%
env.state.population_by_strategy
# Out:
# [{'AttackStrategy': 250,
#   'RetreatStrategy': 250,
#   'RetaliateStrategy': 250,
#   'ExploitStrategy': 250},
#  {'AttackStrategy': 219,
#   'RetreatStrategy': 268,
#   'RetaliateStrategy': 248,
#   'ExploitStrategy': 265},
#  {'AttackStrategy': 183,
#   'RetreatStrategy': 295,
#   'RetaliateStrategy': 241,
#   'ExploitStrategy': 281},
#  {'AttackStrategy': 156,
#   'RetreatStrategy': 319,
#   'RetaliateStrategy': 223,
#   'ExploitStrategy': 302},
#  {'AttackStrategy': 121,
#   'RetreatStrategy': 344,
#   'RetaliateStrategy': 215,
#   'ExploitStrategy': 320},
#  {'AttackStrategy': 102,
#   'RetreatStrategy': 365,
#   'RetaliateStrategy': 206,
#   'ExploitStrategy': 327},
#  {'AttackStrategy': 92,
#   'RetreatStrategy': 386,
#   'RetaliateStrategy': 186,
#   'ExploitStrategy': 336},
#  {'AttackStrategy': 76,
#   'RetreatStrategy': 391,
#   'RetaliateStrategy': 186,
#   'ExploitStrategy': 347},
#  {'AttackStrategy': 70,
#   'RetreatStrategy': 397,
#   'RetaliateStrategy': 182,
#   'ExploitStrategy': 351},
#  {'AttackStrategy': 59,
#   'RetreatStrategy': 405,
#   'RetaliateStrategy': 176,
#   'ExploitStrategy': 360},
#  {'AttackStrategy': 53,
#   'RetreatStrategy': 412,
#   'RetaliateStrategy': 176,
#   'ExploitStrategy': 359},
#  {'AttackStrategy': 50,
#   'RetreatStrategy': 419,
#   'RetaliateStrategy': 175,
#   'ExploitStrategy': 356},
#  {'AttackStrategy': 46,
#   'RetreatStrategy': 430,
#   'RetaliateStrategy': 171,
#   'ExploitStrategy': 353},
#  {'AttackStrategy': 47,
#   'RetreatStrategy': 425,
#   'RetaliateStrategy': 175,
#   'ExploitStrategy': 353},
#  {'AttackStrategy': 41,
#   'RetreatStrategy': 422,
#   'RetaliateStrategy': 179,
#   'ExploitStrategy': 358},
#  {'AttackStrategy': 38,
#   'RetreatStrategy': 423,
#   'RetaliateStrategy': 177,
#   'ExploitStrategy': 362},
#  {'AttackStrategy': 34,
#   'RetreatStrategy': 422,
#   'RetaliateStrategy': 179,
#   'ExploitStrategy': 365},
#  {'AttackStrategy': 35,
#   'RetreatStrategy': 413,
#   'RetaliateStrategy': 180,
#   'ExploitStrategy': 372},
#  {'AttackStrategy': 32,
#   'RetreatStrategy': 411,
#   'RetaliateStrategy': 179,
#   'ExploitStrategy': 378},
#  {'AttackStrategy': 31,
#   'RetreatStrategy': 410,
#   'RetaliateStrategy': 182,
#   'ExploitStrategy': 377},
#  {'AttackStrategy': 28,
#   'RetreatStrategy': 418,
#   'RetaliateStrategy': 180,
#   'ExploitStrategy': 374},
#  {'AttackStrategy': 29,
#   'RetreatStrategy': 421,
#   'RetaliateStrategy': 181,
#   'ExploitStrategy': 369},
#  {'AttackStrategy': 31,
#   'RetreatStrategy': 426,
#   'RetaliateStrategy': 177,
#   'ExploitStrategy': 366},
#  {'AttackStrategy': 25,
#   'RetreatStrategy': 435,
#   'RetaliateStrategy': 179,
#   'ExploitStrategy': 361},
#  {'AttackStrategy': 22,
#   'RetreatStrategy': 443,
#   'RetaliateStrategy': 179,
#   'ExploitStrategy': 356},
#  {'AttackStrategy': 20,
#   'RetreatStrategy': 435,
#   'RetaliateStrategy': 180,
#   'ExploitStrategy': 365},
#  {'AttackStrategy': 17,
#   'RetreatStrategy': 443,
#   'RetaliateStrategy': 185,
#   'ExploitStrategy': 355},
#  {'AttackStrategy': 18,
#   'RetreatStrategy': 435,
#   'RetaliateStrategy': 186,
#   'ExploitStrategy': 361},
#  {'AttackStrategy': 18,
#   'RetreatStrategy': 432,
#   'RetaliateStrategy': 189,
#   'ExploitStrategy': 361},
#  {'AttackStrategy': 20,
#   'RetreatStrategy': 442,
#   'RetaliateStrategy': 191,
#   'ExploitStrategy': 347},
#  {'AttackStrategy': 19,
#   'RetreatStrategy': 436,
#   'RetaliateStrategy': 192,
#   'ExploitStrategy': 353},
#  {'AttackStrategy': 19,
#   'RetreatStrategy': 441,
#   'RetaliateStrategy': 187,
#   'ExploitStrategy': 353},
#  {'AttackStrategy': 19,
#   'RetreatStrategy': 447,
#   'RetaliateStrategy': 182,
#   'ExploitStrategy': 352},
#  {'AttackStrategy': 17,
#   'RetreatStrategy': 458,
#   'RetaliateStrategy': 178,
#   'ExploitStrategy': 347},
#  {'AttackStrategy': 16,
#   'RetreatStrategy': 462,
#   'RetaliateStrategy': 179,
#   'ExploitStrategy': 343},
#  {'AttackStrategy': 15,
#   'RetreatStrategy': 475,
#   'RetaliateStrategy': 175,
#   'ExploitStrategy': 335},
#  {'AttackStrategy': 17,
#   'RetreatStrategy': 473,
#   'RetaliateStrategy': 173,
#   'ExploitStrategy': 337},
#  {'AttackStrategy': 17,
#   'RetreatStrategy': 471,
#   'RetaliateStrategy': 181,
#   'ExploitStrategy': 331},
#  {'AttackStrategy': 16,
#   'RetreatStrategy': 483,
#   'RetaliateStrategy': 174,
#   'ExploitStrategy': 327},
#  {'AttackStrategy': 16,
#   'RetreatStrategy': 485,
#   'RetaliateStrategy': 177,
#   'ExploitStrategy': 322},
#  {'AttackStrategy': 15,
#   'RetreatStrategy': 479,
#   'RetaliateStrategy': 179,
#   'ExploitStrategy': 327},
#  {'AttackStrategy': 15,
#   'RetreatStrategy': 476,
#   'RetaliateStrategy': 185,
#   'ExploitStrategy': 324},
#  {'AttackStrategy': 18,
#   'RetreatStrategy': 483,
#   'RetaliateStrategy': 187,
#   'ExploitStrategy': 312},
#  {'AttackStrategy': 18,
#   'RetreatStrategy': 486,
#   'RetaliateStrategy': 184,
#   'ExploitStrategy': 312},
#  {'AttackStrategy': 18,
#   'RetreatStrategy': 488,
#   'RetaliateStrategy': 181,
#   'ExploitStrategy': 313},
#  {'AttackStrategy': 17,
#   'RetreatStrategy': 487,
#   'RetaliateStrategy': 185,
#   'ExploitStrategy': 311},
#  {'AttackStrategy': 17,
#   'RetreatStrategy': 477,
#   'RetaliateStrategy': 192,
#   'ExploitStrategy': 314},
#  {'AttackStrategy': 16,
#   'RetreatStrategy': 480,
#   'RetaliateStrategy': 195,
#   'ExploitStrategy': 309},
#  {'AttackStrategy': 13,
#   'RetreatStrategy': 487,
#   'RetaliateStrategy': 195,
#   'ExploitStrategy': 305},
#  {'AttackStrategy': 13,
#   'RetreatStrategy': 489,
#   'RetaliateStrategy': 199,
#   'ExploitStrategy': 299},
#  {'AttackStrategy': 14,
#   'RetreatStrategy': 491,
#   'RetaliateStrategy': 200,
#   'ExploitStrategy': 295},
#  {'AttackStrategy': 11,
#   'RetreatStrategy': 492,
#   'RetaliateStrategy': 198,
#   'ExploitStrategy': 299},
#  {'AttackStrategy': 12,
#   'RetreatStrategy': 493,
#   'RetaliateStrategy': 197,
#   'ExploitStrategy': 298},
#  {'AttackStrategy': 10,
#   'RetreatStrategy': 493,
#   'RetaliateStrategy': 194,
#   'ExploitStrategy': 303},
#  {'AttackStrategy': 9,
#   'RetreatStrategy': 494,
#   'RetaliateStrategy': 199,
#   'ExploitStrategy': 298},
#  {'AttackStrategy': 11,
#   'RetreatStrategy': 496,
#   'RetaliateStrategy': 193,
#   'ExploitStrategy': 300},
#  {'AttackStrategy': 10,
#   'RetreatStrategy': 502,
#   'RetaliateStrategy': 196,
#   'ExploitStrategy': 292},
#  {'AttackStrategy': 8,
#   'RetreatStrategy': 504,
#   'RetaliateStrategy': 199,
#   'ExploitStrategy': 289},
#  {'AttackStrategy': 9,
#   'RetreatStrategy': 508,
#   'RetaliateStrategy': 199,
#   'ExploitStrategy': 284},
#  {'AttackStrategy': 10,
#   'RetreatStrategy': 509,
#   'RetaliateStrategy': 199,
#   'ExploitStrategy': 282},
#  {'AttackStrategy': 10,
#   'RetreatStrategy': 511,
#   'RetaliateStrategy': 204,
#   'ExploitStrategy': 275},
#  {'AttackStrategy': 11,
#   'RetreatStrategy': 515,
#   'RetaliateStrategy': 200,
#   'ExploitStrategy': 274},
#  {'AttackStrategy': 11,
#   'RetreatStrategy': 513,
#   'RetaliateStrategy': 203,
#   'ExploitStrategy': 273},
#  {'AttackStrategy': 11,
#   'RetreatStrategy': 513,
#   'RetaliateStrategy': 205,
#   'ExploitStrategy': 271},
#  {'AttackStrategy': 10,
#   'RetreatStrategy': 513,
#   'RetaliateStrategy': 203,
#   'ExploitStrategy': 274},
#  {'AttackStrategy': 9,
#   'RetreatStrategy': 522,
#   'RetaliateStrategy': 201,
#   'ExploitStrategy': 268},
#  {'AttackStrategy': 8,
#   'RetreatStrategy': 519,
#   'RetaliateStrategy': 206,
#   'ExploitStrategy': 267},
#  {'AttackStrategy': 6,
#   'RetreatStrategy': 533,
#   'RetaliateStrategy': 205,
#   'ExploitStrategy': 256},
#  {'AttackStrategy': 5,
#   'RetreatStrategy': 537,
#   'RetaliateStrategy': 198,
#   'ExploitStrategy': 260},
#  {'AttackStrategy': 5,
#   'RetreatStrategy': 541,
#   'RetaliateStrategy': 196,
#   'ExploitStrategy': 258},
#  {'AttackStrategy': 7,
#   'RetreatStrategy': 550,
#   'RetaliateStrategy': 190,
#   'ExploitStrategy': 253},
#  {'AttackStrategy': 6,
#   'RetreatStrategy': 550,
#   'RetaliateStrategy': 193,
#   'ExploitStrategy': 251},
#  {'AttackStrategy': 6,
#   'RetreatStrategy': 547,
#   'RetaliateStrategy': 195,
#   'ExploitStrategy': 252},
#  {'AttackStrategy': 6,
#   'RetreatStrategy': 553,
#   'RetaliateStrategy': 198,
#   'ExploitStrategy': 243},
#  {'AttackStrategy': 8,
#   'RetreatStrategy': 556,
#   'RetaliateStrategy': 197,
#   'ExploitStrategy': 239},
#  {'AttackStrategy': 9,
#   'RetreatStrategy': 559,
#   'RetaliateStrategy': 198,
#   'ExploitStrategy': 234},
#  {'AttackStrategy': 9,
#   'RetreatStrategy': 556,
#   'RetaliateStrategy': 205,
#   'ExploitStrategy': 230},
#  {'AttackStrategy': 10,
#   'RetreatStrategy': 557,
#   'RetaliateStrategy': 208,
#   'ExploitStrategy': 225},
#  {'AttackStrategy': 10,
#   'RetreatStrategy': 555,
#   'RetaliateStrategy': 208,
#   'ExploitStrategy': 227},
#  {'AttackStrategy': 10,
#   'RetreatStrategy': 550,
#   'RetaliateStrategy': 214,
#   'ExploitStrategy': 226},
#  {'AttackStrategy': 9,
#   'RetreatStrategy': 562,
#   'RetaliateStrategy': 214,
#   'ExploitStrategy': 215},
#  {'AttackStrategy': 9,
#   'RetreatStrategy': 562,
#   'RetaliateStrategy': 212,
#   'ExploitStrategy': 217},
#  {'AttackStrategy': 9,
#   'RetreatStrategy': 559,
#   'RetaliateStrategy': 216,
#   'ExploitStrategy': 216},
#  {'AttackStrategy': 8,
#   'RetreatStrategy': 560,
#   'RetaliateStrategy': 216,
#   'ExploitStrategy': 216},
#  {'AttackStrategy': 10,
#   'RetreatStrategy': 564,
#   'RetaliateStrategy': 215,
#   'ExploitStrategy': 211},
#  {'AttackStrategy': 9,
#   'RetreatStrategy': 567,
#   'RetaliateStrategy': 218,
#   'ExploitStrategy': 206},
#  {'AttackStrategy': 8,
#   'RetreatStrategy': 569,
#   'RetaliateStrategy': 223,
#   'ExploitStrategy': 200},
#  {'AttackStrategy': 8,
#   'RetreatStrategy': 576,
#   'RetaliateStrategy': 219,
#   'ExploitStrategy': 197},
#  {'AttackStrategy': 7,
#   'RetreatStrategy': 575,
#   'RetaliateStrategy': 222,
#   'ExploitStrategy': 196},
#  {'AttackStrategy': 7,
#   'RetreatStrategy': 577,
#   'RetaliateStrategy': 224,
#   'ExploitStrategy': 192},
#  {'AttackStrategy': 6,
#   'RetreatStrategy': 585,
#   'RetaliateStrategy': 219,
#   'ExploitStrategy': 190},
#  {'AttackStrategy': 7,
#   'RetreatStrategy': 585,
#   'RetaliateStrategy': 220,
#   'ExploitStrategy': 188},
#  {'AttackStrategy': 6,
#   'RetreatStrategy': 588,
#   'RetaliateStrategy': 223,
#   'ExploitStrategy': 183},
#  {'AttackStrategy': 6,
#   'RetreatStrategy': 601,
#   'RetaliateStrategy': 219,
#   'ExploitStrategy': 174},
#  {'AttackStrategy': 6,
#   'RetreatStrategy': 605,
#   'RetaliateStrategy': 216,
#   'ExploitStrategy': 173},
#  {'AttackStrategy': 6,
#   'RetreatStrategy': 608,
#   'RetaliateStrategy': 216,
#   'ExploitStrategy': 170},
#  {'AttackStrategy': 6,
#   'RetreatStrategy': 610,
#   'RetaliateStrategy': 211,
#   'ExploitStrategy': 173},
#  {'AttackStrategy': 5,
#   'RetreatStrategy': 617,
#   'RetaliateStrategy': 211,
#   'ExploitStrategy': 167},
#  {'AttackStrategy': 3,
#   'RetreatStrategy': 621,
#   'RetaliateStrategy': 209,
#   'ExploitStrategy': 167},
#  {'AttackStrategy': 3,
#   'RetreatStrategy': 621,
#   'RetaliateStrategy': 208,
#   'ExploitStrategy': 168},
#  {'AttackStrategy': 4,
#   'RetreatStrategy': 625,
#   'RetaliateStrategy': 206,
#   'ExploitStrategy': 165},
#  {'AttackStrategy': 3,
#   'RetreatStrategy': 629,
#   'RetaliateStrategy': 204,
#   'ExploitStrategy': 164},
#  {'AttackStrategy': 3,
#   'RetreatStrategy': 635,
#   'RetaliateStrategy': 203,
#   'ExploitStrategy': 159},
#  {'AttackStrategy': 4,
#   'RetreatStrategy': 644,
#   'RetaliateStrategy': 201,
#   'ExploitStrategy': 151},
#  {'AttackStrategy': 4,
#   'RetreatStrategy': 653,
#   'RetaliateStrategy': 195,
#   'ExploitStrategy': 148},
#  {'AttackStrategy': 3,
#   'RetreatStrategy': 658,
#   'RetaliateStrategy': 196,
#   'ExploitStrategy': 143},
#  {'AttackStrategy': 3,
#   'RetreatStrategy': 664,
#   'RetaliateStrategy': 197,
#   'ExploitStrategy': 136},
#  {'AttackStrategy': 2,
#   'RetreatStrategy': 670,
#   'RetaliateStrategy': 197,
#   'ExploitStrategy': 131},
#  {'AttackStrategy': 3,
#   'RetreatStrategy': 676,
#   'RetaliateStrategy': 201,
#   'ExploitStrategy': 120},
#  {'AttackStrategy': 4,
#   'RetreatStrategy': 680,
#   'RetaliateStrategy': 199,
#   'ExploitStrategy': 117},
#  {'AttackStrategy': 4,
#   'RetreatStrategy': 681,
#   'RetaliateStrategy': 201,
#   'ExploitStrategy': 114},
#  {'AttackStrategy': 5,
#   'RetreatStrategy': 687,
#   'RetaliateStrategy': 199,
#   'ExploitStrategy': 109},
#  {'AttackStrategy': 5,
#   'RetreatStrategy': 693,
#   'RetaliateStrategy': 198,
#   'ExploitStrategy': 104},
#  {'AttackStrategy': 4,
#   'RetreatStrategy': 694,
#   'RetaliateStrategy': 200,
#   'ExploitStrategy': 102},
#  {'AttackStrategy': 4,
#   'RetreatStrategy': 694,
#   'RetaliateStrategy': 202,
#   'ExploitStrategy': 100},
#  {'AttackStrategy': 4,
#   'RetreatStrategy': 695,
#   'RetaliateStrategy': 201,
#   'ExploitStrategy': 100},
#  {'AttackStrategy': 4,
#   'RetreatStrategy': 690,
#   'RetaliateStrategy': 206,
#   'ExploitStrategy': 100},
#  {'AttackStrategy': 3,
#   'RetreatStrategy': 691,
#   'RetaliateStrategy': 211,
#   'ExploitStrategy': 95},
#  {'AttackStrategy': 5,
#   'RetreatStrategy': 693,
#   'RetaliateStrategy': 213,
#   'ExploitStrategy': 89},
#  {'AttackStrategy': 5,
#   'RetreatStrategy': 699,
#   'RetaliateStrategy': 210,
#   'ExploitStrategy': 86},
#  {'AttackStrategy': 5,
#   'RetreatStrategy': 700,
#   'RetaliateStrategy': 210,
#   'ExploitStrategy': 85},
#  {'AttackStrategy': 4,
#   'RetreatStrategy': 704,
#   'RetaliateStrategy': 214,
#   'ExploitStrategy': 78},
#  {'AttackStrategy': 4,
#   'RetreatStrategy': 713,
#   'RetaliateStrategy': 213,
#   'ExploitStrategy': 70},
#  {'AttackStrategy': 3,
#   'RetreatStrategy': 719,
#   'RetaliateStrategy': 212,
#   'ExploitStrategy': 66},
#  {'AttackStrategy': 3,
#   'RetreatStrategy': 722,
#   'RetaliateStrategy': 207,
#   'ExploitStrategy': 68},
#  {'AttackStrategy': 3,
#   'RetreatStrategy': 729,
#   'RetaliateStrategy': 203,
#   'ExploitStrategy': 65},
#  {'AttackStrategy': 4,
#   'RetreatStrategy': 728,
#   'RetaliateStrategy': 203,
#   'ExploitStrategy': 65},
#  {'AttackStrategy': 4,
#   'RetreatStrategy': 729,
#   'RetaliateStrategy': 204,
#   'ExploitStrategy': 63},
#  {'AttackStrategy': 3,
#   'RetreatStrategy': 728,
#   'RetaliateStrategy': 207,
#   'ExploitStrategy': 62},
#  {'AttackStrategy': 2,
#   'RetreatStrategy': 731,
#   'RetaliateStrategy': 208,
#   'ExploitStrategy': 59},
#  {'AttackStrategy': 2,
#   'RetreatStrategy': 736,
#   'RetaliateStrategy': 206,
#   'ExploitStrategy': 56},
#  {'AttackStrategy': 3,
#   'RetreatStrategy': 732,
#   'RetaliateStrategy': 209,
#   'ExploitStrategy': 56},
#  {'AttackStrategy': 3,
#   'RetreatStrategy': 738,
#   'RetaliateStrategy': 206,
#   'ExploitStrategy': 53},
#  {'AttackStrategy': 3,
#   'RetreatStrategy': 736,
#   'RetaliateStrategy': 212,
#   'ExploitStrategy': 49},
#  {'AttackStrategy': 3,
#   'RetreatStrategy': 739,
#   'RetaliateStrategy': 212,
#   'ExploitStrategy': 46},
#  {'AttackStrategy': 3,
#   'RetreatStrategy': 741,
#   'RetaliateStrategy': 213,
#   'ExploitStrategy': 43},
#  {'AttackStrategy': 2,
#   'RetreatStrategy': 739,
#   'RetaliateStrategy': 218,
#   'ExploitStrategy': 41},
#  {'AttackStrategy': 3,
#   'RetreatStrategy': 736,
#   'RetaliateStrategy': 222,
#   'ExploitStrategy': 39},
#  {'AttackStrategy': 3,
#   'RetreatStrategy': 738,
#   'RetaliateStrategy': 220,
#   'ExploitStrategy': 39},
#  {'AttackStrategy': 2,
#   'RetreatStrategy': 742,
#   'RetaliateStrategy': 218,
#   'ExploitStrategy': 38},
#  {'AttackStrategy': 2,
#   'RetreatStrategy': 742,
#   'RetaliateStrategy': 219,
#   'ExploitStrategy': 37},
#  {'AttackStrategy': 2,
#   'RetreatStrategy': 749,
#   'RetaliateStrategy': 218,
#   'ExploitStrategy': 31},
#  {'AttackStrategy': 3,
#   'RetreatStrategy': 749,
#   'RetaliateStrategy': 219,
#   'ExploitStrategy': 29},
#  {'AttackStrategy': 3,
#   'RetreatStrategy': 749,
#   'RetaliateStrategy': 220,
#   'ExploitStrategy': 28},
#  {'AttackStrategy': 3,
#   'RetreatStrategy': 749,
#   'RetaliateStrategy': 221,
#   'ExploitStrategy': 27},
#  {'AttackStrategy': 4,
#   'RetreatStrategy': 745,
#   'RetaliateStrategy': 226,
#   'ExploitStrategy': 25},
#  {'AttackStrategy': 4,
#   'RetreatStrategy': 748,
#   'RetaliateStrategy': 223,
#   'ExploitStrategy': 25},
#  {'AttackStrategy': 2,
#   'RetreatStrategy': 749,
#   'RetaliateStrategy': 223,
#   'ExploitStrategy': 26},
#  {'AttackStrategy': 1,
#   'RetreatStrategy': 753,
#   'RetaliateStrategy': 221,
#   'ExploitStrategy': 25},
#  {'AttackStrategy': 1,
#   'RetreatStrategy': 758,
#   'RetaliateStrategy': 217,
#   'ExploitStrategy': 24},
#  {'AttackStrategy': 1,
#   'RetreatStrategy': 762,
#   'RetaliateStrategy': 216,
#   'ExploitStrategy': 21},
#  {'AttackStrategy': 1,
#   'RetreatStrategy': 769,
#   'RetaliateStrategy': 213,
#   'ExploitStrategy': 17},
#  {'AttackStrategy': 2,
#   'RetreatStrategy': 772,
#   'RetaliateStrategy': 210,
#   'ExploitStrategy': 16},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 775,
#   'RetaliateStrategy': 210,
#   'ExploitStrategy': 15},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 776,
#   'RetaliateStrategy': 210,
#   'ExploitStrategy': 14},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 777,
#   'RetaliateStrategy': 209,
#   'ExploitStrategy': 14},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 778,
#   'RetaliateStrategy': 208,
#   'ExploitStrategy': 14},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 780,
#   'RetaliateStrategy': 206,
#   'ExploitStrategy': 14},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 785,
#   'RetaliateStrategy': 202,
#   'ExploitStrategy': 13},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 786,
#   'RetaliateStrategy': 201,
#   'ExploitStrategy': 13},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 788,
#   'RetaliateStrategy': 203,
#   'ExploitStrategy': 9},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 786,
#   'RetaliateStrategy': 205,
#   'ExploitStrategy': 9},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 789,
#   'RetaliateStrategy': 202,
#   'ExploitStrategy': 9},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 788,
#   'RetaliateStrategy': 203,
#   'ExploitStrategy': 9},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 789,
#   'RetaliateStrategy': 202,
#   'ExploitStrategy': 9},
#  {'AttackStrategy': 1,
#   'RetreatStrategy': 786,
#   'RetaliateStrategy': 204,
#   'ExploitStrategy': 9},
#  {'AttackStrategy': 1,
#   'RetreatStrategy': 787,
#   'RetaliateStrategy': 202,
#   'ExploitStrategy': 10},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 794,
#   'RetaliateStrategy': 198,
#   'ExploitStrategy': 8},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 792,
#   'RetaliateStrategy': 200,
#   'ExploitStrategy': 8},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 794,
#   'RetaliateStrategy': 199,
#   'ExploitStrategy': 7},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 794,
#   'RetaliateStrategy': 199,
#   'ExploitStrategy': 7},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 794,
#   'RetaliateStrategy': 199,
#   'ExploitStrategy': 7},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 796,
#   'RetaliateStrategy': 198,
#   'ExploitStrategy': 6},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 794,
#   'RetaliateStrategy': 200,
#   'ExploitStrategy': 6},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 795,
#   'RetaliateStrategy': 199,
#   'ExploitStrategy': 6},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 797,
#   'RetaliateStrategy': 197,
#   'ExploitStrategy': 6},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 798,
#   'RetaliateStrategy': 196,
#   'ExploitStrategy': 6},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 797,
#   'RetaliateStrategy': 197,
#   'ExploitStrategy': 6},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 798,
#   'RetaliateStrategy': 197,
#   'ExploitStrategy': 5},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 798,
#   'RetaliateStrategy': 197,
#   'ExploitStrategy': 5},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 798,
#   'RetaliateStrategy': 197,
#   'ExploitStrategy': 5},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 796,
#   'RetaliateStrategy': 199,
#   'ExploitStrategy': 5},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 793,
#   'RetaliateStrategy': 202,
#   'ExploitStrategy': 5},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 792,
#   'RetaliateStrategy': 203,
#   'ExploitStrategy': 5},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 791,
#   'RetaliateStrategy': 204,
#   'ExploitStrategy': 5},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 791,
#   'RetaliateStrategy': 205,
#   'ExploitStrategy': 4},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 791,
#   'RetaliateStrategy': 205,
#   'ExploitStrategy': 4},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 789,
#   'RetaliateStrategy': 207,
#   'ExploitStrategy': 4},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 788,
#   'RetaliateStrategy': 208,
#   'ExploitStrategy': 4},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 787,
#   'RetaliateStrategy': 209,
#   'ExploitStrategy': 4},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 784,
#   'RetaliateStrategy': 213,
#   'ExploitStrategy': 3},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 785,
#   'RetaliateStrategy': 212,
#   'ExploitStrategy': 3},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 786,
#   'RetaliateStrategy': 211,
#   'ExploitStrategy': 3},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 785,
#   'RetaliateStrategy': 213,
#   'ExploitStrategy': 2},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 784,
#   'RetaliateStrategy': 214,
#   'ExploitStrategy': 2},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 785,
#   'RetaliateStrategy': 213,
#   'ExploitStrategy': 2},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 784,
#   'RetaliateStrategy': 215,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 784,
#   'RetaliateStrategy': 215,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 785,
#   'RetaliateStrategy': 215,
#   'ExploitStrategy': 0},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 785,
#   'RetaliateStrategy': 215,
#   'ExploitStrategy': 0},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 786,
#   'RetaliateStrategy': 214,
#   'ExploitStrategy': 0},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 785,
#   'RetaliateStrategy': 215,
#   'ExploitStrategy': 0},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 785,
#   'RetaliateStrategy': 215,
#   'ExploitStrategy': 0},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 785,
#   'RetaliateStrategy': 215,
#   'ExploitStrategy': 0},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 784,
#   'RetaliateStrategy': 216,
#   'ExploitStrategy': 0},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 782,
#   'RetaliateStrategy': 218,
#   'ExploitStrategy': 0},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 781,
#   'RetaliateStrategy': 218,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 781,
#   'RetaliateStrategy': 218,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 779,
#   'RetaliateStrategy': 220,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 781,
#   'RetaliateStrategy': 218,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 781,
#   'RetaliateStrategy': 218,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 782,
#   'RetaliateStrategy': 217,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 784,
#   'RetaliateStrategy': 215,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 784,
#   'RetaliateStrategy': 215,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 786,
#   'RetaliateStrategy': 213,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 787,
#   'RetaliateStrategy': 211,
#   'ExploitStrategy': 2},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 785,
#   'RetaliateStrategy': 213,
#   'ExploitStrategy': 2},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 785,
#   'RetaliateStrategy': 213,
#   'ExploitStrategy': 2},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 790,
#   'RetaliateStrategy': 208,
#   'ExploitStrategy': 2},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 791,
#   'RetaliateStrategy': 207,
#   'ExploitStrategy': 2},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 793,
#   'RetaliateStrategy': 205,
#   'ExploitStrategy': 2},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 797,
#   'RetaliateStrategy': 201,
#   'ExploitStrategy': 2},
#  {'AttackStrategy': 1,
#   'RetreatStrategy': 799,
#   'RetaliateStrategy': 198,
#   'ExploitStrategy': 2},
#  {'AttackStrategy': 1,
#   'RetreatStrategy': 798,
#   'RetaliateStrategy': 199,
#   'ExploitStrategy': 2},
#  {'AttackStrategy': 1,
#   'RetreatStrategy': 799,
#   'RetaliateStrategy': 198,
#   'ExploitStrategy': 2},
#  {'AttackStrategy': 1,
#   'RetreatStrategy': 799,
#   'RetaliateStrategy': 198,
#   'ExploitStrategy': 2},
#  {'AttackStrategy': 1,
#   'RetreatStrategy': 801,
#   'RetaliateStrategy': 196,
#   'ExploitStrategy': 2},
#  {'AttackStrategy': 1,
#   'RetreatStrategy': 801,
#   'RetaliateStrategy': 196,
#   'ExploitStrategy': 2},
#  {'AttackStrategy': 1,
#   'RetreatStrategy': 803,
#   'RetaliateStrategy': 194,
#   'ExploitStrategy': 2},
#  {'AttackStrategy': 1,
#   'RetreatStrategy': 802,
#   'RetaliateStrategy': 195,
#   'ExploitStrategy': 2},
#  {'AttackStrategy': 1,
#   'RetreatStrategy': 801,
#   'RetaliateStrategy': 196,
#   'ExploitStrategy': 2},
#  {'AttackStrategy': 2,
#   'RetreatStrategy': 800,
#   'RetaliateStrategy': 196,
#   'ExploitStrategy': 2},
#  {'AttackStrategy': 2,
#   'RetreatStrategy': 803,
#   'RetaliateStrategy': 193,
#   'ExploitStrategy': 2},
#  {'AttackStrategy': 1,
#   'RetreatStrategy': 800,
#   'RetaliateStrategy': 197,
#   'ExploitStrategy': 2},
#  {'AttackStrategy': 1,
#   'RetreatStrategy': 803,
#   'RetaliateStrategy': 194,
#   'ExploitStrategy': 2},
#  {'AttackStrategy': 1,
#   'RetreatStrategy': 805,
#   'RetaliateStrategy': 192,
#   'ExploitStrategy': 2},
#  {'AttackStrategy': 2,
#   'RetreatStrategy': 807,
#   'RetaliateStrategy': 189,
#   'ExploitStrategy': 2},
#  {'AttackStrategy': 2,
#   'RetreatStrategy': 806,
#   'RetaliateStrategy': 191,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 2,
#   'RetreatStrategy': 808,
#   'RetaliateStrategy': 189,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 2,
#   'RetreatStrategy': 805,
#   'RetaliateStrategy': 192,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 2,
#   'RetreatStrategy': 804,
#   'RetaliateStrategy': 193,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 2,
#   'RetreatStrategy': 806,
#   'RetaliateStrategy': 191,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 2,
#   'RetreatStrategy': 807,
#   'RetaliateStrategy': 190,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 2,
#   'RetreatStrategy': 805,
#   'RetaliateStrategy': 192,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 2,
#   'RetreatStrategy': 803,
#   'RetaliateStrategy': 194,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 2,
#   'RetreatStrategy': 802,
#   'RetaliateStrategy': 195,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 2,
#   'RetreatStrategy': 805,
#   'RetaliateStrategy': 193,
#   'ExploitStrategy': 0},
#  {'AttackStrategy': 1,
#   'RetreatStrategy': 806,
#   'RetaliateStrategy': 193,
#   'ExploitStrategy': 0},
#  {'AttackStrategy': 1,
#   'RetreatStrategy': 805,
#   'RetaliateStrategy': 194,
#   'ExploitStrategy': 0},
#  {'AttackStrategy': 1,
#   'RetreatStrategy': 805,
#   'RetaliateStrategy': 194,
#   'ExploitStrategy': 0},
#  {'AttackStrategy': 1,
#   'RetreatStrategy': 804,
#   'RetaliateStrategy': 195,
#   'ExploitStrategy': 0},
#  {'AttackStrategy': 1,
#   'RetreatStrategy': 802,
#   'RetaliateStrategy': 197,
#   'ExploitStrategy': 0},
#  {'AttackStrategy': 1,
#   'RetreatStrategy': 800,
#   'RetaliateStrategy': 199,
#   'ExploitStrategy': 0},
#  {'AttackStrategy': 1,
#   'RetreatStrategy': 801,
#   'RetaliateStrategy': 198,
#   'ExploitStrategy': 0},
#  {'AttackStrategy': 1,
#   'RetreatStrategy': 800,
#   'RetaliateStrategy': 199,
#   'ExploitStrategy': 0},
#  {'AttackStrategy': 1,
#   'RetreatStrategy': 799,
#   'RetaliateStrategy': 200,
#   'ExploitStrategy': 0},
#  {'AttackStrategy': 1,
#   'RetreatStrategy': 798,
#   'RetaliateStrategy': 201,
#   'ExploitStrategy': 0},
#  {'AttackStrategy': 1,
#   'RetreatStrategy': 797,
#   'RetaliateStrategy': 202,
#   'ExploitStrategy': 0},
#  {'AttackStrategy': 1,
#   'RetreatStrategy': 796,
#   'RetaliateStrategy': 203,
#   'ExploitStrategy': 0},
#  {'AttackStrategy': 1,
#   'RetreatStrategy': 794,
#   'RetaliateStrategy': 205,
#   'ExploitStrategy': 0},
#  {'AttackStrategy': 1,
#   'RetreatStrategy': 791,
#   'RetaliateStrategy': 208,
#   'ExploitStrategy': 0},
#  {'AttackStrategy': 1,
#   'RetreatStrategy': 790,
#   'RetaliateStrategy': 209,
#   'ExploitStrategy': 0},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 792,
#   'RetaliateStrategy': 208,
#   'ExploitStrategy': 0},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 790,
#   'RetaliateStrategy': 210,
#   'ExploitStrategy': 0},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 790,
#   'RetaliateStrategy': 210,
#   'ExploitStrategy': 0},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 788,
#   'RetaliateStrategy': 211,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 793,
#   'RetaliateStrategy': 206,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 794,
#   'RetaliateStrategy': 205,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 794,
#   'RetaliateStrategy': 205,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 792,
#   'RetaliateStrategy': 207,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 792,
#   'RetaliateStrategy': 207,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 788,
#   'RetaliateStrategy': 211,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 786,
#   'RetaliateStrategy': 213,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 1,
#   'RetreatStrategy': 782,
#   'RetaliateStrategy': 216,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 1,
#   'RetreatStrategy': 782,
#   'RetaliateStrategy': 216,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 1,
#   'RetreatStrategy': 776,
#   'RetaliateStrategy': 222,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 1,
#   'RetreatStrategy': 774,
#   'RetaliateStrategy': 224,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 1,
#   'RetreatStrategy': 776,
#   'RetaliateStrategy': 222,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 1,
#   'RetreatStrategy': 774,
#   'RetaliateStrategy': 224,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 1,
#   'RetreatStrategy': 776,
#   'RetaliateStrategy': 222,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 1,
#   'RetreatStrategy': 777,
#   'RetaliateStrategy': 221,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 1,
#   'RetreatStrategy': 779,
#   'RetaliateStrategy': 219,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 1,
#   'RetreatStrategy': 779,
#   'RetaliateStrategy': 219,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 1,
#   'RetreatStrategy': 778,
#   'RetaliateStrategy': 220,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 779,
#   'RetaliateStrategy': 220,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 775,
#   'RetaliateStrategy': 224,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 778,
#   'RetaliateStrategy': 221,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 774,
#   'RetaliateStrategy': 225,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 777,
#   'RetaliateStrategy': 222,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 774,
#   'RetaliateStrategy': 225,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 775,
#   'RetaliateStrategy': 223,
#   'ExploitStrategy': 2},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 778,
#   'RetaliateStrategy': 220,
#   'ExploitStrategy': 2},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 778,
#   'RetaliateStrategy': 220,
#   'ExploitStrategy': 2},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 779,
#   'RetaliateStrategy': 219,
#   'ExploitStrategy': 2},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 779,
#   'RetaliateStrategy': 219,
#   'ExploitStrategy': 2},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 779,
#   'RetaliateStrategy': 219,
#   'ExploitStrategy': 2},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 777,
#   'RetaliateStrategy': 221,
#   'ExploitStrategy': 2},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 777,
#   'RetaliateStrategy': 221,
#   'ExploitStrategy': 2},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 777,
#   'RetaliateStrategy': 221,
#   'ExploitStrategy': 2},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 778,
#   'RetaliateStrategy': 220,
#   'ExploitStrategy': 2},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 777,
#   'RetaliateStrategy': 221,
#   'ExploitStrategy': 2},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 778,
#   'RetaliateStrategy': 220,
#   'ExploitStrategy': 2},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 779,
#   'RetaliateStrategy': 219,
#   'ExploitStrategy': 2},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 780,
#   'RetaliateStrategy': 218,
#   'ExploitStrategy': 2},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 779,
#   'RetaliateStrategy': 219,
#   'ExploitStrategy': 2},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 782,
#   'RetaliateStrategy': 216,
#   'ExploitStrategy': 2},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 780,
#   'RetaliateStrategy': 218,
#   'ExploitStrategy': 2},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 780,
#   'RetaliateStrategy': 218,
#   'ExploitStrategy': 2},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 777,
#   'RetaliateStrategy': 221,
#   'ExploitStrategy': 2},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 779,
#   'RetaliateStrategy': 219,
#   'ExploitStrategy': 2},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 777,
#   'RetaliateStrategy': 221,
#   'ExploitStrategy': 2},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 774,
#   'RetaliateStrategy': 224,
#   'ExploitStrategy': 2},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 773,
#   'RetaliateStrategy': 225,
#   'ExploitStrategy': 2},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 773,
#   'RetaliateStrategy': 225,
#   'ExploitStrategy': 2},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 774,
#   'RetaliateStrategy': 224,
#   'ExploitStrategy': 2},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 775,
#   'RetaliateStrategy': 223,
#   'ExploitStrategy': 2},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 774,
#   'RetaliateStrategy': 224,
#   'ExploitStrategy': 2},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 775,
#   'RetaliateStrategy': 223,
#   'ExploitStrategy': 2},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 772,
#   'RetaliateStrategy': 225,
#   'ExploitStrategy': 3},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 773,
#   'RetaliateStrategy': 224,
#   'ExploitStrategy': 3},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 771,
#   'RetaliateStrategy': 226,
#   'ExploitStrategy': 3},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 771,
#   'RetaliateStrategy': 226,
#   'ExploitStrategy': 3},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 770,
#   'RetaliateStrategy': 227,
#   'ExploitStrategy': 3},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 767,
#   'RetaliateStrategy': 231,
#   'ExploitStrategy': 2},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 769,
#   'RetaliateStrategy': 229,
#   'ExploitStrategy': 2},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 770,
#   'RetaliateStrategy': 227,
#   'ExploitStrategy': 3},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 770,
#   'RetaliateStrategy': 227,
#   'ExploitStrategy': 3},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 768,
#   'RetaliateStrategy': 229,
#   'ExploitStrategy': 3},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 771,
#   'RetaliateStrategy': 226,
#   'ExploitStrategy': 3},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 769,
#   'RetaliateStrategy': 228,
#   'ExploitStrategy': 3},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 770,
#   'RetaliateStrategy': 227,
#   'ExploitStrategy': 3},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 771,
#   'RetaliateStrategy': 226,
#   'ExploitStrategy': 3},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 770,
#   'RetaliateStrategy': 227,
#   'ExploitStrategy': 3},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 772,
#   'RetaliateStrategy': 225,
#   'ExploitStrategy': 3},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 774,
#   'RetaliateStrategy': 223,
#   'ExploitStrategy': 3},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 775,
#   'RetaliateStrategy': 223,
#   'ExploitStrategy': 2},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 778,
#   'RetaliateStrategy': 220,
#   'ExploitStrategy': 2},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 775,
#   'RetaliateStrategy': 223,
#   'ExploitStrategy': 2},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 774,
#   'RetaliateStrategy': 224,
#   'ExploitStrategy': 2},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 775,
#   'RetaliateStrategy': 223,
#   'ExploitStrategy': 2},
#  {'AttackStrategy': 1,
#   'RetreatStrategy': 777,
#   'RetaliateStrategy': 220,
#   'ExploitStrategy': 2},
#  {'AttackStrategy': 1,
#   'RetreatStrategy': 778,
#   'RetaliateStrategy': 219,
#   'ExploitStrategy': 2},
#  {'AttackStrategy': 2,
#   'RetreatStrategy': 776,
#   'RetaliateStrategy': 220,
#   'ExploitStrategy': 2},
#  {'AttackStrategy': 2,
#   'RetreatStrategy': 772,
#   'RetaliateStrategy': 224,
#   'ExploitStrategy': 2},
#  {'AttackStrategy': 3,
#   'RetreatStrategy': 771,
#   'RetaliateStrategy': 224,
#   'ExploitStrategy': 2},
#  {'AttackStrategy': 3,
#   'RetreatStrategy': 770,
#   'RetaliateStrategy': 225,
#   'ExploitStrategy': 2},
#  {'AttackStrategy': 4,
#   'RetreatStrategy': 772,
#   'RetaliateStrategy': 221,
#   'ExploitStrategy': 3},
#  {'AttackStrategy': 4,
#   'RetreatStrategy': 772,
#   'RetaliateStrategy': 221,
#   'ExploitStrategy': 3},
#  {'AttackStrategy': 4,
#   'RetreatStrategy': 771,
#   'RetaliateStrategy': 223,
#   'ExploitStrategy': 2},
#  {'AttackStrategy': 3,
#   'RetreatStrategy': 771,
#   'RetaliateStrategy': 224,
#   'ExploitStrategy': 2},
#  {'AttackStrategy': 3,
#   'RetreatStrategy': 771,
#   'RetaliateStrategy': 224,
#   'ExploitStrategy': 2},
#  {'AttackStrategy': 3,
#   'RetreatStrategy': 771,
#   'RetaliateStrategy': 224,
#   'ExploitStrategy': 2},
#  {'AttackStrategy': 3,
#   'RetreatStrategy': 771,
#   'RetaliateStrategy': 224,
#   'ExploitStrategy': 2},
#  {'AttackStrategy': 1,
#   'RetreatStrategy': 773,
#   'RetaliateStrategy': 224,
#   'ExploitStrategy': 2},
#  {'AttackStrategy': 1,
#   'RetreatStrategy': 772,
#   'RetaliateStrategy': 224,
#   'ExploitStrategy': 3},
#  {'AttackStrategy': 1,
#   'RetreatStrategy': 772,
#   'RetaliateStrategy': 224,
#   'ExploitStrategy': 3},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 773,
#   'RetaliateStrategy': 224,
#   'ExploitStrategy': 3},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 774,
#   'RetaliateStrategy': 223,
#   'ExploitStrategy': 3},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 774,
#   'RetaliateStrategy': 223,
#   'ExploitStrategy': 3},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 776,
#   'RetaliateStrategy': 221,
#   'ExploitStrategy': 3},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 774,
#   'RetaliateStrategy': 223,
#   'ExploitStrategy': 3},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 772,
#   'RetaliateStrategy': 225,
#   'ExploitStrategy': 3},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 772,
#   'RetaliateStrategy': 225,
#   'ExploitStrategy': 3},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 772,
#   'RetaliateStrategy': 225,
#   'ExploitStrategy': 3},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 773,
#   'RetaliateStrategy': 224,
#   'ExploitStrategy': 3},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 772,
#   'RetaliateStrategy': 225,
#   'ExploitStrategy': 3},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 776,
#   'RetaliateStrategy': 222,
#   'ExploitStrategy': 2},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 777,
#   'RetaliateStrategy': 222,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 775,
#   'RetaliateStrategy': 224,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 773,
#   'RetaliateStrategy': 226,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 776,
#   'RetaliateStrategy': 223,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 775,
#   'RetaliateStrategy': 224,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 778,
#   'RetaliateStrategy': 221,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 781,
#   'RetaliateStrategy': 218,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 781,
#   'RetaliateStrategy': 217,
#   'ExploitStrategy': 2},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 783,
#   'RetaliateStrategy': 216,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 787,
#   'RetaliateStrategy': 212,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 786,
#   'RetaliateStrategy': 213,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 788,
#   'RetaliateStrategy': 211,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 788,
#   'RetaliateStrategy': 211,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 787,
#   'RetaliateStrategy': 212,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 788,
#   'RetaliateStrategy': 211,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 786,
#   'RetaliateStrategy': 213,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 785,
#   'RetaliateStrategy': 214,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 790,
#   'RetaliateStrategy': 209,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 789,
#   'RetaliateStrategy': 210,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 791,
#   'RetaliateStrategy': 208,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 790,
#   'RetaliateStrategy': 209,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 791,
#   'RetaliateStrategy': 208,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 788,
#   'RetaliateStrategy': 211,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 789,
#   'RetaliateStrategy': 210,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 790,
#   'RetaliateStrategy': 209,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 788,
#   'RetaliateStrategy': 211,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 789,
#   'RetaliateStrategy': 210,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 789,
#   'RetaliateStrategy': 210,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 787,
#   'RetaliateStrategy': 212,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 787,
#   'RetaliateStrategy': 212,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 1,
#   'RetreatStrategy': 788,
#   'RetaliateStrategy': 210,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 1,
#   'RetreatStrategy': 790,
#   'RetaliateStrategy': 208,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 1,
#   'RetreatStrategy': 792,
#   'RetaliateStrategy': 206,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 1,
#   'RetreatStrategy': 792,
#   'RetaliateStrategy': 206,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 1,
#   'RetreatStrategy': 793,
#   'RetaliateStrategy': 205,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 1,
#   'RetreatStrategy': 793,
#   'RetaliateStrategy': 205,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 1,
#   'RetreatStrategy': 793,
#   'RetaliateStrategy': 205,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 1,
#   'RetreatStrategy': 791,
#   'RetaliateStrategy': 207,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 1,
#   'RetreatStrategy': 792,
#   'RetaliateStrategy': 206,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 1,
#   'RetreatStrategy': 790,
#   'RetaliateStrategy': 208,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 1,
#   'RetreatStrategy': 794,
#   'RetaliateStrategy': 204,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 1,
#   'RetreatStrategy': 796,
#   'RetaliateStrategy': 202,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 1,
#   'RetreatStrategy': 796,
#   'RetaliateStrategy': 202,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 794,
#   'RetaliateStrategy': 205,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 794,
#   'RetaliateStrategy': 205,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 794,
#   'RetaliateStrategy': 205,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 793,
#   'RetaliateStrategy': 206,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 795,
#   'RetaliateStrategy': 204,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 794,
#   'RetaliateStrategy': 205,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 792,
#   'RetaliateStrategy': 208,
#   'ExploitStrategy': 0},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 792,
#   'RetaliateStrategy': 208,
#   'ExploitStrategy': 0},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 794,
#   'RetaliateStrategy': 206,
#   'ExploitStrategy': 0},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 797,
#   'RetaliateStrategy': 203,
#   'ExploitStrategy': 0},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 798,
#   'RetaliateStrategy': 202,
#   'ExploitStrategy': 0},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 800,
#   'RetaliateStrategy': 200,
#   'ExploitStrategy': 0},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 800,
#   'RetaliateStrategy': 200,
#   'ExploitStrategy': 0},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 798,
#   'RetaliateStrategy': 202,
#   'ExploitStrategy': 0},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 797,
#   'RetaliateStrategy': 203,
#   'ExploitStrategy': 0},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 795,
#   'RetaliateStrategy': 205,
#   'ExploitStrategy': 0},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 795,
#   'RetaliateStrategy': 205,
#   'ExploitStrategy': 0},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 793,
#   'RetaliateStrategy': 207,
#   'ExploitStrategy': 0},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 792,
#   'RetaliateStrategy': 208,
#   'ExploitStrategy': 0},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 790,
#   'RetaliateStrategy': 210,
#   'ExploitStrategy': 0},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 791,
#   'RetaliateStrategy': 209,
#   'ExploitStrategy': 0},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 792,
#   'RetaliateStrategy': 208,
#   'ExploitStrategy': 0},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 791,
#   'RetaliateStrategy': 209,
#   'ExploitStrategy': 0},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 793,
#   'RetaliateStrategy': 207,
#   'ExploitStrategy': 0},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 788,
#   'RetaliateStrategy': 212,
#   'ExploitStrategy': 0},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 788,
#   'RetaliateStrategy': 212,
#   'ExploitStrategy': 0},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 789,
#   'RetaliateStrategy': 211,
#   'ExploitStrategy': 0},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 785,
#   'RetaliateStrategy': 215,
#   'ExploitStrategy': 0},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 785,
#   'RetaliateStrategy': 215,
#   'ExploitStrategy': 0},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 784,
#   'RetaliateStrategy': 216,
#   'ExploitStrategy': 0},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 784,
#   'RetaliateStrategy': 216,
#   'ExploitStrategy': 0},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 781,
#   'RetaliateStrategy': 219,
#   'ExploitStrategy': 0},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 780,
#   'RetaliateStrategy': 220,
#   'ExploitStrategy': 0},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 779,
#   'RetaliateStrategy': 221,
#   'ExploitStrategy': 0},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 782,
#   'RetaliateStrategy': 218,
#   'ExploitStrategy': 0},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 782,
#   'RetaliateStrategy': 218,
#   'ExploitStrategy': 0},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 782,
#   'RetaliateStrategy': 218,
#   'ExploitStrategy': 0},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 782,
#   'RetaliateStrategy': 218,
#   'ExploitStrategy': 0},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 784,
#   'RetaliateStrategy': 216,
#   'ExploitStrategy': 0},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 785,
#   'RetaliateStrategy': 215,
#   'ExploitStrategy': 0},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 789,
#   'RetaliateStrategy': 211,
#   'ExploitStrategy': 0},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 790,
#   'RetaliateStrategy': 210,
#   'ExploitStrategy': 0},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 790,
#   'RetaliateStrategy': 210,
#   'ExploitStrategy': 0},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 791,
#   'RetaliateStrategy': 209,
#   'ExploitStrategy': 0},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 789,
#   'RetaliateStrategy': 211,
#   'ExploitStrategy': 0},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 784,
#   'RetaliateStrategy': 215,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 785,
#   'RetaliateStrategy': 214,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 785,
#   'RetaliateStrategy': 214,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 784,
#   'RetaliateStrategy': 215,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 783,
#   'RetaliateStrategy': 216,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 782,
#   'RetaliateStrategy': 217,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 785,
#   'RetaliateStrategy': 214,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 789,
#   'RetaliateStrategy': 210,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 790,
#   'RetaliateStrategy': 209,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 791,
#   'RetaliateStrategy': 208,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 792,
#   'RetaliateStrategy': 207,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 792,
#   'RetaliateStrategy': 207,
#   'ExploitStrategy': 1},
# ...
#   'RetreatStrategy': 841,
#   'RetaliateStrategy': 155,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 3,
#   'RetreatStrategy': 842,
#   'RetaliateStrategy': 154,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 3,
#   'RetreatStrategy': 843,
#   'RetaliateStrategy': 153,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 3,
#   'RetreatStrategy': 844,
#   'RetaliateStrategy': 152,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 3,
#   'RetreatStrategy': 844,
#   'RetaliateStrategy': 152,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 3,
#   'RetreatStrategy': 846,
#   'RetaliateStrategy': 150,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 3,
#   'RetreatStrategy': 847,
#   'RetaliateStrategy': 149,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 2,
#   'RetreatStrategy': 846,
#   'RetaliateStrategy': 151,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 2,
#   'RetreatStrategy': 847,
#   'RetaliateStrategy': 150,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 2,
#   'RetreatStrategy': 849,
#   'RetaliateStrategy': 148,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 2,
#   'RetreatStrategy': 846,
#   'RetaliateStrategy': 151,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 2,
#   'RetreatStrategy': 844,
#   'RetaliateStrategy': 153,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 1,
#   'RetreatStrategy': 847,
#   'RetaliateStrategy': 151,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 1,
#   'RetreatStrategy': 847,
#   'RetaliateStrategy': 151,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 1,
#   'RetreatStrategy': 846,
#   'RetaliateStrategy': 152,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 1,
#   'RetreatStrategy': 846,
#   'RetaliateStrategy': 152,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 1,
#   'RetreatStrategy': 846,
#   'RetaliateStrategy': 152,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 1,
#   'RetreatStrategy': 846,
#   'RetaliateStrategy': 152,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 1,
#   'RetreatStrategy': 845,
#   'RetaliateStrategy': 153,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 845,
#   'RetaliateStrategy': 154,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 846,
#   'RetaliateStrategy': 153,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 1,
#   'RetreatStrategy': 844,
#   'RetaliateStrategy': 154,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 1,
#   'RetreatStrategy': 849,
#   'RetaliateStrategy': 149,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 1,
#   'RetreatStrategy': 850,
#   'RetaliateStrategy': 148,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 1,
#   'RetreatStrategy': 850,
#   'RetaliateStrategy': 148,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 1,
#   'RetreatStrategy': 850,
#   'RetaliateStrategy': 148,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 1,
#   'RetreatStrategy': 852,
#   'RetaliateStrategy': 145,
#   'ExploitStrategy': 2},
#  {'AttackStrategy': 1,
#   'RetreatStrategy': 853,
#   'RetaliateStrategy': 144,
#   'ExploitStrategy': 2},
#  {'AttackStrategy': 1,
#   'RetreatStrategy': 854,
#   'RetaliateStrategy': 143,
#   'ExploitStrategy': 2},
#  {'AttackStrategy': 1,
#   'RetreatStrategy': 851,
#   'RetaliateStrategy': 146,
#   'ExploitStrategy': 2},
#  {'AttackStrategy': 1,
#   'RetreatStrategy': 851,
#   'RetaliateStrategy': 146,
#   'ExploitStrategy': 2},
#  {'AttackStrategy': 1,
#   'RetreatStrategy': 851,
#   'RetaliateStrategy': 147,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 1,
#   'RetreatStrategy': 853,
#   'RetaliateStrategy': 145,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 1,
#   'RetreatStrategy': 855,
#   'RetaliateStrategy': 143,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 856,
#   'RetaliateStrategy': 143,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 856,
#   'RetaliateStrategy': 143,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 856,
#   'RetaliateStrategy': 143,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 856,
#   'RetaliateStrategy': 143,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 858,
#   'RetaliateStrategy': 141,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 856,
#   'RetaliateStrategy': 143,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 858,
#   'RetaliateStrategy': 141,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 858,
#   'RetaliateStrategy': 141,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 858,
#   'RetaliateStrategy': 141,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 858,
#   'RetaliateStrategy': 141,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 859,
#   'RetaliateStrategy': 140,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 856,
#   'RetaliateStrategy': 143,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 858,
#   'RetaliateStrategy': 141,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 858,
#   'RetaliateStrategy': 141,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 859,
#   'RetaliateStrategy': 140,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 859,
#   'RetaliateStrategy': 140,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 858,
#   'RetaliateStrategy': 141,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 860,
#   'RetaliateStrategy': 139,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 857,
#   'RetaliateStrategy': 142,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 858,
#   'RetaliateStrategy': 141,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 858,
#   'RetaliateStrategy': 141,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 857,
#   'RetaliateStrategy': 142,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 856,
#   'RetaliateStrategy': 143,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 858,
#   'RetaliateStrategy': 141,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 854,
#   'RetaliateStrategy': 145,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 853,
#   'RetaliateStrategy': 146,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 853,
#   'RetaliateStrategy': 146,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 854,
#   'RetaliateStrategy': 145,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 857,
#   'RetaliateStrategy': 142,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 856,
#   'RetaliateStrategy': 143,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 856,
#   'RetaliateStrategy': 143,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 857,
#   'RetaliateStrategy': 142,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 857,
#   'RetaliateStrategy': 142,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 855,
#   'RetaliateStrategy': 144,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 854,
#   'RetaliateStrategy': 145,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 853,
#   'RetaliateStrategy': 146,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 853,
#   'RetaliateStrategy': 146,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 853,
#   'RetaliateStrategy': 146,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 852,
#   'RetaliateStrategy': 147,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 852,
#   'RetaliateStrategy': 148,
#   'ExploitStrategy': 0},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 854,
#   'RetaliateStrategy': 146,
#   'ExploitStrategy': 0},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 850,
#   'RetaliateStrategy': 150,
#   'ExploitStrategy': 0},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 851,
#   'RetaliateStrategy': 149,
#   'ExploitStrategy': 0},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 851,
#   'RetaliateStrategy': 149,
#   'ExploitStrategy': 0},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 850,
#   'RetaliateStrategy': 150,
#   'ExploitStrategy': 0},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 850,
#   'RetaliateStrategy': 150,
#   'ExploitStrategy': 0},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 849,
#   'RetaliateStrategy': 151,
#   'ExploitStrategy': 0},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 849,
#   'RetaliateStrategy': 151,
#   'ExploitStrategy': 0},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 850,
#   'RetaliateStrategy': 150,
#   'ExploitStrategy': 0},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 850,
#   'RetaliateStrategy': 150,
#   'ExploitStrategy': 0},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 851,
#   'RetaliateStrategy': 149,
#   'ExploitStrategy': 0},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 850,
#   'RetaliateStrategy': 150,
#   'ExploitStrategy': 0},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 850,
#   'RetaliateStrategy': 150,
#   'ExploitStrategy': 0},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 851,
#   'RetaliateStrategy': 149,
#   'ExploitStrategy': 0},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 852,
#   'RetaliateStrategy': 148,
#   'ExploitStrategy': 0},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 852,
#   'RetaliateStrategy': 148,
#   'ExploitStrategy': 0},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 849,
#   'RetaliateStrategy': 151,
#   'ExploitStrategy': 0},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 851,
#   'RetaliateStrategy': 149,
#   'ExploitStrategy': 0},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 853,
#   'RetaliateStrategy': 147,
#   'ExploitStrategy': 0},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 852,
#   'RetaliateStrategy': 148,
#   'ExploitStrategy': 0},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 853,
#   'RetaliateStrategy': 147,
#   'ExploitStrategy': 0},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 852,
#   'RetaliateStrategy': 148,
#   'ExploitStrategy': 0},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 852,
#   'RetaliateStrategy': 148,
#   'ExploitStrategy': 0},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 852,
#   'RetaliateStrategy': 148,
#   'ExploitStrategy': 0},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 851,
#   'RetaliateStrategy': 149,
#   'ExploitStrategy': 0},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 852,
#   'RetaliateStrategy': 148,
#   'ExploitStrategy': 0},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 851,
#   'RetaliateStrategy': 149,
#   'ExploitStrategy': 0},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 853,
#   'RetaliateStrategy': 147,
#   'ExploitStrategy': 0},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 851,
#   'RetaliateStrategy': 149,
#   'ExploitStrategy': 0},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 851,
#   'RetaliateStrategy': 148,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 850,
#   'RetaliateStrategy': 149,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 850,
#   'RetaliateStrategy': 149,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 849,
#   'RetaliateStrategy': 150,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 847,
#   'RetaliateStrategy': 152,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 848,
#   'RetaliateStrategy': 151,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 848,
#   'RetaliateStrategy': 151,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 848,
#   'RetaliateStrategy': 151,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 850,
#   'RetaliateStrategy': 149,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 851,
#   'RetaliateStrategy': 148,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 850,
#   'RetaliateStrategy': 148,
#   'ExploitStrategy': 2},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 850,
#   'RetaliateStrategy': 148,
#   'ExploitStrategy': 2},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 851,
#   'RetaliateStrategy': 147,
#   'ExploitStrategy': 2},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 851,
#   'RetaliateStrategy': 147,
#   'ExploitStrategy': 2},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 851,
#   'RetaliateStrategy': 147,
#   'ExploitStrategy': 2},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 852,
#   'RetaliateStrategy': 146,
#   'ExploitStrategy': 2},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 855,
#   'RetaliateStrategy': 143,
#   'ExploitStrategy': 2},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 857,
#   'RetaliateStrategy': 141,
#   'ExploitStrategy': 2},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 855,
#   'RetaliateStrategy': 143,
#   'ExploitStrategy': 2},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 856,
#   'RetaliateStrategy': 142,
#   'ExploitStrategy': 2},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 854,
#   'RetaliateStrategy': 144,
#   'ExploitStrategy': 2},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 853,
#   'RetaliateStrategy': 145,
#   'ExploitStrategy': 2},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 851,
#   'RetaliateStrategy': 147,
#   'ExploitStrategy': 2},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 851,
#   'RetaliateStrategy': 147,
#   'ExploitStrategy': 2},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 852,
#   'RetaliateStrategy': 146,
#   'ExploitStrategy': 2},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 853,
#   'RetaliateStrategy': 145,
#   'ExploitStrategy': 2},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 852,
#   'RetaliateStrategy': 146,
#   'ExploitStrategy': 2},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 855,
#   'RetaliateStrategy': 143,
#   'ExploitStrategy': 2},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 855,
#   'RetaliateStrategy': 143,
#   'ExploitStrategy': 2},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 855,
#   'RetaliateStrategy': 143,
#   'ExploitStrategy': 2},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 855,
#   'RetaliateStrategy': 143,
#   'ExploitStrategy': 2},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 854,
#   'RetaliateStrategy': 144,
#   'ExploitStrategy': 2},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 855,
#   'RetaliateStrategy': 143,
#   'ExploitStrategy': 2},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 856,
#   'RetaliateStrategy': 142,
#   'ExploitStrategy': 2},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 856,
#   'RetaliateStrategy': 142,
#   'ExploitStrategy': 2},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 856,
#   'RetaliateStrategy': 142,
#   'ExploitStrategy': 2},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 856,
#   'RetaliateStrategy': 142,
#   'ExploitStrategy': 2},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 856,
#   'RetaliateStrategy': 142,
#   'ExploitStrategy': 2},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 858,
#   'RetaliateStrategy': 140,
#   'ExploitStrategy': 2},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 857,
#   'RetaliateStrategy': 141,
#   'ExploitStrategy': 2},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 857,
#   'RetaliateStrategy': 141,
#   'ExploitStrategy': 2},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 858,
#   'RetaliateStrategy': 140,
#   'ExploitStrategy': 2},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 858,
#   'RetaliateStrategy': 140,
#   'ExploitStrategy': 2},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 860,
#   'RetaliateStrategy': 139,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 858,
#   'RetaliateStrategy': 141,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 858,
#   'RetaliateStrategy': 141,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 858,
#   'RetaliateStrategy': 141,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 858,
#   'RetaliateStrategy': 141,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 859,
#   'RetaliateStrategy': 141,
#   'ExploitStrategy': 0},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 856,
#   'RetaliateStrategy': 144,
#   'ExploitStrategy': 0},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 857,
#   'RetaliateStrategy': 143,
#   'ExploitStrategy': 0},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 855,
#   'RetaliateStrategy': 145,
#   'ExploitStrategy': 0},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 852,
#   'RetaliateStrategy': 147,
#   'ExploitStrategy': 1},
#  {'AttackStrategy': 0,
#   'RetreatStrategy': 853,
#   'RetaliateStrategy': 146,
#   'ExploitStrategy': 1}]

# %%
# %matplotlib inline
import matplotlib.pyplot as plt


def plot_strategy_counts(data):
    """Plot strategy counts for each iteration."""

    # Extract strategy names
    strategy_names = list(data[0].keys())

    # Create a color map for each strategy
    colors = ["blue", "orange", "green", "red"]
    color_map = dict(zip(strategy_names, colors))

    # Create lists to store data for each strategy
    strategy_counts = {}
    for strategy in strategy_names:
        strategy_counts[strategy] = []

    # Extract counts for each strategy for each iteration
    for iteration in data:
        for strategy in strategy_names:
            strategy_counts[strategy].append(iteration[strategy])

    # Create plot
    plt.figure(figsize=(10, 6))
    for strategy in strategy_names:
        plt.plot(
            range(len(data)),
            strategy_counts[strategy],
            label=strategy,
            color=color_map[strategy],
        )
    plt.xlabel("Iterations")
    plt.ylabel("Strategy Count")
    plt.legend()
    plt.show()

# %%
plot_strategy_counts(env.state.population_by_strategy)

# %%
plot_strategy_counts(env.state.hp_by_strategy)

# %%
plot_strategy_counts(env.state.xp_by_strategy)

# %%
len(env.state.agents_fallen[0])
# Out:
# 89

# %%
from collections import Counter

# %%
for i in range(env.num_rounds):
    print(
        "agents_fallen: "
        + str(Counter([a.strategy.__name__ for a in env.state.agents_fallen[i]]))
    )
    print(
        "agents_respawned: "
        + str(Counter([a.strategy.__name__ for a in env.state.agents_respawned[i]]))
    )
# Out:
# agents_fallen: Counter({'AttackStrategy': 57, 'RetaliateStrategy': 29, 'ExploitStrategy': 2, 'RetreatStrategy': 1})
# agents_respawned: Counter({'RetaliateStrategy': 27, 'AttackStrategy': 26, 'RetreatStrategy': 19, 'ExploitStrategy': 17})
# agents_fallen: Counter({'AttackStrategy': 50, 'RetaliateStrategy': 24, 'RetreatStrategy': 3, 'ExploitStrategy': 1})
# agents_respawned: Counter({'RetreatStrategy': 30, 'ExploitStrategy': 17, 'RetaliateStrategy': 17, 'AttackStrategy': 14})
# agents_fallen: Counter({'AttackStrategy': 36, 'RetaliateStrategy': 29, 'ExploitStrategy': 5, 'RetreatStrategy': 4})
# agents_respawned: Counter({'RetreatStrategy': 28, 'ExploitStrategy': 26, 'RetaliateStrategy': 11, 'AttackStrategy': 9})
# agents_fallen: Counter({'AttackStrategy': 47, 'RetaliateStrategy': 26, 'RetreatStrategy': 8, 'ExploitStrategy': 5})
# agents_respawned: Counter({'RetreatStrategy': 33, 'ExploitStrategy': 23, 'RetaliateStrategy': 18, 'AttackStrategy': 12})
# agents_fallen: Counter({'AttackStrategy': 25, 'RetaliateStrategy': 20, 'ExploitStrategy': 12, 'RetreatStrategy': 2})
# agents_respawned: Counter({'RetreatStrategy': 23, 'ExploitStrategy': 19, 'RetaliateStrategy': 11, 'AttackStrategy': 6})
# agents_fallen: Counter({'RetaliateStrategy': 26, 'AttackStrategy': 12, 'RetreatStrategy': 8, 'ExploitStrategy': 5})
# agents_respawned: Counter({'RetreatStrategy': 29, 'ExploitStrategy': 14, 'RetaliateStrategy': 6, 'AttackStrategy': 2})
# agents_fallen: Counter({'AttackStrategy': 17, 'RetaliateStrategy': 13, 'ExploitStrategy': 11, 'RetreatStrategy': 11})
# agents_respawned: Counter({'ExploitStrategy': 22, 'RetreatStrategy': 16, 'RetaliateStrategy': 13, 'AttackStrategy': 1})
# agents_fallen: Counter({'RetreatStrategy': 15, 'RetaliateStrategy': 13, 'ExploitStrategy': 11, 'AttackStrategy': 9})
# agents_respawned: Counter({'RetreatStrategy': 21, 'ExploitStrategy': 15, 'RetaliateStrategy': 9, 'AttackStrategy': 3})
# agents_fallen: Counter({'RetreatStrategy': 16, 'RetaliateStrategy': 15, 'AttackStrategy': 13, 'ExploitStrategy': 10})
# agents_respawned: Counter({'RetreatStrategy': 24, 'ExploitStrategy': 19, 'RetaliateStrategy': 9, 'AttackStrategy': 2})
# agents_fallen: Counter({'RetreatStrategy': 22, 'ExploitStrategy': 13, 'AttackStrategy': 10, 'RetaliateStrategy': 8})
# agents_respawned: Counter({'RetreatStrategy': 29, 'ExploitStrategy': 12, 'RetaliateStrategy': 8, 'AttackStrategy': 4})
# agents_fallen: Counter({'RetreatStrategy': 39, 'ExploitStrategy': 28, 'RetaliateStrategy': 16, 'AttackStrategy': 12})
# agents_respawned: Counter({'RetreatStrategy': 46, 'ExploitStrategy': 25, 'RetaliateStrategy': 15, 'AttackStrategy': 9})
# agents_fallen: Counter({'ExploitStrategy': 21, 'RetreatStrategy': 16, 'RetaliateStrategy': 12, 'AttackStrategy': 6})
# agents_respawned: Counter({'RetreatStrategy': 27, 'ExploitStrategy': 18, 'RetaliateStrategy': 8, 'AttackStrategy': 2})
# agents_fallen: Counter({'RetreatStrategy': 28, 'ExploitStrategy': 21, 'RetaliateStrategy': 9, 'AttackStrategy': 1})
# agents_respawned: Counter({'RetreatStrategy': 23, 'ExploitStrategy': 21, 'RetaliateStrategy': 13, 'AttackStrategy': 2})
# agents_fallen: Counter({'RetreatStrategy': 24, 'ExploitStrategy': 11, 'RetaliateStrategy': 11, 'AttackStrategy': 7})
# agents_respawned: Counter({'RetreatStrategy': 21, 'ExploitStrategy': 16, 'RetaliateStrategy': 15, 'AttackStrategy': 1})
# agents_fallen: Counter({'RetreatStrategy': 27, 'ExploitStrategy': 17, 'RetaliateStrategy': 11, 'AttackStrategy': 4})
# agents_respawned: Counter({'RetreatStrategy': 28, 'ExploitStrategy': 21, 'RetaliateStrategy': 9, 'AttackStrategy': 1})
# agents_fallen: Counter({'RetreatStrategy': 22, 'ExploitStrategy': 16, 'RetaliateStrategy': 8, 'AttackStrategy': 5})
# agents_respawned: Counter({'RetreatStrategy': 21, 'ExploitStrategy': 19, 'RetaliateStrategy': 10, 'AttackStrategy': 1})
# agents_fallen: Counter({'RetreatStrategy': 30, 'ExploitStrategy': 21, 'RetaliateStrategy': 10, 'AttackStrategy': 2})
# agents_respawned: Counter({'ExploitStrategy': 28, 'RetreatStrategy': 21, 'RetaliateStrategy': 11, 'AttackStrategy': 3})
# agents_fallen: Counter({'RetreatStrategy': 25, 'ExploitStrategy': 20, 'RetaliateStrategy': 16, 'AttackStrategy': 5})
# agents_respawned: Counter({'ExploitStrategy': 26, 'RetreatStrategy': 23, 'RetaliateStrategy': 15, 'AttackStrategy': 2})
# agents_fallen: Counter({'RetreatStrategy': 32, 'ExploitStrategy': 17, 'RetaliateStrategy': 8, 'AttackStrategy': 4})
# agents_respawned: Counter({'RetreatStrategy': 31, 'ExploitStrategy': 16, 'RetaliateStrategy': 11, 'AttackStrategy': 3})
# agents_fallen: Counter({'RetreatStrategy': 16, 'ExploitStrategy': 15, 'RetaliateStrategy': 12, 'AttackStrategy': 3})
# agents_respawned: Counter({'RetreatStrategy': 24, 'ExploitStrategy': 12, 'RetaliateStrategy': 10})
# agents_fallen: Counter({'ExploitStrategy': 37, 'RetreatStrategy': 33, 'RetaliateStrategy': 17, 'AttackStrategy': 1})
# agents_respawned: Counter({'RetreatStrategy': 36, 'ExploitStrategy': 32, 'RetaliateStrategy': 18, 'AttackStrategy': 2})
# agents_fallen: Counter({'RetreatStrategy': 20, 'ExploitStrategy': 20, 'RetaliateStrategy': 11, 'AttackStrategy': 2})
# agents_respawned: Counter({'RetreatStrategy': 25, 'ExploitStrategy': 17, 'RetaliateStrategy': 7, 'AttackStrategy': 4})
# agents_fallen: Counter({'RetreatStrategy': 29, 'ExploitStrategy': 20, 'RetaliateStrategy': 8, 'AttackStrategy': 6})
# agents_respawned: Counter({'RetreatStrategy': 38, 'ExploitStrategy': 15, 'RetaliateStrategy': 10})
# agents_fallen: Counter({'RetreatStrategy': 21, 'ExploitStrategy': 20, 'RetaliateStrategy': 10, 'AttackStrategy': 3})
# agents_respawned: Counter({'RetreatStrategy': 29, 'ExploitStrategy': 15, 'RetaliateStrategy': 10})
# agents_fallen: Counter({'RetreatStrategy': 32, 'RetaliateStrategy': 11, 'ExploitStrategy': 10, 'AttackStrategy': 3})
# agents_respawned: Counter({'RetreatStrategy': 24, 'ExploitStrategy': 19, 'RetaliateStrategy': 12, 'AttackStrategy': 1})
# agents_fallen: Counter({'ExploitStrategy': 27, 'RetreatStrategy': 25, 'RetaliateStrategy': 8, 'AttackStrategy': 4})
# agents_respawned: Counter({'RetreatStrategy': 33, 'ExploitStrategy': 17, 'RetaliateStrategy': 13, 'AttackStrategy': 1})
# agents_fallen: Counter({'RetreatStrategy': 24, 'ExploitStrategy': 16, 'RetaliateStrategy': 11})
# agents_respawned: Counter({'ExploitStrategy': 22, 'RetreatStrategy': 16, 'RetaliateStrategy': 12, 'AttackStrategy': 1})
# agents_fallen: Counter({'RetreatStrategy': 25, 'ExploitStrategy': 19, 'RetaliateStrategy': 12})
# agents_respawned: Counter({'RetreatStrategy': 22, 'ExploitStrategy': 19, 'RetaliateStrategy': 15})
# agents_fallen: Counter({'RetreatStrategy': 27, 'ExploitStrategy': 24, 'RetaliateStrategy': 14})
# agents_respawned: Counter({'RetreatStrategy': 37, 'RetaliateStrategy': 16, 'ExploitStrategy': 10, 'AttackStrategy': 2})
# agents_fallen: Counter({'RetreatStrategy': 27, 'ExploitStrategy': 18, 'RetaliateStrategy': 8, 'AttackStrategy': 4})
# agents_respawned: Counter({'ExploitStrategy': 24, 'RetreatStrategy': 21, 'RetaliateStrategy': 9, 'AttackStrategy': 3})
# agents_fallen: Counter({'RetreatStrategy': 20, 'ExploitStrategy': 17, 'RetaliateStrategy': 16, 'AttackStrategy': 1})
# agents_respawned: Counter({'RetreatStrategy': 25, 'ExploitStrategy': 17, 'RetaliateStrategy': 11, 'AttackStrategy': 1})
# agents_fallen: Counter({'RetreatStrategy': 28, 'RetaliateStrategy': 18, 'ExploitStrategy': 17, 'AttackStrategy': 1})
# agents_respawned: Counter({'RetreatStrategy': 34, 'ExploitStrategy': 16, 'RetaliateStrategy': 13, 'AttackStrategy': 1})
# agents_fallen: Counter({'RetreatStrategy': 23, 'ExploitStrategy': 16, 'RetaliateStrategy': 13, 'AttackStrategy': 2})
# agents_respawned: Counter({'RetreatStrategy': 34, 'ExploitStrategy': 11, 'RetaliateStrategy': 9})
# agents_fallen: Counter({'RetreatStrategy': 26, 'ExploitStrategy': 19, 'RetaliateStrategy': 11, 'AttackStrategy': 1})
# agents_respawned: Counter({'RetreatStrategy': 30, 'ExploitStrategy': 15, 'RetaliateStrategy': 12})
# agents_fallen: Counter({'ExploitStrategy': 24, 'RetreatStrategy': 23, 'RetaliateStrategy': 13, 'AttackStrategy': 2})
# agents_respawned: Counter({'RetreatStrategy': 36, 'ExploitStrategy': 16, 'RetaliateStrategy': 9, 'AttackStrategy': 1})
# agents_fallen: Counter({'RetreatStrategy': 20, 'ExploitStrategy': 16, 'RetaliateStrategy': 9, 'AttackStrategy': 1})
# agents_respawned: Counter({'RetreatStrategy': 18, 'ExploitStrategy': 18, 'RetaliateStrategy': 7, 'AttackStrategy': 3})
# agents_fallen: Counter({'RetreatStrategy': 23, 'ExploitStrategy': 19, 'RetaliateStrategy': 9, 'AttackStrategy': 1})
# agents_respawned: Counter({'RetreatStrategy': 21, 'RetaliateStrategy': 17, 'ExploitStrategy': 13, 'AttackStrategy': 1})
# agents_fallen: Counter({'RetreatStrategy': 29, 'ExploitStrategy': 23, 'RetaliateStrategy': 10, 'AttackStrategy': 1})
# agents_respawned: Counter({'RetreatStrategy': 41, 'ExploitStrategy': 19, 'RetaliateStrategy': 3})
# agents_fallen: Counter({'RetreatStrategy': 19, 'ExploitStrategy': 17, 'RetaliateStrategy': 5, 'AttackStrategy': 2})
# agents_respawned: Counter({'RetreatStrategy': 21, 'ExploitStrategy': 12, 'RetaliateStrategy': 8, 'AttackStrategy': 2})
# agents_fallen: Counter({'RetreatStrategy': 35, 'ExploitStrategy': 15, 'RetaliateStrategy': 10, 'AttackStrategy': 1})
# agents_respawned: Counter({'RetreatStrategy': 29, 'ExploitStrategy': 20, 'RetaliateStrategy': 12})
# agents_fallen: Counter({'RetreatStrategy': 27, 'ExploitStrategy': 11, 'RetaliateStrategy': 6, 'AttackStrategy': 1})
# agents_respawned: Counter({'RetreatStrategy': 24, 'RetaliateStrategy': 12, 'ExploitStrategy': 8, 'AttackStrategy': 1})
# agents_fallen: Counter({'RetreatStrategy': 27, 'ExploitStrategy': 23, 'RetaliateStrategy': 9, 'AttackStrategy': 1})
# agents_respawned: Counter({'RetreatStrategy': 34, 'RetaliateStrategy': 11, 'ExploitStrategy': 11, 'AttackStrategy': 4})
# agents_fallen: Counter({'RetreatStrategy': 18, 'ExploitStrategy': 16, 'RetaliateStrategy': 10, 'AttackStrategy': 1})
# agents_respawned: Counter({'RetreatStrategy': 21, 'ExploitStrategy': 16, 'RetaliateStrategy': 7, 'AttackStrategy': 1})
# agents_fallen: Counter({'RetreatStrategy': 31, 'ExploitStrategy': 20, 'RetaliateStrategy': 7, 'AttackStrategy': 2})
# agents_respawned: Counter({'RetreatStrategy': 33, 'ExploitStrategy': 21, 'RetaliateStrategy': 4, 'AttackStrategy': 2})
# agents_fallen: Counter({'RetreatStrategy': 30, 'ExploitStrategy': 15, 'RetaliateStrategy': 6, 'AttackStrategy': 2})
# agents_respawned: Counter({'RetreatStrategy': 29, 'ExploitStrategy': 13, 'RetaliateStrategy': 10, 'AttackStrategy': 1})
# agents_fallen: Counter({'RetreatStrategy': 33, 'ExploitStrategy': 13, 'RetaliateStrategy': 7, 'AttackStrategy': 1})
# agents_respawned: Counter({'RetreatStrategy': 23, 'ExploitStrategy': 16, 'RetaliateStrategy': 14, 'AttackStrategy': 1})
# agents_fallen: Counter({'ExploitStrategy': 16, 'RetreatStrategy': 16, 'RetaliateStrategy': 6, 'AttackStrategy': 2})
# agents_respawned: Counter({'RetreatStrategy': 19, 'ExploitStrategy': 11, 'RetaliateStrategy': 9, 'AttackStrategy': 1})
# agents_fallen: Counter({'RetreatStrategy': 19, 'ExploitStrategy': 14, 'RetaliateStrategy': 12, 'AttackStrategy': 3})
# agents_respawned: Counter({'RetreatStrategy': 26, 'RetaliateStrategy': 12, 'ExploitStrategy': 10})
# agents_fallen: Counter({'RetreatStrategy': 27, 'ExploitStrategy': 14, 'RetaliateStrategy': 8, 'AttackStrategy': 1})
# agents_respawned: Counter({'RetreatStrategy': 29, 'RetaliateStrategy': 12, 'ExploitStrategy': 8, 'AttackStrategy': 1})
# agents_fallen: Counter({'RetreatStrategy': 27, 'ExploitStrategy': 18, 'RetaliateStrategy': 7})
# agents_respawned: Counter({'RetreatStrategy': 29, 'ExploitStrategy': 14, 'RetaliateStrategy': 8, 'AttackStrategy': 1})
# agents_fallen: Counter({'RetreatStrategy': 26, 'RetaliateStrategy': 13, 'ExploitStrategy': 12, 'AttackStrategy': 3})
# agents_respawned: Counter({'RetreatStrategy': 27, 'ExploitStrategy': 16, 'RetaliateStrategy': 11})
# agents_fallen: Counter({'RetreatStrategy': 24, 'ExploitStrategy': 16, 'RetaliateStrategy': 13, 'AttackStrategy': 1})
# agents_respawned: Counter({'RetreatStrategy': 25, 'ExploitStrategy': 15, 'RetaliateStrategy': 12, 'AttackStrategy': 2})
# agents_fallen: Counter({'RetreatStrategy': 22, 'ExploitStrategy': 17, 'RetaliateStrategy': 8, 'AttackStrategy': 2})
# agents_respawned: Counter({'RetreatStrategy': 22, 'ExploitStrategy': 22, 'RetaliateStrategy': 5})
# agents_fallen: Counter({'RetreatStrategy': 27, 'ExploitStrategy': 19, 'RetaliateStrategy': 8, 'AttackStrategy': 1})
# agents_respawned: Counter({'RetreatStrategy': 28, 'ExploitStrategy': 14, 'RetaliateStrategy': 13})
# agents_fallen: Counter({'RetreatStrategy': 21, 'RetaliateStrategy': 13, 'ExploitStrategy': 12})
# agents_respawned: Counter({'RetreatStrategy': 23, 'ExploitStrategy': 14, 'RetaliateStrategy': 7, 'AttackStrategy': 2})
# agents_fallen: Counter({'RetreatStrategy': 29, 'ExploitStrategy': 18, 'RetaliateStrategy': 8, 'AttackStrategy': 1})
# agents_respawned: Counter({'RetreatStrategy': 35, 'RetaliateStrategy': 11, 'ExploitStrategy': 10})
# agents_fallen: Counter({'RetreatStrategy': 26, 'ExploitStrategy': 20, 'RetaliateStrategy': 10, 'AttackStrategy': 2})
# agents_respawned: Counter({'RetreatStrategy': 28, 'ExploitStrategy': 17, 'RetaliateStrategy': 13})
# agents_fallen: Counter({'RetreatStrategy': 24, 'ExploitStrategy': 18, 'RetaliateStrategy': 8})
# agents_respawned: Counter({'RetreatStrategy': 28, 'ExploitStrategy': 13, 'RetaliateStrategy': 8, 'AttackStrategy': 1})
# agents_fallen: Counter({'RetreatStrategy': 21, 'ExploitStrategy': 9, 'RetaliateStrategy': 9})
# agents_respawned: Counter({'RetreatStrategy': 22, 'RetaliateStrategy': 9, 'ExploitStrategy': 7, 'AttackStrategy': 1})
# agents_fallen: Counter({'RetreatStrategy': 17, 'ExploitStrategy': 15, 'RetaliateStrategy': 10, 'AttackStrategy': 1})
# agents_respawned: Counter({'RetreatStrategy': 19, 'RetaliateStrategy': 15, 'ExploitStrategy': 8, 'AttackStrategy': 1})
# agents_fallen: Counter({'RetreatStrategy': 25, 'ExploitStrategy': 14, 'RetaliateStrategy': 13})
# agents_respawned: Counter({'RetreatStrategy': 29, 'ExploitStrategy': 13, 'RetaliateStrategy': 9, 'AttackStrategy': 1})
# agents_fallen: Counter({'RetreatStrategy': 31, 'ExploitStrategy': 14, 'RetaliateStrategy': 8})
# agents_respawned: Counter({'RetreatStrategy': 29, 'ExploitStrategy': 13, 'RetaliateStrategy': 11})
# agents_fallen: Counter({'RetreatStrategy': 27, 'ExploitStrategy': 12, 'RetaliateStrategy': 10, 'AttackStrategy': 2})
# agents_respawned: Counter({'RetreatStrategy': 27, 'RetaliateStrategy': 12, 'ExploitStrategy': 10, 'AttackStrategy': 2})
# agents_fallen: Counter({'RetreatStrategy': 23, 'RetaliateStrategy': 11, 'ExploitStrategy': 8, 'AttackStrategy': 1})
# agents_respawned: Counter({'RetreatStrategy': 23, 'ExploitStrategy': 11, 'RetaliateStrategy': 9})
# agents_fallen: Counter({'RetreatStrategy': 28, 'ExploitStrategy': 15, 'RetaliateStrategy': 8, 'AttackStrategy': 1})
# agents_respawned: Counter({'RetreatStrategy': 37, 'ExploitStrategy': 9, 'RetaliateStrategy': 6})
# agents_fallen: Counter({'RetreatStrategy': 30, 'ExploitStrategy': 13, 'RetaliateStrategy': 7, 'AttackStrategy': 1})
# agents_respawned: Counter({'RetreatStrategy': 27, 'ExploitStrategy': 12, 'RetaliateStrategy': 12})
# agents_fallen: Counter({'ExploitStrategy': 19, 'RetreatStrategy': 19, 'RetaliateStrategy': 12, 'AttackStrategy': 2})
# agents_respawned: Counter({'RetreatStrategy': 33, 'RetaliateStrategy': 11, 'ExploitStrategy': 8})
# agents_fallen: Counter({'RetreatStrategy': 24, 'RetaliateStrategy': 19, 'ExploitStrategy': 8, 'AttackStrategy': 1})
# agents_respawned: Counter({'RetreatStrategy': 28, 'ExploitStrategy': 12, 'RetaliateStrategy': 12})
# agents_fallen: Counter({'RetreatStrategy': 24, 'RetaliateStrategy': 11, 'ExploitStrategy': 7})
# agents_respawned: Counter({'RetreatStrategy': 28, 'RetaliateStrategy': 9, 'ExploitStrategy': 5})
# agents_fallen: Counter({'RetreatStrategy': 18, 'ExploitStrategy': 14, 'RetaliateStrategy': 10})
# agents_respawned: Counter({'RetreatStrategy': 27, 'ExploitStrategy': 9, 'RetaliateStrategy': 4, 'AttackStrategy': 2})
# agents_fallen: Counter({'RetreatStrategy': 26, 'ExploitStrategy': 9, 'RetaliateStrategy': 4, 'AttackStrategy': 2})
# agents_respawned: Counter({'RetreatStrategy': 26, 'ExploitStrategy': 7, 'RetaliateStrategy': 7, 'AttackStrategy': 1})
# agents_fallen: Counter({'RetreatStrategy': 26, 'ExploitStrategy': 11, 'RetaliateStrategy': 6})
# agents_respawned: Counter({'RetreatStrategy': 23, 'ExploitStrategy': 12, 'RetaliateStrategy': 8})
# agents_fallen: Counter({'RetreatStrategy': 17, 'ExploitStrategy': 16, 'RetaliateStrategy': 8})
# agents_respawned: Counter({'RetreatStrategy': 23, 'RetaliateStrategy': 11, 'ExploitStrategy': 7})
# agents_fallen: Counter({'RetreatStrategy': 18, 'ExploitStrategy': 15, 'RetaliateStrategy': 11})
# agents_respawned: Counter({'RetreatStrategy': 21, 'ExploitStrategy': 11, 'RetaliateStrategy': 10, 'AttackStrategy': 2})
# agents_fallen: Counter({'RetreatStrategy': 18, 'ExploitStrategy': 10, 'RetaliateStrategy': 8})
# agents_respawned: Counter({'RetreatStrategy': 21, 'RetaliateStrategy': 9, 'ExploitStrategy': 5, 'AttackStrategy': 1})
# agents_fallen: Counter({'RetreatStrategy': 24, 'ExploitStrategy': 11, 'RetaliateStrategy': 4, 'AttackStrategy': 1})
# agents_respawned: Counter({'RetreatStrategy': 21, 'RetaliateStrategy': 11, 'ExploitStrategy': 7, 'AttackStrategy': 1})
# agents_fallen: Counter({'RetreatStrategy': 18, 'ExploitStrategy': 11, 'RetaliateStrategy': 8})
# agents_respawned: Counter({'RetreatStrategy': 19, 'RetaliateStrategy': 11, 'ExploitStrategy': 6, 'AttackStrategy': 1})
# agents_fallen: Counter({'RetreatStrategy': 22, 'RetaliateStrategy': 11, 'ExploitStrategy': 9, 'AttackStrategy': 2})
# agents_respawned: Counter({'RetreatStrategy': 20, 'RetaliateStrategy': 11, 'ExploitStrategy': 11, 'AttackStrategy': 2})
# agents_fallen: Counter({'RetreatStrategy': 30, 'ExploitStrategy': 10, 'RetaliateStrategy': 6, 'AttackStrategy': 1})
# agents_respawned: Counter({'RetreatStrategy': 25, 'RetaliateStrategy': 12, 'ExploitStrategy': 9, 'AttackStrategy': 1})
# agents_fallen: Counter({'RetreatStrategy': 24, 'ExploitStrategy': 18, 'RetaliateStrategy': 9, 'AttackStrategy': 1})
# agents_respawned: Counter({'RetreatStrategy': 36, 'RetaliateStrategy': 9, 'ExploitStrategy': 7})
# agents_fallen: Counter({'RetreatStrategy': 20, 'RetaliateStrategy': 10, 'ExploitStrategy': 7, 'AttackStrategy': 2})
# agents_respawned: Counter({'RetreatStrategy': 20, 'ExploitStrategy': 9, 'RetaliateStrategy': 8, 'AttackStrategy': 2})
# agents_fallen: Counter({'RetreatStrategy': 28, 'ExploitStrategy': 8, 'RetaliateStrategy': 2})
# agents_respawned: Counter({'RetreatStrategy': 25, 'ExploitStrategy': 7, 'RetaliateStrategy': 6})
# agents_fallen: Counter({'RetreatStrategy': 22, 'RetaliateStrategy': 7, 'ExploitStrategy': 7, 'AttackStrategy': 1})
# agents_respawned: Counter({'RetreatStrategy': 23, 'RetaliateStrategy': 7, 'ExploitStrategy': 7})
# agents_fallen: Counter({'RetreatStrategy': 20, 'ExploitStrategy': 11, 'RetaliateStrategy': 10})
# agents_respawned: Counter({'RetreatStrategy': 24, 'RetaliateStrategy': 9, 'ExploitStrategy': 6, 'AttackStrategy': 2})
# agents_fallen: Counter({'RetreatStrategy': 31, 'ExploitStrategy': 15, 'RetaliateStrategy': 10, 'AttackStrategy': 2})
# agents_respawned: Counter({'RetreatStrategy': 34, 'RetaliateStrategy': 13, 'ExploitStrategy': 10, 'AttackStrategy': 1})
# agents_fallen: Counter({'RetreatStrategy': 21, 'ExploitStrategy': 18, 'RetaliateStrategy': 12, 'AttackStrategy': 2})
# agents_respawned: Counter({'RetreatStrategy': 23, 'RetaliateStrategy': 17, 'ExploitStrategy': 12, 'AttackStrategy': 1})
# agents_fallen: Counter({'RetreatStrategy': 13, 'RetaliateStrategy': 12, 'ExploitStrategy': 7})
# agents_respawned: Counter({'RetreatStrategy': 20, 'RetaliateStrategy': 8, 'ExploitStrategy': 4})
# agents_fallen: Counter({'RetreatStrategy': 27, 'RetaliateStrategy': 9, 'ExploitStrategy': 6, 'AttackStrategy': 1})
# agents_respawned: Counter({'RetreatStrategy': 26, 'RetaliateStrategy': 12, 'ExploitStrategy': 5})
# agents_fallen: Counter({'RetreatStrategy': 18, 'RetaliateStrategy': 11, 'ExploitStrategy': 8})
# agents_respawned: Counter({'RetreatStrategy': 20, 'RetaliateStrategy': 13, 'ExploitStrategy': 4})
# agents_fallen: Counter({'RetreatStrategy': 16, 'ExploitStrategy': 7, 'RetaliateStrategy': 7, 'AttackStrategy': 1})
# agents_respawned: Counter({'RetreatStrategy': 24, 'ExploitStrategy': 5, 'RetaliateStrategy': 2})
# agents_fallen: Counter({'RetreatStrategy': 23, 'ExploitStrategy': 7, 'RetaliateStrategy': 6, 'AttackStrategy': 1})
# agents_respawned: Counter({'RetreatStrategy': 23, 'RetaliateStrategy': 7, 'ExploitStrategy': 5, 'AttackStrategy': 2})
# agents_fallen: Counter({'RetreatStrategy': 14, 'ExploitStrategy': 11, 'RetaliateStrategy': 6, 'AttackStrategy': 1})
# agents_respawned: Counter({'RetreatStrategy': 17, 'RetaliateStrategy': 9, 'ExploitStrategy': 6})
# agents_fallen: Counter({'RetreatStrategy': 14, 'ExploitStrategy': 12, 'RetaliateStrategy': 6})
# agents_respawned: Counter({'RetreatStrategy': 27, 'ExploitStrategy': 3, 'RetaliateStrategy': 2})
# agents_fallen: Counter({'RetreatStrategy': 18, 'RetaliateStrategy': 11, 'ExploitStrategy': 9})
# agents_respawned: Counter({'RetreatStrategy': 22, 'RetaliateStrategy': 8, 'ExploitStrategy': 8})
# agents_fallen: Counter({'RetreatStrategy': 29, 'ExploitStrategy': 7, 'RetaliateStrategy': 4, 'AttackStrategy': 1})
# agents_respawned: Counter({'RetreatStrategy': 32, 'ExploitStrategy': 4, 'RetaliateStrategy': 4, 'AttackStrategy': 1})
# agents_fallen: Counter({'RetreatStrategy': 21, 'RetaliateStrategy': 11, 'ExploitStrategy': 4, 'AttackStrategy': 1})
# agents_respawned: Counter({'RetreatStrategy': 23, 'ExploitStrategy': 7, 'RetaliateStrategy': 6, 'AttackStrategy': 1})
# agents_fallen: Counter({'RetreatStrategy': 14, 'ExploitStrategy': 12, 'RetaliateStrategy': 7, 'AttackStrategy': 1})
# agents_respawned: Counter({'RetreatStrategy': 21, 'RetaliateStrategy': 7, 'ExploitStrategy': 6})
# agents_fallen: Counter({'RetreatStrategy': 18, 'ExploitStrategy': 5, 'RetaliateStrategy': 5, 'AttackStrategy': 2})
# agents_respawned: Counter({'RetreatStrategy': 22, 'ExploitStrategy': 5, 'RetaliateStrategy': 3})
# agents_fallen: Counter({'RetreatStrategy': 17, 'ExploitStrategy': 6, 'RetaliateStrategy': 4})
# agents_respawned: Counter({'RetreatStrategy': 17, 'ExploitStrategy': 7, 'RetaliateStrategy': 3})
# agents_fallen: Counter({'RetreatStrategy': 20, 'ExploitStrategy': 11, 'RetaliateStrategy': 8})
# agents_respawned: Counter({'RetreatStrategy': 24, 'ExploitStrategy': 8, 'RetaliateStrategy': 6, 'AttackStrategy': 1})
# agents_fallen: Counter({'RetreatStrategy': 24, 'ExploitStrategy': 6, 'RetaliateStrategy': 6, 'AttackStrategy': 1})
# agents_respawned: Counter({'RetreatStrategy': 28, 'ExploitStrategy': 5, 'RetaliateStrategy': 4})
# agents_fallen: Counter({'RetreatStrategy': 18, 'ExploitStrategy': 9, 'RetaliateStrategy': 8, 'AttackStrategy': 1})
# agents_respawned: Counter({'RetreatStrategy': 24, 'RetaliateStrategy': 7, 'ExploitStrategy': 4, 'AttackStrategy': 1})
# agents_fallen: Counter({'RetreatStrategy': 18, 'ExploitStrategy': 9, 'RetaliateStrategy': 9})
# agents_respawned: Counter({'RetreatStrategy': 27, 'RetaliateStrategy': 7, 'AttackStrategy': 1, 'ExploitStrategy': 1})
# agents_fallen: Counter({'RetreatStrategy': 18, 'RetaliateStrategy': 10, 'ExploitStrategy': 4, 'AttackStrategy': 1})
# agents_respawned: Counter({'RetreatStrategy': 27, 'RetaliateStrategy': 4, 'ExploitStrategy': 1, 'AttackStrategy': 1})
# agents_fallen: Counter({'RetreatStrategy': 14, 'ExploitStrategy': 7, 'RetaliateStrategy': 6, 'AttackStrategy': 1})
# agents_respawned: Counter({'RetreatStrategy': 19, 'RetaliateStrategy': 7, 'ExploitStrategy': 2})
# agents_fallen: Counter({'RetreatStrategy': 14, 'ExploitStrategy': 8, 'RetaliateStrategy': 5})
# agents_respawned: Counter({'RetreatStrategy': 20, 'RetaliateStrategy': 6, 'ExploitStrategy': 1})
# agents_fallen: Counter({'RetreatStrategy': 20, 'ExploitStrategy': 9, 'RetaliateStrategy': 7, 'AttackStrategy': 1})
# agents_respawned: Counter({'RetreatStrategy': 26, 'RetaliateStrategy': 7, 'ExploitStrategy': 4})
# agents_fallen: Counter({'ExploitStrategy': 14, 'RetreatStrategy': 11, 'RetaliateStrategy': 4})
# agents_respawned: Counter({'RetreatStrategy': 17, 'RetaliateStrategy': 8, 'ExploitStrategy': 3, 'AttackStrategy': 1})
# agents_fallen: Counter({'RetreatStrategy': 14, 'RetaliateStrategy': 8, 'ExploitStrategy': 7})
# agents_respawned: Counter({'RetreatStrategy': 18, 'RetaliateStrategy': 6, 'ExploitStrategy': 4, 'AttackStrategy': 1})
# agents_fallen: Counter({'RetreatStrategy': 23, 'ExploitStrategy': 5, 'RetaliateStrategy': 5})
# agents_respawned: Counter({'RetreatStrategy': 24, 'RetaliateStrategy': 7, 'ExploitStrategy': 2})
# agents_fallen: Counter({'RetreatStrategy': 16, 'RetaliateStrategy': 8, 'ExploitStrategy': 5})
# agents_respawned: Counter({'RetreatStrategy': 22, 'RetaliateStrategy': 6, 'AttackStrategy': 1})
# agents_fallen: Counter({'RetreatStrategy': 6, 'ExploitStrategy': 6, 'RetaliateStrategy': 4})
# agents_respawned: Counter({'RetreatStrategy': 12, 'RetaliateStrategy': 3, 'ExploitStrategy': 1})
# agents_fallen: Counter({'RetreatStrategy': 19, 'RetaliateStrategy': 5, 'ExploitStrategy': 4, 'AttackStrategy': 1})
# agents_respawned: Counter({'RetreatStrategy': 20, 'RetaliateStrategy': 7, 'ExploitStrategy': 2})
# agents_fallen: Counter({'RetreatStrategy': 18, 'ExploitStrategy': 5, 'RetaliateStrategy': 3})
# agents_respawned: Counter({'RetreatStrategy': 18, 'RetaliateStrategy': 5, 'ExploitStrategy': 3})
# agents_fallen: Counter({'RetreatStrategy': 17, 'RetaliateStrategy': 5, 'ExploitStrategy': 2})
# agents_respawned: Counter({'RetreatStrategy': 18, 'RetaliateStrategy': 4, 'ExploitStrategy': 2})
# agents_fallen: Counter({'RetreatStrategy': 17, 'ExploitStrategy': 7, 'RetaliateStrategy': 2})
# agents_respawned: Counter({'RetreatStrategy': 12, 'ExploitStrategy': 7, 'RetaliateStrategy': 7})
# agents_fallen: Counter({'RetreatStrategy': 19, 'ExploitStrategy': 5, 'RetaliateStrategy': 3, 'AttackStrategy': 1})
# agents_respawned: Counter({'RetreatStrategy': 20, 'RetaliateStrategy': 8})
# agents_fallen: Counter({'RetreatStrategy': 13, 'ExploitStrategy': 6, 'RetaliateStrategy': 3})
# agents_respawned: Counter({'RetreatStrategy': 15, 'RetaliateStrategy': 5, 'AttackStrategy': 2})
# agents_fallen: Counter({'RetreatStrategy': 17, 'RetaliateStrategy': 7, 'ExploitStrategy': 4})
# agents_respawned: Counter({'RetreatStrategy': 23, 'RetaliateStrategy': 4, 'ExploitStrategy': 1})
# agents_fallen: Counter({'RetreatStrategy': 8, 'RetaliateStrategy': 7, 'ExploitStrategy': 4})
# agents_respawned: Counter({'RetreatStrategy': 9, 'RetaliateStrategy': 7, 'ExploitStrategy': 3})
# agents_fallen: Counter({'RetreatStrategy': 12, 'ExploitStrategy': 7, 'RetaliateStrategy': 4, 'AttackStrategy': 1})
# agents_respawned: Counter({'RetreatStrategy': 16, 'RetaliateStrategy': 8})
# agents_fallen: Counter({'RetreatStrategy': 12, 'ExploitStrategy': 8, 'RetaliateStrategy': 3})
# agents_respawned: Counter({'RetreatStrategy': 21, 'RetaliateStrategy': 2})
# agents_fallen: Counter({'RetreatStrategy': 13, 'RetaliateStrategy': 8, 'ExploitStrategy': 5, 'AttackStrategy': 1})
# agents_respawned: Counter({'RetreatStrategy': 19, 'RetaliateStrategy': 7, 'ExploitStrategy': 1})
# agents_fallen: Counter({'RetreatStrategy': 11, 'RetaliateStrategy': 8, 'ExploitStrategy': 1})
# agents_respawned: Counter({'RetreatStrategy': 14, 'ExploitStrategy': 3, 'RetaliateStrategy': 3})
# agents_fallen: Counter({'RetreatStrategy': 14, 'RetaliateStrategy': 6, 'ExploitStrategy': 3})
# agents_respawned: Counter({'RetreatStrategy': 21, 'RetaliateStrategy': 2})
# agents_fallen: Counter({'RetreatStrategy': 13, 'RetaliateStrategy': 3, 'ExploitStrategy': 3})
# agents_respawned: Counter({'RetreatStrategy': 12, 'RetaliateStrategy': 3, 'ExploitStrategy': 3, 'AttackStrategy': 1})
# agents_fallen: Counter({'RetreatStrategy': 10, 'RetaliateStrategy': 4, 'ExploitStrategy': 3, 'AttackStrategy': 1})
# agents_respawned: Counter({'RetreatStrategy': 11, 'RetaliateStrategy': 5, 'AttackStrategy': 1, 'ExploitStrategy': 1})
# agents_fallen: Counter({'RetreatStrategy': 16, 'ExploitStrategy': 3, 'RetaliateStrategy': 2, 'AttackStrategy': 1})
# agents_respawned: Counter({'RetreatStrategy': 15, 'RetaliateStrategy': 5, 'ExploitStrategy': 2})
# agents_fallen: Counter({'RetreatStrategy': 13, 'ExploitStrategy': 3, 'RetaliateStrategy': 2, 'AttackStrategy': 1})
# agents_respawned: Counter({'RetreatStrategy': 16, 'RetaliateStrategy': 3})
# agents_fallen: Counter({'RetreatStrategy': 10, 'RetaliateStrategy': 5, 'ExploitStrategy': 3})
# agents_respawned: Counter({'RetreatStrategy': 15, 'RetaliateStrategy': 3})
# agents_fallen: Counter({'RetreatStrategy': 15, 'RetaliateStrategy': 6, 'ExploitStrategy': 1})
# agents_respawned: Counter({'RetreatStrategy': 11, 'RetaliateStrategy': 9, 'ExploitStrategy': 1, 'AttackStrategy': 1})
# agents_fallen: Counter({'RetreatStrategy': 10, 'RetaliateStrategy': 4, 'ExploitStrategy': 3})
# agents_respawned: Counter({'RetreatStrategy': 16, 'RetaliateStrategy': 1})
# agents_fallen: Counter({'RetreatStrategy': 15, 'ExploitStrategy': 4, 'RetaliateStrategy': 2, 'AttackStrategy': 1})
# agents_respawned: Counter({'RetreatStrategy': 13, 'RetaliateStrategy': 8, 'AttackStrategy': 1})
# agents_fallen: Counter({'RetreatStrategy': 10, 'RetaliateStrategy': 3, 'ExploitStrategy': 3})
# agents_respawned: Counter({'RetreatStrategy': 13, 'RetaliateStrategy': 3})
# agents_fallen: Counter({'RetreatStrategy': 14, 'RetaliateStrategy': 4, 'ExploitStrategy': 3})
# agents_respawned: Counter({'RetreatStrategy': 16, 'RetaliateStrategy': 5})
# agents_fallen: Counter({'RetreatStrategy': 8, 'ExploitStrategy': 2, 'AttackStrategy': 1, 'RetaliateStrategy': 1})
# agents_respawned: Counter({'RetreatStrategy': 6, 'RetaliateStrategy': 6})
# agents_fallen: Counter({'RetreatStrategy': 8, 'ExploitStrategy': 5, 'RetaliateStrategy': 2})
# agents_respawned: Counter({'RetaliateStrategy': 6, 'RetreatStrategy': 5, 'ExploitStrategy': 3, 'AttackStrategy': 1})
# agents_fallen: Counter({'RetreatStrategy': 13, 'RetaliateStrategy': 2})
# agents_respawned: Counter({'RetreatStrategy': 15})
# agents_fallen: Counter({'RetreatStrategy': 7, 'RetaliateStrategy': 3, 'AttackStrategy': 1, 'ExploitStrategy': 1})
# agents_respawned: Counter({'RetreatStrategy': 11, 'RetaliateStrategy': 1})
# agents_fallen: Counter({'RetreatStrategy': 6, 'RetaliateStrategy': 2, 'ExploitStrategy': 1})
# agents_respawned: Counter({'RetreatStrategy': 6, 'RetaliateStrategy': 3})
# agents_fallen: Counter({'RetreatStrategy': 9, 'ExploitStrategy': 7, 'RetaliateStrategy': 3, 'AttackStrategy': 1})
# agents_respawned: Counter({'RetreatStrategy': 16, 'RetaliateStrategy': 2, 'AttackStrategy': 1, 'ExploitStrategy': 1})
# agents_fallen: Counter({'RetreatStrategy': 6, 'ExploitStrategy': 2})
# agents_respawned: Counter({'RetreatStrategy': 6, 'RetaliateStrategy': 1, 'AttackStrategy': 1})
# agents_fallen: Counter({'RetreatStrategy': 11, 'RetaliateStrategy': 2, 'ExploitStrategy': 1})
# agents_respawned: Counter({'RetreatStrategy': 11, 'RetaliateStrategy': 3})
# agents_fallen: Counter({'RetreatStrategy': 9, 'RetaliateStrategy': 4, 'ExploitStrategy': 1})
# agents_respawned: Counter({'RetreatStrategy': 9, 'RetaliateStrategy': 5})
# agents_fallen: Counter({'RetreatStrategy': 11, 'RetaliateStrategy': 3, 'ExploitStrategy': 2})
# agents_respawned: Counter({'RetaliateStrategy': 8, 'RetreatStrategy': 7, 'AttackStrategy': 1})
# agents_fallen: Counter({'RetreatStrategy': 8, 'RetaliateStrategy': 4})
# agents_respawned: Counter({'RetreatStrategy': 11, 'RetaliateStrategy': 1})
# agents_fallen: Counter({'RetreatStrategy': 8, 'RetaliateStrategy': 3, 'AttackStrategy': 2, 'ExploitStrategy': 1})
# agents_respawned: Counter({'RetreatStrategy': 9, 'RetaliateStrategy': 3, 'ExploitStrategy': 2})
# agents_fallen: Counter({'RetreatStrategy': 9, 'RetaliateStrategy': 4, 'ExploitStrategy': 1, 'AttackStrategy': 1})
# agents_respawned: Counter({'RetreatStrategy': 13, 'RetaliateStrategy': 2})
# agents_fallen: Counter({'RetreatStrategy': 6, 'RetaliateStrategy': 5, 'ExploitStrategy': 1})
# agents_respawned: Counter({'RetreatStrategy': 11, 'RetaliateStrategy': 1})
# agents_fallen: Counter({'RetreatStrategy': 8, 'RetaliateStrategy': 4, 'ExploitStrategy': 3})
# agents_respawned: Counter({'RetreatStrategy': 12, 'RetaliateStrategy': 3})
# agents_fallen: Counter({'ExploitStrategy': 4, 'RetreatStrategy': 3, 'RetaliateStrategy': 3})
# agents_respawned: Counter({'RetreatStrategy': 10})
# agents_fallen: Counter({'RetreatStrategy': 10, 'RetaliateStrategy': 4, 'ExploitStrategy': 2})
# agents_respawned: Counter({'RetreatStrategy': 13, 'AttackStrategy': 1, 'RetaliateStrategy': 1, 'ExploitStrategy': 1})
# agents_fallen: Counter({'RetreatStrategy': 6, 'AttackStrategy': 2, 'ExploitStrategy': 1, 'RetaliateStrategy': 1})
# agents_respawned: Counter({'RetreatStrategy': 9, 'RetaliateStrategy': 1})
# agents_fallen: Counter({'RetreatStrategy': 8, 'RetaliateStrategy': 3, 'ExploitStrategy': 1})
# agents_respawned: Counter({'RetreatStrategy': 9, 'RetaliateStrategy': 3})
# agents_fallen: Counter({'RetreatStrategy': 5, 'RetaliateStrategy': 1})
# agents_respawned: Counter({'RetreatStrategy': 6})
# agents_fallen: Counter({'RetreatStrategy': 10, 'RetaliateStrategy': 3})
# agents_respawned: Counter({'RetreatStrategy': 11, 'RetaliateStrategy': 2})
# agents_fallen: Counter({'RetreatStrategy': 4, 'RetaliateStrategy': 3})
# agents_respawned: Counter({'RetreatStrategy': 6, 'RetaliateStrategy': 1})
# agents_fallen: Counter({'RetreatStrategy': 10, 'RetaliateStrategy': 5, 'ExploitStrategy': 1})
# agents_respawned: Counter({'RetreatStrategy': 15, 'RetaliateStrategy': 1})
# agents_fallen: Counter({'RetreatStrategy': 6, 'RetaliateStrategy': 1})
# agents_respawned: Counter({'RetreatStrategy': 7})
# agents_fallen: Counter({'RetreatStrategy': 5, 'ExploitStrategy': 4, 'RetaliateStrategy': 1})
# agents_respawned: Counter({'RetreatStrategy': 7, 'RetaliateStrategy': 3})
# agents_fallen: Counter({'RetreatStrategy': 6})
# agents_respawned: Counter({'RetreatStrategy': 4, 'RetaliateStrategy': 2})
# agents_fallen: Counter({'RetreatStrategy': 9, 'RetaliateStrategy': 5})
# agents_respawned: Counter({'RetreatStrategy': 12, 'RetaliateStrategy': 2})
# agents_fallen: Counter({'RetreatStrategy': 7})
# agents_respawned: Counter({'RetreatStrategy': 6, 'RetaliateStrategy': 1})
# agents_fallen: Counter({'RetreatStrategy': 5, 'RetaliateStrategy': 4, 'ExploitStrategy': 1})
# agents_respawned: Counter({'RetreatStrategy': 6, 'RetaliateStrategy': 3, 'ExploitStrategy': 1})
# agents_fallen: Counter({'RetreatStrategy': 8, 'RetaliateStrategy': 4})
# agents_respawned: Counter({'RetaliateStrategy': 6, 'RetreatStrategy': 5, 'AttackStrategy': 1})
# agents_fallen: Counter({'RetreatStrategy': 6, 'RetaliateStrategy': 3})
# agents_respawned: Counter({'RetreatStrategy': 7, 'ExploitStrategy': 1, 'RetaliateStrategy': 1})
# agents_fallen: Counter({'RetreatStrategy': 8, 'RetaliateStrategy': 6, 'ExploitStrategy': 2, 'AttackStrategy': 1})
# agents_respawned: Counter({'RetreatStrategy': 15, 'RetaliateStrategy': 2})
# agents_fallen: Counter({'RetreatStrategy': 13, 'RetaliateStrategy': 2})
# agents_respawned: Counter({'RetreatStrategy': 11, 'RetaliateStrategy': 4})
# agents_fallen: Counter({'RetreatStrategy': 5, 'RetaliateStrategy': 2, 'ExploitStrategy': 1})
# agents_respawned: Counter({'RetreatStrategy': 7, 'RetaliateStrategy': 1})
# agents_fallen: Counter({'RetreatStrategy': 5})
# agents_respawned: Counter({'RetreatStrategy': 5})
# agents_fallen: Counter({'RetreatStrategy': 11, 'RetaliateStrategy': 1})
# agents_respawned: Counter({'RetreatStrategy': 11, 'RetaliateStrategy': 1})
# agents_fallen: Counter({'RetreatStrategy': 12, 'RetaliateStrategy': 3, 'ExploitStrategy': 1})
# agents_respawned: Counter({'RetreatStrategy': 14, 'RetaliateStrategy': 2})
# agents_fallen: Counter({'RetreatStrategy': 10})
# agents_respawned: Counter({'RetreatStrategy': 8, 'RetaliateStrategy': 2})
# agents_fallen: Counter({'RetreatStrategy': 12, 'RetaliateStrategy': 2})
# agents_respawned: Counter({'RetreatStrategy': 13, 'RetaliateStrategy': 1})
# agents_fallen: Counter({'RetreatStrategy': 10, 'RetaliateStrategy': 3})
# agents_respawned: Counter({'RetreatStrategy': 12, 'RetaliateStrategy': 1})
# agents_fallen: Counter({'RetreatStrategy': 10, 'RetaliateStrategy': 2})
# agents_respawned: Counter({'RetreatStrategy': 11, 'RetaliateStrategy': 1})
# agents_fallen: Counter({'RetreatStrategy': 3})
# agents_respawned: Counter({'RetreatStrategy': 2, 'RetaliateStrategy': 1})
# agents_fallen: Counter({'RetreatStrategy': 8, 'RetaliateStrategy': 3, 'ExploitStrategy': 1})
# agents_respawned: Counter({'RetreatStrategy': 9, 'RetaliateStrategy': 3})
# agents_fallen: Counter({'RetreatStrategy': 2, 'RetaliateStrategy': 1})
# agents_respawned: Counter({'RetreatStrategy': 2, 'RetaliateStrategy': 1})
# agents_fallen: Counter({'RetreatStrategy': 5, 'RetaliateStrategy': 1})
# agents_respawned: Counter({'RetreatStrategy': 5, 'RetaliateStrategy': 1})
# agents_fallen: Counter({'RetreatStrategy': 8})
# agents_respawned: Counter({'RetreatStrategy': 6, 'RetaliateStrategy': 2})
# agents_fallen: Counter({'RetreatStrategy': 10, 'RetaliateStrategy': 1})
# agents_respawned: Counter({'RetreatStrategy': 7, 'RetaliateStrategy': 4})
# agents_fallen: Counter({'RetreatStrategy': 4, 'RetaliateStrategy': 1})
# agents_respawned: Counter({'RetreatStrategy': 3, 'RetaliateStrategy': 2})
# agents_fallen: Counter({'RetreatStrategy': 7, 'RetaliateStrategy': 1})
# agents_respawned: Counter({'RetreatStrategy': 6, 'RetaliateStrategy': 2})
# agents_fallen: Counter({'RetreatStrategy': 7, 'RetaliateStrategy': 3, 'ExploitStrategy': 1})
# agents_respawned: Counter({'RetreatStrategy': 7, 'RetaliateStrategy': 4})
# agents_fallen: Counter({'RetreatStrategy': 10, 'RetaliateStrategy': 3})
# agents_respawned: Counter({'RetreatStrategy': 10, 'RetaliateStrategy': 3})
# agents_fallen: Counter({'RetreatStrategy': 13, 'RetaliateStrategy': 2})
# agents_respawned: Counter({'RetreatStrategy': 11, 'RetaliateStrategy': 4})
# agents_fallen: Counter({'RetreatStrategy': 9})
# agents_respawned: Counter({'RetreatStrategy': 8, 'RetaliateStrategy': 1})
# agents_fallen: Counter({'RetreatStrategy': 9, 'RetaliateStrategy': 2})
# agents_respawned: Counter({'RetreatStrategy': 8, 'RetaliateStrategy': 3})
# agents_fallen: Counter({'RetreatStrategy': 15, 'ExploitStrategy': 1, 'RetaliateStrategy': 1})
# agents_respawned: Counter({'RetreatStrategy': 12, 'RetaliateStrategy': 5})
# agents_fallen: Counter({'RetreatStrategy': 4, 'RetaliateStrategy': 2})
# agents_respawned: Counter({'RetreatStrategy': 5, 'RetaliateStrategy': 1})
# agents_fallen: Counter({'RetreatStrategy': 12, 'RetaliateStrategy': 3})
# agents_respawned: Counter({'RetreatStrategy': 13, 'RetaliateStrategy': 2})
# agents_fallen: Counter({'RetreatStrategy': 10, 'RetaliateStrategy': 3, 'ExploitStrategy': 1})
# agents_respawned: Counter({'RetreatStrategy': 9, 'RetaliateStrategy': 5})
# agents_fallen: Counter({'RetreatStrategy': 8, 'RetaliateStrategy': 1})
# agents_respawned: Counter({'RetreatStrategy': 7, 'RetaliateStrategy': 2})
# agents_fallen: Counter({'RetreatStrategy': 6, 'RetaliateStrategy': 3})
# agents_respawned: Counter({'RetreatStrategy': 7, 'RetaliateStrategy': 2})
# agents_fallen: Counter({'RetreatStrategy': 8, 'ExploitStrategy': 1})
# agents_respawned: Counter({'RetreatStrategy': 7, 'RetaliateStrategy': 2})
# agents_fallen: Counter({'RetreatStrategy': 6, 'RetaliateStrategy': 1})
# agents_respawned: Counter({'RetreatStrategy': 6, 'RetaliateStrategy': 1})
# agents_fallen: Counter({'RetreatStrategy': 4, 'RetaliateStrategy': 2, 'ExploitStrategy': 1})
# agents_respawned: Counter({'RetreatStrategy': 5, 'RetaliateStrategy': 2})
# agents_fallen: Counter({'RetreatStrategy': 10, 'RetaliateStrategy': 2})
# agents_respawned: Counter({'RetreatStrategy': 10, 'RetaliateStrategy': 2})
# agents_fallen: Counter({'RetreatStrategy': 8, 'RetaliateStrategy': 3})
# agents_respawned: Counter({'RetreatStrategy': 9, 'RetaliateStrategy': 2})
# agents_fallen: Counter({'RetreatStrategy': 8, 'RetaliateStrategy': 1})
# agents_respawned: Counter({'RetreatStrategy': 7, 'RetaliateStrategy': 2})
# agents_fallen: Counter({'RetreatStrategy': 8, 'RetaliateStrategy': 3})
# agents_respawned: Counter({'RetreatStrategy': 8, 'RetaliateStrategy': 3})
# agents_fallen: Counter({'RetreatStrategy': 5, 'RetaliateStrategy': 1})
# agents_respawned: Counter({'RetreatStrategy': 5, 'RetaliateStrategy': 1})
# agents_fallen: Counter({'RetreatStrategy': 8, 'RetaliateStrategy': 3})
# agents_respawned: Counter({'RetreatStrategy': 7, 'RetaliateStrategy': 4})
# agents_fallen: Counter({'RetreatStrategy': 6})
# agents_respawned: Counter({'RetreatStrategy': 4, 'RetaliateStrategy': 2})
# agents_fallen: Counter({'RetreatStrategy': 7, 'RetaliateStrategy': 1})
# agents_respawned: Counter({'RetreatStrategy': 6, 'RetaliateStrategy': 1, 'ExploitStrategy': 1})
# agents_fallen: Counter({'RetreatStrategy': 5, 'RetaliateStrategy': 1})
# agents_respawned: Counter({'RetreatStrategy': 5, 'RetaliateStrategy': 1})
# agents_fallen: Counter({'RetreatStrategy': 8, 'RetaliateStrategy': 1})
# agents_respawned: Counter({'RetreatStrategy': 6, 'RetaliateStrategy': 3})
# agents_fallen: Counter({'RetreatStrategy': 7, 'RetaliateStrategy': 3})
# agents_respawned: Counter({'RetreatStrategy': 9, 'RetaliateStrategy': 1})
# agents_fallen: Counter({'RetreatStrategy': 13, 'RetaliateStrategy': 1})
# agents_respawned: Counter({'RetreatStrategy': 13, 'RetaliateStrategy': 1})
# agents_fallen: Counter({'RetreatStrategy': 11, 'RetaliateStrategy': 2})
# agents_respawned: Counter({'RetreatStrategy': 12, 'RetaliateStrategy': 1})
# agents_fallen: Counter({'RetreatStrategy': 4, 'RetaliateStrategy': 4})
# agents_respawned: Counter({'RetreatStrategy': 6, 'RetaliateStrategy': 2})
# agents_fallen: Counter({'RetreatStrategy': 6, 'RetaliateStrategy': 1})
# agents_respawned: Counter({'RetreatStrategy': 6, 'RetaliateStrategy': 1})
# agents_fallen: Counter({'RetreatStrategy': 9, 'RetaliateStrategy': 4})
# agents_respawned: Counter({'RetreatStrategy': 11, 'RetaliateStrategy': 2})
# agents_fallen: Counter({'RetreatStrategy': 4, 'RetaliateStrategy': 2})
# agents_respawned: Counter({'RetreatStrategy': 5, 'ExploitStrategy': 1})
# agents_fallen: Counter({'RetreatStrategy': 7, 'RetaliateStrategy': 2})
# agents_respawned: Counter({'RetreatStrategy': 5, 'RetaliateStrategy': 4})
# agents_fallen: Counter({'RetreatStrategy': 9, 'RetaliateStrategy': 3})
# agents_respawned: Counter({'RetreatStrategy': 9, 'RetaliateStrategy': 3})
# agents_fallen: Counter({'RetaliateStrategy': 7, 'RetreatStrategy': 4})
# agents_respawned: Counter({'RetreatStrategy': 9, 'RetaliateStrategy': 2})
# agents_fallen: Counter({'RetreatStrategy': 7, 'RetaliateStrategy': 2})
# agents_respawned: Counter({'RetreatStrategy': 8, 'RetaliateStrategy': 1})
# agents_fallen: Counter({'RetreatStrategy': 7, 'RetaliateStrategy': 4})
# agents_respawned: Counter({'RetreatStrategy': 9, 'RetaliateStrategy': 2})
# agents_fallen: Counter({'RetreatStrategy': 5, 'RetaliateStrategy': 5})
# agents_respawned: Counter({'RetreatStrategy': 9, 'RetaliateStrategy': 1})
# agents_fallen: Counter({'RetreatStrategy': 6, 'RetaliateStrategy': 3})
# agents_respawned: Counter({'RetreatStrategy': 8, 'AttackStrategy': 1})
# agents_fallen: Counter({'RetreatStrategy': 12, 'RetaliateStrategy': 1})
# agents_respawned: Counter({'RetreatStrategy': 11, 'RetaliateStrategy': 2})
# agents_fallen: Counter({'RetreatStrategy': 10, 'RetaliateStrategy': 4})
# agents_respawned: Counter({'RetreatStrategy': 11, 'RetaliateStrategy': 3})
# agents_fallen: Counter({'RetreatStrategy': 7, 'RetaliateStrategy': 1})
# agents_respawned: Counter({'RetreatStrategy': 7, 'RetaliateStrategy': 1})
# agents_fallen: Counter({'RetreatStrategy': 7, 'RetaliateStrategy': 2})
# agents_respawned: Counter({'RetreatStrategy': 9})
# agents_fallen: Counter({'RetreatStrategy': 7, 'RetaliateStrategy': 4})
# agents_respawned: Counter({'RetreatStrategy': 7, 'RetaliateStrategy': 4})
# agents_fallen: Counter({'RetreatStrategy': 8, 'RetaliateStrategy': 4})
# agents_respawned: Counter({'RetreatStrategy': 10, 'RetaliateStrategy': 2})
# agents_fallen: Counter({'RetreatStrategy': 11, 'RetaliateStrategy': 3})
# agents_respawned: Counter({'RetreatStrategy': 10, 'RetaliateStrategy': 4})
# agents_fallen: Counter({'RetreatStrategy': 13, 'RetaliateStrategy': 3})
# agents_respawned: Counter({'RetreatStrategy': 12, 'RetaliateStrategy': 4})
# agents_fallen: Counter({'RetreatStrategy': 6, 'RetaliateStrategy': 3})
# agents_respawned: Counter({'RetreatStrategy': 5, 'RetaliateStrategy': 3, 'AttackStrategy': 1})
# agents_fallen: Counter({'RetreatStrategy': 8, 'RetaliateStrategy': 6})
# agents_respawned: Counter({'RetreatStrategy': 11, 'RetaliateStrategy': 3})
# agents_fallen: Counter({'RetreatStrategy': 13, 'AttackStrategy': 1})
# agents_respawned: Counter({'RetreatStrategy': 10, 'RetaliateStrategy': 4})
# agents_fallen: Counter({'RetreatStrategy': 10, 'RetaliateStrategy': 5})
# agents_respawned: Counter({'RetreatStrategy': 13, 'RetaliateStrategy': 2})
# agents_fallen: Counter({'RetreatStrategy': 17, 'RetaliateStrategy': 5})
# agents_respawned: Counter({'RetreatStrategy': 19, 'RetaliateStrategy': 3})
# agents_fallen: Counter({'RetreatStrategy': 12, 'RetaliateStrategy': 6})
# agents_respawned: Counter({'RetreatStrategy': 14, 'RetaliateStrategy': 3, 'AttackStrategy': 1})
# agents_fallen: Counter({'RetreatStrategy': 5, 'ExploitStrategy': 1, 'RetaliateStrategy': 1})
# agents_respawned: Counter({'RetreatStrategy': 4, 'RetaliateStrategy': 3})
# agents_fallen: Counter({'RetaliateStrategy': 5, 'RetreatStrategy': 4})
# agents_respawned: Counter({'RetreatStrategy': 6, 'RetaliateStrategy': 3})
# agents_fallen: Counter({'RetreatStrategy': 14})
# agents_respawned: Counter({'RetreatStrategy': 11, 'RetaliateStrategy': 3})
# agents_fallen: Counter({'RetreatStrategy': 10})
# agents_respawned: Counter({'RetreatStrategy': 9, 'RetaliateStrategy': 1})
# agents_fallen: Counter({'RetreatStrategy': 7, 'RetaliateStrategy': 3})
# agents_respawned: Counter({'RetreatStrategy': 9, 'RetaliateStrategy': 1})
# agents_fallen: Counter({'RetreatStrategy': 11, 'RetaliateStrategy': 2})
# agents_respawned: Counter({'RetreatStrategy': 12, 'RetaliateStrategy': 1})
# agents_fallen: Counter({'RetreatStrategy': 6})
# agents_respawned: Counter({'RetreatStrategy': 4, 'RetaliateStrategy': 2})
# agents_fallen: Counter({'RetreatStrategy': 8, 'RetaliateStrategy': 2})
# agents_respawned: Counter({'RetreatStrategy': 6, 'RetaliateStrategy': 4})
# agents_fallen: Counter({'RetreatStrategy': 4, 'RetaliateStrategy': 3})
# agents_respawned: Counter({'RetaliateStrategy': 4, 'RetreatStrategy': 3})
# agents_fallen: Counter({'RetreatStrategy': 6, 'RetaliateStrategy': 3, 'ExploitStrategy': 1})
# agents_respawned: Counter({'RetreatStrategy': 9, 'RetaliateStrategy': 1})
# agents_fallen: Counter({'RetreatStrategy': 11, 'AttackStrategy': 1, 'RetaliateStrategy': 1})
# agents_respawned: Counter({'RetreatStrategy': 12, 'RetaliateStrategy': 1})
# agents_fallen: Counter({'RetreatStrategy': 5, 'RetaliateStrategy': 1})
# agents_respawned: Counter({'RetreatStrategy': 4, 'RetaliateStrategy': 2})
# agents_fallen: Counter({'RetreatStrategy': 10, 'RetaliateStrategy': 2})
# agents_respawned: Counter({'RetreatStrategy': 10, 'RetaliateStrategy': 2})
# agents_fallen: Counter({'RetreatStrategy': 4})
# agents_respawned: Counter({'RetreatStrategy': 3, 'RetaliateStrategy': 1})
# agents_fallen: Counter({'RetreatStrategy': 6, 'RetaliateStrategy': 1})
# agents_respawned: Counter({'RetreatStrategy': 4, 'RetaliateStrategy': 3})
# agents_fallen: Counter({'RetreatStrategy': 9})
# agents_respawned: Counter({'RetreatStrategy': 7, 'RetaliateStrategy': 2})
# agents_fallen: Counter({'RetreatStrategy': 11, 'RetaliateStrategy': 2})
# agents_respawned: Counter({'RetreatStrategy': 12, 'RetaliateStrategy': 1})
# agents_fallen: Counter({'RetreatStrategy': 8})
# agents_respawned: Counter({'RetreatStrategy': 7, 'RetaliateStrategy': 1})
# agents_fallen: Counter({'RetreatStrategy': 10, 'RetaliateStrategy': 2})
# agents_respawned: Counter({'RetreatStrategy': 9, 'RetaliateStrategy': 3})
# agents_fallen: Counter({'RetreatStrategy': 4})
# agents_respawned: Counter({'RetreatStrategy': 3, 'RetaliateStrategy': 1})
# agents_fallen: Counter({'RetreatStrategy': 7, 'RetaliateStrategy': 2})
# agents_respawned: Counter({'RetreatStrategy': 6, 'RetaliateStrategy': 3})
# agents_fallen: Counter({'RetreatStrategy': 6, 'RetaliateStrategy': 2})
# agents_respawned: Counter({'RetreatStrategy': 5, 'RetaliateStrategy': 3})
# agents_fallen: Counter({'RetreatStrategy': 14, 'RetaliateStrategy': 1})
# agents_respawned: Counter({'RetreatStrategy': 12, 'RetaliateStrategy': 3})
# agents_fallen: Counter({'RetreatStrategy': 8})
# ...
# agents_fallen: Counter({'RetreatStrategy': 10, 'RetaliateStrategy': 4})
# agents_respawned: Counter({'RetreatStrategy': 12, 'RetaliateStrategy': 2})
# agents_fallen: Counter({'RetreatStrategy': 7})
# agents_respawned: Counter({'RetreatStrategy': 7})
# agents_fallen: Counter({'RetreatStrategy': 5})
# agents_respawned: Counter({'RetreatStrategy': 5})
# agents_fallen: Counter({'RetreatStrategy': 5, 'RetaliateStrategy': 1})
# agents_respawned: Counter({'RetreatStrategy': 5, 'RetaliateStrategy': 1})
# agents_fallen: Counter({'RetreatStrategy': 5, 'RetaliateStrategy': 1})
# agents_respawned: Counter({'RetreatStrategy': 6})
# agents_fallen: Counter({'RetreatStrategy': 6, 'RetaliateStrategy': 1})
# agents_respawned: Counter({'RetaliateStrategy': 4, 'RetreatStrategy': 3})
# agents_fallen: Counter({'RetreatStrategy': 12, 'RetaliateStrategy': 4})
# agents_respawned: Counter({'RetreatStrategy': 14, 'RetaliateStrategy': 2})
# agents_fallen: Counter({'RetreatStrategy': 5, 'RetaliateStrategy': 1})
# agents_respawned: Counter({'RetreatStrategy': 5, 'RetaliateStrategy': 1})
# agents_fallen: Counter({'RetreatStrategy': 5, 'RetaliateStrategy': 2})
# agents_respawned: Counter({'RetreatStrategy': 6, 'RetaliateStrategy': 1})
# agents_fallen: Counter({'RetreatStrategy': 7, 'RetaliateStrategy': 1})
# agents_respawned: Counter({'RetreatStrategy': 7, 'RetaliateStrategy': 1})
# agents_fallen: Counter({'RetreatStrategy': 7})
# agents_respawned: Counter({'RetreatStrategy': 6, 'RetaliateStrategy': 1})
# agents_fallen: Counter({'RetreatStrategy': 9, 'RetaliateStrategy': 2})
# agents_respawned: Counter({'RetreatStrategy': 11})
# agents_fallen: Counter({'RetreatStrategy': 7})
# agents_respawned: Counter({'RetreatStrategy': 4, 'RetaliateStrategy': 3})
# agents_fallen: Counter({'RetreatStrategy': 9, 'RetaliateStrategy': 1})
# agents_respawned: Counter({'RetreatStrategy': 10})
# agents_fallen: Counter({'RetreatStrategy': 11, 'RetaliateStrategy': 1})
# agents_respawned: Counter({'RetreatStrategy': 11, 'RetaliateStrategy': 1})
# agents_fallen: Counter({'RetreatStrategy': 7, 'RetaliateStrategy': 2})
# agents_respawned: Counter({'RetreatStrategy': 6, 'RetaliateStrategy': 3})
# agents_fallen: Counter({'RetreatStrategy': 8})
# agents_respawned: Counter({'RetreatStrategy': 7, 'RetaliateStrategy': 1})
# agents_fallen: Counter({'RetreatStrategy': 6, 'RetaliateStrategy': 5})
# agents_respawned: Counter({'RetreatStrategy': 8, 'RetaliateStrategy': 3})
# agents_fallen: Counter({'RetreatStrategy': 11, 'RetaliateStrategy': 1})
# agents_respawned: Counter({'RetreatStrategy': 7, 'RetaliateStrategy': 5})
# agents_fallen: Counter({'RetreatStrategy': 9})
# agents_respawned: Counter({'RetreatStrategy': 8, 'RetaliateStrategy': 1})
# agents_fallen: Counter({'RetreatStrategy': 8, 'RetaliateStrategy': 2})
# agents_respawned: Counter({'RetreatStrategy': 8, 'RetaliateStrategy': 2})
# agents_fallen: Counter({'RetreatStrategy': 7, 'RetaliateStrategy': 1})
# agents_respawned: Counter({'RetreatStrategy': 8})
# agents_fallen: Counter({'RetaliateStrategy': 5, 'RetreatStrategy': 5})
# agents_respawned: Counter({'RetreatStrategy': 8, 'RetaliateStrategy': 2})
# agents_fallen: Counter({'RetreatStrategy': 9, 'RetaliateStrategy': 1})
# agents_respawned: Counter({'RetreatStrategy': 8, 'RetaliateStrategy': 2})
# agents_fallen: Counter({'RetreatStrategy': 7, 'RetaliateStrategy': 2})
# agents_respawned: Counter({'RetreatStrategy': 7, 'RetaliateStrategy': 2})
# agents_fallen: Counter({'RetreatStrategy': 4, 'RetaliateStrategy': 2})
# agents_respawned: Counter({'RetreatStrategy': 5, 'RetaliateStrategy': 1})
# agents_fallen: Counter({'RetreatStrategy': 6})
# agents_respawned: Counter({'RetreatStrategy': 6})
# agents_fallen: Counter({'RetreatStrategy': 9, 'RetaliateStrategy': 1})
# agents_respawned: Counter({'RetreatStrategy': 7, 'RetaliateStrategy': 3})
# agents_fallen: Counter({'RetreatStrategy': 5, 'RetaliateStrategy': 1})
# agents_respawned: Counter({'RetreatStrategy': 4, 'RetaliateStrategy': 2})
# agents_fallen: Counter({'RetreatStrategy': 10})
# agents_respawned: Counter({'RetreatStrategy': 9, 'RetaliateStrategy': 1})
# agents_fallen: Counter({'RetreatStrategy': 11, 'RetaliateStrategy': 2})
# agents_respawned: Counter({'RetreatStrategy': 11, 'RetaliateStrategy': 2})
# agents_fallen: Counter({'RetreatStrategy': 6, 'RetaliateStrategy': 2})
# agents_respawned: Counter({'RetreatStrategy': 6, 'RetaliateStrategy': 2})
# agents_fallen: Counter({'RetreatStrategy': 9, 'RetaliateStrategy': 1})
# agents_respawned: Counter({'RetreatStrategy': 8, 'RetaliateStrategy': 2})
# agents_fallen: Counter({'RetreatStrategy': 15, 'RetaliateStrategy': 1, 'ExploitStrategy': 1})
# agents_respawned: Counter({'RetreatStrategy': 15, 'RetaliateStrategy': 2})
# agents_fallen: Counter({'RetreatStrategy': 9, 'RetaliateStrategy': 2})
# agents_respawned: Counter({'RetreatStrategy': 11})
# agents_fallen: Counter({'RetreatStrategy': 13})
# agents_respawned: Counter({'RetreatStrategy': 9, 'RetaliateStrategy': 4})
# agents_fallen: Counter({'RetreatStrategy': 8, 'RetaliateStrategy': 1})
# agents_respawned: Counter({'RetreatStrategy': 9})
# agents_fallen: Counter({'RetreatStrategy': 11, 'RetaliateStrategy': 1})
# agents_respawned: Counter({'RetreatStrategy': 11, 'RetaliateStrategy': 1})
# agents_fallen: Counter({'RetreatStrategy': 9, 'RetaliateStrategy': 2})
# agents_respawned: Counter({'RetreatStrategy': 8, 'RetaliateStrategy': 3})
# agents_fallen: Counter({'RetreatStrategy': 9, 'RetaliateStrategy': 1})
# agents_respawned: Counter({'RetreatStrategy': 9, 'RetaliateStrategy': 1})
# agents_fallen: Counter({'RetreatStrategy': 3, 'RetaliateStrategy': 1})
# agents_respawned: Counter({'RetaliateStrategy': 2, 'RetreatStrategy': 2})
# agents_fallen: Counter({'RetreatStrategy': 13})
# agents_respawned: Counter({'RetreatStrategy': 13})
# agents_fallen: Counter({'RetreatStrategy': 11, 'RetaliateStrategy': 4})
# agents_respawned: Counter({'RetreatStrategy': 12, 'RetaliateStrategy': 3})
# agents_fallen: Counter({'RetreatStrategy': 8, 'RetaliateStrategy': 1})
# agents_respawned: Counter({'RetreatStrategy': 8, 'RetaliateStrategy': 1})
# agents_fallen: Counter({'RetreatStrategy': 8, 'RetaliateStrategy': 1})
# agents_respawned: Counter({'RetreatStrategy': 9})
# agents_fallen: Counter({'RetreatStrategy': 11, 'RetaliateStrategy': 1})
# agents_respawned: Counter({'RetreatStrategy': 10, 'RetaliateStrategy': 2})
# agents_fallen: Counter({'RetreatStrategy': 10, 'RetaliateStrategy': 2})
# agents_respawned: Counter({'RetreatStrategy': 10, 'RetaliateStrategy': 2})
# agents_fallen: Counter({'RetreatStrategy': 8, 'RetaliateStrategy': 2})
# agents_respawned: Counter({'RetreatStrategy': 9, 'RetaliateStrategy': 1})
# agents_fallen: Counter({'RetreatStrategy': 8, 'RetaliateStrategy': 1})
# agents_respawned: Counter({'RetreatStrategy': 9})
# agents_fallen: Counter({'RetreatStrategy': 8, 'RetaliateStrategy': 1})
# agents_respawned: Counter({'RetreatStrategy': 8, 'RetaliateStrategy': 1})
# agents_fallen: Counter({'RetreatStrategy': 10})
# agents_respawned: Counter({'RetreatStrategy': 7, 'RetaliateStrategy': 3})
# agents_fallen: Counter({'RetreatStrategy': 5, 'RetaliateStrategy': 2})
# agents_respawned: Counter({'RetreatStrategy': 7})
# agents_fallen: Counter({'RetreatStrategy': 9, 'RetaliateStrategy': 3})
# agents_respawned: Counter({'RetreatStrategy': 11, 'RetaliateStrategy': 1})
# agents_fallen: Counter({'RetreatStrategy': 9, 'RetaliateStrategy': 1})
# agents_respawned: Counter({'RetreatStrategy': 8, 'RetaliateStrategy': 2})
# agents_fallen: Counter({'RetreatStrategy': 11, 'RetaliateStrategy': 1})
# agents_respawned: Counter({'RetreatStrategy': 12})
# agents_fallen: Counter({'RetreatStrategy': 9})
# agents_respawned: Counter({'RetreatStrategy': 8, 'RetaliateStrategy': 1})
# agents_fallen: Counter({'RetreatStrategy': 8, 'RetaliateStrategy': 3})
# agents_respawned: Counter({'RetreatStrategy': 8, 'RetaliateStrategy': 3})
# agents_fallen: Counter({'RetreatStrategy': 13})
# agents_respawned: Counter({'RetreatStrategy': 13})
# agents_fallen: Counter({'RetreatStrategy': 12, 'RetaliateStrategy': 2})
# agents_respawned: Counter({'RetreatStrategy': 11, 'RetaliateStrategy': 3})
# agents_fallen: Counter({'RetreatStrategy': 12, 'RetaliateStrategy': 3})
# agents_respawned: Counter({'RetreatStrategy': 13, 'RetaliateStrategy': 2})
# agents_fallen: Counter({'RetreatStrategy': 10, 'RetaliateStrategy': 3})
# agents_respawned: Counter({'RetreatStrategy': 9, 'RetaliateStrategy': 4})
# agents_fallen: Counter({'RetreatStrategy': 6, 'RetaliateStrategy': 2})
# agents_respawned: Counter({'RetreatStrategy': 8})
# agents_fallen: Counter({'RetreatStrategy': 5})
# agents_respawned: Counter({'RetreatStrategy': 3, 'RetaliateStrategy': 2})
# agents_fallen: Counter({'RetreatStrategy': 12, 'RetaliateStrategy': 2})
# agents_respawned: Counter({'RetreatStrategy': 12, 'ExploitStrategy': 1, 'RetaliateStrategy': 1})
# agents_fallen: Counter({'RetreatStrategy': 10, 'RetaliateStrategy': 2})
# agents_respawned: Counter({'RetreatStrategy': 9, 'RetaliateStrategy': 3})
# agents_fallen: Counter({'RetreatStrategy': 9, 'RetaliateStrategy': 2})
# agents_respawned: Counter({'RetreatStrategy': 9, 'RetaliateStrategy': 2})
# agents_fallen: Counter({'RetreatStrategy': 10, 'RetaliateStrategy': 1})
# agents_respawned: Counter({'RetreatStrategy': 9, 'RetaliateStrategy': 2})
# agents_fallen: Counter({'RetreatStrategy': 7})
# agents_respawned: Counter({'RetreatStrategy': 5, 'RetaliateStrategy': 2})
# agents_fallen: Counter({'RetreatStrategy': 7, 'RetaliateStrategy': 2})
# agents_respawned: Counter({'RetreatStrategy': 8, 'RetaliateStrategy': 1})
# agents_fallen: Counter({'RetreatStrategy': 6})
# agents_respawned: Counter({'RetreatStrategy': 6})
# agents_fallen: Counter({'RetreatStrategy': 8, 'RetaliateStrategy': 2})
# agents_respawned: Counter({'RetreatStrategy': 8, 'RetaliateStrategy': 2})
# agents_fallen: Counter({'RetreatStrategy': 10, 'RetaliateStrategy': 3})
# agents_respawned: Counter({'RetreatStrategy': 12, 'RetaliateStrategy': 1})
# agents_fallen: Counter({'RetreatStrategy': 5, 'RetaliateStrategy': 3})
# agents_respawned: Counter({'RetreatStrategy': 6, 'RetaliateStrategy': 2})
# agents_fallen: Counter({'RetreatStrategy': 13, 'RetaliateStrategy': 1})
# agents_respawned: Counter({'RetreatStrategy': 12, 'RetaliateStrategy': 1, 'ExploitStrategy': 1})
# agents_fallen: Counter({'RetreatStrategy': 6})
# agents_respawned: Counter({'RetreatStrategy': 6})
# agents_fallen: Counter({'RetreatStrategy': 7, 'RetaliateStrategy': 1})
# agents_respawned: Counter({'RetreatStrategy': 8})
# agents_fallen: Counter({'RetreatStrategy': 9, 'RetaliateStrategy': 1})
# agents_respawned: Counter({'RetreatStrategy': 9, 'RetaliateStrategy': 1})
# agents_fallen: Counter({'RetreatStrategy': 10, 'RetaliateStrategy': 1})
# agents_respawned: Counter({'RetreatStrategy': 10, 'RetaliateStrategy': 1})
# agents_fallen: Counter({'RetreatStrategy': 6, 'RetaliateStrategy': 1})
# agents_respawned: Counter({'RetreatStrategy': 7})
# agents_fallen: Counter({'RetreatStrategy': 8, 'RetaliateStrategy': 3})
# agents_respawned: Counter({'RetreatStrategy': 11})
# agents_fallen: Counter({'RetreatStrategy': 10, 'RetaliateStrategy': 3})
# agents_respawned: Counter({'RetreatStrategy': 12, 'RetaliateStrategy': 1})
# agents_fallen: Counter({'RetreatStrategy': 8})
# agents_respawned: Counter({'RetreatStrategy': 6, 'RetaliateStrategy': 2})
# agents_fallen: Counter({'RetreatStrategy': 11, 'RetaliateStrategy': 3})
# agents_respawned: Counter({'RetreatStrategy': 12, 'RetaliateStrategy': 2})
# agents_fallen: Counter({'RetreatStrategy': 15})
# agents_respawned: Counter({'RetreatStrategy': 13, 'RetaliateStrategy': 2})
# agents_fallen: Counter({'RetreatStrategy': 9})
# agents_respawned: Counter({'RetreatStrategy': 8, 'RetaliateStrategy': 1})
# agents_fallen: Counter({'RetreatStrategy': 8, 'RetaliateStrategy': 1})
# agents_respawned: Counter({'RetreatStrategy': 6, 'RetaliateStrategy': 3})
# agents_fallen: Counter({'RetreatStrategy': 5})
# agents_respawned: Counter({'RetreatStrategy': 5})
# agents_fallen: Counter({'RetreatStrategy': 11, 'RetaliateStrategy': 2})
# agents_respawned: Counter({'RetreatStrategy': 12, 'RetaliateStrategy': 1})
# agents_fallen: Counter({'RetreatStrategy': 7, 'RetaliateStrategy': 2})
# agents_respawned: Counter({'RetreatStrategy': 8, 'RetaliateStrategy': 1})
# agents_fallen: Counter({'RetreatStrategy': 10, 'RetaliateStrategy': 1})
# agents_respawned: Counter({'RetreatStrategy': 9, 'RetaliateStrategy': 2})
# agents_fallen: Counter({'RetreatStrategy': 6, 'RetaliateStrategy': 3})
# agents_respawned: Counter({'RetreatStrategy': 9})
# agents_fallen: Counter({'RetreatStrategy': 7, 'RetaliateStrategy': 2})
# agents_respawned: Counter({'RetreatStrategy': 7, 'RetaliateStrategy': 2})
# agents_fallen: Counter({'RetreatStrategy': 9, 'RetaliateStrategy': 1})
# agents_respawned: Counter({'RetreatStrategy': 9, 'RetaliateStrategy': 1})
# agents_fallen: Counter({'RetreatStrategy': 13, 'RetaliateStrategy': 2})
# agents_respawned: Counter({'RetreatStrategy': 13, 'RetaliateStrategy': 2})
# agents_fallen: Counter({'RetreatStrategy': 13})
# agents_respawned: Counter({'RetreatStrategy': 12, 'RetaliateStrategy': 1})
# agents_fallen: Counter({'RetreatStrategy': 14, 'RetaliateStrategy': 2})
# agents_respawned: Counter({'RetreatStrategy': 15, 'RetaliateStrategy': 1})
# agents_fallen: Counter({'RetreatStrategy': 9, 'RetaliateStrategy': 3})
# agents_respawned: Counter({'RetreatStrategy': 10, 'RetaliateStrategy': 2})
# agents_fallen: Counter({'RetreatStrategy': 13, 'RetaliateStrategy': 3})
# agents_respawned: Counter({'RetreatStrategy': 13, 'RetaliateStrategy': 3})
# agents_fallen: Counter({'RetreatStrategy': 7})
# agents_respawned: Counter({'RetreatStrategy': 7})
# agents_fallen: Counter({'RetreatStrategy': 9, 'RetaliateStrategy': 1})
# agents_respawned: Counter({'RetreatStrategy': 9, 'RetaliateStrategy': 1})
# agents_fallen: Counter({'RetreatStrategy': 5, 'RetaliateStrategy': 2})
# agents_respawned: Counter({'RetreatStrategy': 5, 'RetaliateStrategy': 2})
# agents_fallen: Counter({'RetreatStrategy': 13, 'RetaliateStrategy': 2})
# agents_respawned: Counter({'RetreatStrategy': 15})
# agents_fallen: Counter({'RetreatStrategy': 6})
# agents_respawned: Counter({'RetreatStrategy': 5, 'RetaliateStrategy': 1})
# agents_fallen: Counter({'RetreatStrategy': 5})
# agents_respawned: Counter({'RetreatStrategy': 5})
# agents_fallen: Counter({'RetreatStrategy': 2, 'RetaliateStrategy': 1})
# agents_respawned: Counter({'RetreatStrategy': 3})
# agents_fallen: Counter({'RetreatStrategy': 6})
# agents_respawned: Counter({'RetreatStrategy': 6})
# agents_fallen: Counter({'RetreatStrategy': 3, 'RetaliateStrategy': 3, 'ExploitStrategy': 1})
# agents_respawned: Counter({'RetreatStrategy': 5, 'RetaliateStrategy': 2})
# agents_fallen: Counter({'RetreatStrategy': 13, 'RetaliateStrategy': 1})
# agents_respawned: Counter({'RetreatStrategy': 11, 'RetaliateStrategy': 3})
# agents_fallen: Counter({'RetreatStrategy': 7, 'RetaliateStrategy': 1})
# agents_respawned: Counter({'RetreatStrategy': 7, 'RetaliateStrategy': 1})
# agents_fallen: Counter({'RetreatStrategy': 6, 'RetaliateStrategy': 1})
# agents_respawned: Counter({'RetreatStrategy': 6, 'RetaliateStrategy': 1})
# agents_fallen: Counter({'RetreatStrategy': 7, 'RetaliateStrategy': 1})
# agents_respawned: Counter({'RetreatStrategy': 7, 'RetaliateStrategy': 1})
# agents_fallen: Counter({'RetreatStrategy': 7, 'RetaliateStrategy': 1, 'ExploitStrategy': 1})
# agents_respawned: Counter({'RetreatStrategy': 8, 'RetaliateStrategy': 1})
# agents_fallen: Counter({'RetreatStrategy': 10})
# agents_respawned: Counter({'RetreatStrategy': 7, 'RetaliateStrategy': 3})
# agents_fallen: Counter({'RetreatStrategy': 4, 'RetaliateStrategy': 3})
# agents_respawned: Counter({'RetreatStrategy': 5, 'RetaliateStrategy': 2})
# agents_fallen: Counter({'RetreatStrategy': 9})
# agents_respawned: Counter({'RetreatStrategy': 7, 'RetaliateStrategy': 2})
# agents_fallen: Counter({'RetreatStrategy': 10, 'RetaliateStrategy': 1})
# agents_respawned: Counter({'RetreatStrategy': 7, 'RetaliateStrategy': 3, 'ExploitStrategy': 1})
# agents_fallen: Counter({'RetreatStrategy': 6, 'RetaliateStrategy': 4})
# agents_respawned: Counter({'RetreatStrategy': 7, 'RetaliateStrategy': 3})
# agents_fallen: Counter({'RetreatStrategy': 7, 'RetaliateStrategy': 1})
# agents_respawned: Counter({'RetreatStrategy': 7, 'RetaliateStrategy': 1})

# %%
[a.strategy for a in env.state.game_rounds[-1][0].agents]
# Out:
# [creatures.simulate.RetreatStrategy, creatures.simulate.RetreatStrategy]

# %%
[a.state.moves[-1] for a in env.state.game_rounds[-1][0].agents]
# Out:
# [[('retreat', False)], [('retreat', True)]]

# %%
env.state.game_rounds[-1][0].state.moves
# Out:
# [('retreat', False), ('retreat', True)]
