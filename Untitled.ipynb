# %%
from creatures.simulate import *

# %%
main(save_path="/tmp/environment.pickle")

# %%
env = Environment.load("/tmp/environment.pickle")

# %%
len(env.state.hp_by_strategy)
# Out:
# 1000

# %%
env.state.hp_by_strategy[0]
# Out:
# {'AttackStrategy': 13685,
#  'RetreatStrategy': 23440,
#  'RetaliateStrategy': 13326,
#  'ExploitStrategy': 23270}

# %%
env.state.hp_by_strategy[-1]
# Out:
# {'AttackStrategy': 10211,
#  'RetreatStrategy': 0,
#  'RetaliateStrategy': 0,
#  'ExploitStrategy': 43795}

# %%
env.state.xp_by_strategy[0]
# Out:
# {'AttackStrategy': 4806,
#  'RetreatStrategy': 1467,
#  'RetaliateStrategy': 4434,
#  'ExploitStrategy': 1649}

# %%
env.state.xp_by_strategy[-1]
# Out:
# {'AttackStrategy': 12647,
#  'RetreatStrategy': 0,
#  'RetaliateStrategy': 0,
#  'ExploitStrategy': 46437}

# %%
env.state.population_by_strategy[0]
# Out:
# {'AttackStrategy': 250,
#  'RetreatStrategy': 250,
#  'RetaliateStrategy': 250,
#  'ExploitStrategy': 250}

# %%
env.state.population_by_strategy
# Out:
# [{'AttackStrategy': 250,
#   'RetreatStrategy': 250,
#   'RetaliateStrategy': 250,
#   'ExploitStrategy': 250},
#  {'AttackStrategy': 233,
#   'RetreatStrategy': 266,
#   'RetaliateStrategy': 230,
#   'ExploitStrategy': 271},
#  {'AttackStrategy': 212,
#   'RetreatStrategy': 275,
#   'RetaliateStrategy': 214,
#   'ExploitStrategy': 299},
#  {'AttackStrategy': 180,
#   'RetreatStrategy': 290,
#   'RetaliateStrategy': 210,
#   'ExploitStrategy': 320},
#  {'AttackStrategy': 174,
#   'RetreatStrategy': 304,
#   'RetaliateStrategy': 187,
#   'ExploitStrategy': 335},
#  {'AttackStrategy': 164,
#   'RetreatStrategy': 311,
#   'RetaliateStrategy': 176,
#   'ExploitStrategy': 349},
#  {'AttackStrategy': 151,
#   'RetreatStrategy': 329,
#   'RetaliateStrategy': 155,
#   'ExploitStrategy': 365},
#  {'AttackStrategy': 140,
#   'RetreatStrategy': 334,
#   'RetaliateStrategy': 148,
#   'ExploitStrategy': 378},
#  {'AttackStrategy': 130,
#   'RetreatStrategy': 334,
#   'RetaliateStrategy': 143,
#   'ExploitStrategy': 393},
#  {'AttackStrategy': 130,
#   'RetreatStrategy': 335,
#   'RetaliateStrategy': 132,
#   'ExploitStrategy': 403},
#  {'AttackStrategy': 126,
#   'RetreatStrategy': 341,
#   'RetaliateStrategy': 122,
#   'ExploitStrategy': 411},
#  {'AttackStrategy': 116,
#   'RetreatStrategy': 349,
#   'RetaliateStrategy': 116,
#   'ExploitStrategy': 419},
#  {'AttackStrategy': 112,
#   'RetreatStrategy': 352,
#   'RetaliateStrategy': 104,
#   'ExploitStrategy': 432},
#  {'AttackStrategy': 106,
#   'RetreatStrategy': 355,
#   'RetaliateStrategy': 97,
#   'ExploitStrategy': 442},
#  {'AttackStrategy': 101,
#   'RetreatStrategy': 353,
#   'RetaliateStrategy': 94,
#   'ExploitStrategy': 452},
#  {'AttackStrategy': 104,
#   'RetreatStrategy': 350,
#   'RetaliateStrategy': 85,
#   'ExploitStrategy': 461},
#  {'AttackStrategy': 99,
#   'RetreatStrategy': 342,
#   'RetaliateStrategy': 82,
#   'ExploitStrategy': 477},
#  {'AttackStrategy': 102,
#   'RetreatStrategy': 336,
#   'RetaliateStrategy': 75,
#   'ExploitStrategy': 487},
#  {'AttackStrategy': 95,
#   'RetreatStrategy': 327,
#   'RetaliateStrategy': 73,
#   'ExploitStrategy': 505},
#  {'AttackStrategy': 94,
#   'RetreatStrategy': 317,
#   'RetaliateStrategy': 76,
#   'ExploitStrategy': 513},
#  {'AttackStrategy': 91,
#   'RetreatStrategy': 312,
#   'RetaliateStrategy': 73,
#   'ExploitStrategy': 524},
#  {'AttackStrategy': 83,
#   'RetreatStrategy': 311,
#   'RetaliateStrategy': 71,
#   'ExploitStrategy': 535},
#  {'AttackStrategy': 83,
#   'RetreatStrategy': 311,
#   'RetaliateStrategy': 66,
#   'ExploitStrategy': 540},
#  {'AttackStrategy': 81,
#   'RetreatStrategy': 303,
#   'RetaliateStrategy': 65,
#   'ExploitStrategy': 551},
#  {'AttackStrategy': 77,
#   'RetreatStrategy': 303,
#   'RetaliateStrategy': 60,
#   'ExploitStrategy': 560},
#  {'AttackStrategy': 73,
#   'RetreatStrategy': 300,
#   'RetaliateStrategy': 59,
#   'ExploitStrategy': 568},
#  {'AttackStrategy': 79,
#   'RetreatStrategy': 296,
#   'RetaliateStrategy': 59,
#   'ExploitStrategy': 566},
#  {'AttackStrategy': 81,
#   'RetreatStrategy': 280,
#   'RetaliateStrategy': 55,
#   'ExploitStrategy': 584},
#  {'AttackStrategy': 76,
#   'RetreatStrategy': 269,
#   'RetaliateStrategy': 55,
#   'ExploitStrategy': 600},
#  {'AttackStrategy': 76,
#   'RetreatStrategy': 258,
#   'RetaliateStrategy': 54,
#   'ExploitStrategy': 612},
#  {'AttackStrategy': 76,
#   'RetreatStrategy': 254,
#   'RetaliateStrategy': 53,
#   'ExploitStrategy': 617},
#  {'AttackStrategy': 76,
#   'RetreatStrategy': 249,
#   'RetaliateStrategy': 53,
#   'ExploitStrategy': 622},
#  {'AttackStrategy': 76,
#   'RetreatStrategy': 242,
#   'RetaliateStrategy': 50,
#   'ExploitStrategy': 632},
#  {'AttackStrategy': 74,
#   'RetreatStrategy': 236,
#   'RetaliateStrategy': 48,
#   'ExploitStrategy': 642},
#  {'AttackStrategy': 74,
#   'RetreatStrategy': 230,
#   'RetaliateStrategy': 42,
#   'ExploitStrategy': 654},
#  {'AttackStrategy': 76,
#   'RetreatStrategy': 225,
#   'RetaliateStrategy': 40,
#   'ExploitStrategy': 659},
#  {'AttackStrategy': 79,
#   'RetreatStrategy': 215,
#   'RetaliateStrategy': 37,
#   'ExploitStrategy': 669},
#  {'AttackStrategy': 78,
#   'RetreatStrategy': 207,
#   'RetaliateStrategy': 39,
#   'ExploitStrategy': 676},
#  {'AttackStrategy': 84,
#   'RetreatStrategy': 202,
#   'RetaliateStrategy': 39,
#   'ExploitStrategy': 675},
#  {'AttackStrategy': 87,
#   'RetreatStrategy': 203,
#   'RetaliateStrategy': 36,
#   'ExploitStrategy': 674},
#  {'AttackStrategy': 82,
#   'RetreatStrategy': 198,
#   'RetaliateStrategy': 32,
#   'ExploitStrategy': 688},
#  {'AttackStrategy': 80,
#   'RetreatStrategy': 193,
#   'RetaliateStrategy': 34,
#   'ExploitStrategy': 693},
#  {'AttackStrategy': 81,
#   'RetreatStrategy': 190,
#   'RetaliateStrategy': 35,
#   'ExploitStrategy': 694},
#  {'AttackStrategy': 88,
#   'RetreatStrategy': 186,
#   'RetaliateStrategy': 32,
#   'ExploitStrategy': 694},
#  {'AttackStrategy': 92,
#   'RetreatStrategy': 183,
#   'RetaliateStrategy': 30,
#   'ExploitStrategy': 695},
#  {'AttackStrategy': 91,
#   'RetreatStrategy': 178,
#   'RetaliateStrategy': 29,
#   'ExploitStrategy': 702},
#  {'AttackStrategy': 90,
#   'RetreatStrategy': 164,
#   'RetaliateStrategy': 30,
#   'ExploitStrategy': 716},
#  {'AttackStrategy': 95,
#   'RetreatStrategy': 150,
#   'RetaliateStrategy': 27,
#   'ExploitStrategy': 728},
#  {'AttackStrategy': 95,
#   'RetreatStrategy': 139,
#   'RetaliateStrategy': 28,
#   'ExploitStrategy': 738},
#  {'AttackStrategy': 101,
#   'RetreatStrategy': 131,
#   'RetaliateStrategy': 26,
#   'ExploitStrategy': 742},
#  {'AttackStrategy': 102,
#   'RetreatStrategy': 129,
#   'RetaliateStrategy': 23,
#   'ExploitStrategy': 746},
#  {'AttackStrategy': 101,
#   'RetreatStrategy': 129,
#   'RetaliateStrategy': 23,
#   'ExploitStrategy': 747},
#  {'AttackStrategy': 96,
#   'RetreatStrategy': 127,
#   'RetaliateStrategy': 25,
#   'ExploitStrategy': 752},
#  {'AttackStrategy': 102,
#   'RetreatStrategy': 127,
#   'RetaliateStrategy': 25,
#   'ExploitStrategy': 746},
#  {'AttackStrategy': 108,
#   'RetreatStrategy': 118,
#   'RetaliateStrategy': 22,
#   'ExploitStrategy': 752},
#  {'AttackStrategy': 113,
#   'RetreatStrategy': 115,
#   'RetaliateStrategy': 20,
#   'ExploitStrategy': 752},
#  {'AttackStrategy': 122,
#   'RetreatStrategy': 106,
#   'RetaliateStrategy': 20,
#   'ExploitStrategy': 752},
#  {'AttackStrategy': 117,
#   'RetreatStrategy': 99,
#   'RetaliateStrategy': 17,
#   'ExploitStrategy': 767},
#  {'AttackStrategy': 121,
#   'RetreatStrategy': 90,
#   'RetaliateStrategy': 15,
#   'ExploitStrategy': 774},
#  {'AttackStrategy': 119,
#   'RetreatStrategy': 81,
#   'RetaliateStrategy': 18,
#   'ExploitStrategy': 782},
#  {'AttackStrategy': 128,
#   'RetreatStrategy': 74,
#   'RetaliateStrategy': 17,
#   'ExploitStrategy': 781},
#  {'AttackStrategy': 130,
#   'RetreatStrategy': 65,
#   'RetaliateStrategy': 18,
#   'ExploitStrategy': 787},
#  {'AttackStrategy': 128,
#   'RetreatStrategy': 59,
#   'RetaliateStrategy': 18,
#   'ExploitStrategy': 795},
#  {'AttackStrategy': 122,
#   'RetreatStrategy': 57,
#   'RetaliateStrategy': 16,
#   'ExploitStrategy': 805},
#  {'AttackStrategy': 124,
#   'RetreatStrategy': 54,
#   'RetaliateStrategy': 15,
#   'ExploitStrategy': 807},
#  {'AttackStrategy': 122,
#   'RetreatStrategy': 48,
#   'RetaliateStrategy': 16,
#   'ExploitStrategy': 814},
#  {'AttackStrategy': 122,
#   'RetreatStrategy': 46,
#   'RetaliateStrategy': 16,
#   'ExploitStrategy': 816},
#  {'AttackStrategy': 127,
#   'RetreatStrategy': 47,
#   'RetaliateStrategy': 15,
#   'ExploitStrategy': 811},
#  {'AttackStrategy': 131,
#   'RetreatStrategy': 44,
#   'RetaliateStrategy': 14,
#   'ExploitStrategy': 811},
#  {'AttackStrategy': 134,
#   'RetreatStrategy': 44,
#   'RetaliateStrategy': 12,
#   'ExploitStrategy': 810},
#  {'AttackStrategy': 131,
#   'RetreatStrategy': 43,
#   'RetaliateStrategy': 11,
#   'ExploitStrategy': 815},
#  {'AttackStrategy': 128,
#   'RetreatStrategy': 40,
#   'RetaliateStrategy': 10,
#   'ExploitStrategy': 822},
#  {'AttackStrategy': 133,
#   'RetreatStrategy': 34,
#   'RetaliateStrategy': 12,
#   'ExploitStrategy': 821},
#  {'AttackStrategy': 133,
#   'RetreatStrategy': 25,
#   'RetaliateStrategy': 12,
#   'ExploitStrategy': 830},
#  {'AttackStrategy': 131,
#   'RetreatStrategy': 24,
#   'RetaliateStrategy': 10,
#   'ExploitStrategy': 835},
#  {'AttackStrategy': 132,
#   'RetreatStrategy': 24,
#   'RetaliateStrategy': 10,
#   'ExploitStrategy': 834},
#  {'AttackStrategy': 141,
#   'RetreatStrategy': 26,
#   'RetaliateStrategy': 9,
#   'ExploitStrategy': 824},
#  {'AttackStrategy': 137,
#   'RetreatStrategy': 25,
#   'RetaliateStrategy': 8,
#   'ExploitStrategy': 830},
#  {'AttackStrategy': 137,
#   'RetreatStrategy': 23,
#   'RetaliateStrategy': 8,
#   'ExploitStrategy': 832},
#  {'AttackStrategy': 137,
#   'RetreatStrategy': 21,
#   'RetaliateStrategy': 7,
#   'ExploitStrategy': 835},
#  {'AttackStrategy': 136,
#   'RetreatStrategy': 20,
#   'RetaliateStrategy': 7,
#   'ExploitStrategy': 837},
#  {'AttackStrategy': 138,
#   'RetreatStrategy': 17,
#   'RetaliateStrategy': 8,
#   'ExploitStrategy': 837},
#  {'AttackStrategy': 135,
#   'RetreatStrategy': 14,
#   'RetaliateStrategy': 8,
#   'ExploitStrategy': 843},
#  {'AttackStrategy': 129,
#   'RetreatStrategy': 12,
#   'RetaliateStrategy': 10,
#   'ExploitStrategy': 849},
#  {'AttackStrategy': 136,
#   'RetreatStrategy': 9,
#   'RetaliateStrategy': 8,
#   'ExploitStrategy': 847},
#  {'AttackStrategy': 135,
#   'RetreatStrategy': 7,
#   'RetaliateStrategy': 8,
#   'ExploitStrategy': 850},
#  {'AttackStrategy': 138,
#   'RetreatStrategy': 9,
#   'RetaliateStrategy': 8,
#   'ExploitStrategy': 845},
#  {'AttackStrategy': 145,
#   'RetreatStrategy': 6,
#   'RetaliateStrategy': 6,
#   'ExploitStrategy': 843},
#  {'AttackStrategy': 147,
#   'RetreatStrategy': 6,
#   'RetaliateStrategy': 6,
#   'ExploitStrategy': 841},
#  {'AttackStrategy': 145,
#   'RetreatStrategy': 7,
#   'RetaliateStrategy': 5,
#   'ExploitStrategy': 843},
#  {'AttackStrategy': 137,
#   'RetreatStrategy': 5,
#   'RetaliateStrategy': 5,
#   'ExploitStrategy': 853},
#  {'AttackStrategy': 141,
#   'RetreatStrategy': 5,
#   'RetaliateStrategy': 5,
#   'ExploitStrategy': 849},
#  {'AttackStrategy': 149,
#   'RetreatStrategy': 5,
#   'RetaliateStrategy': 3,
#   'ExploitStrategy': 843},
#  {'AttackStrategy': 147,
#   'RetreatStrategy': 5,
#   'RetaliateStrategy': 3,
#   'ExploitStrategy': 845},
#  {'AttackStrategy': 148,
#   'RetreatStrategy': 4,
#   'RetaliateStrategy': 3,
#   'ExploitStrategy': 845},
#  {'AttackStrategy': 154,
#   'RetreatStrategy': 3,
#   'RetaliateStrategy': 1,
#   'ExploitStrategy': 842},
#  {'AttackStrategy': 152,
#   'RetreatStrategy': 3,
#   'RetaliateStrategy': 1,
#   'ExploitStrategy': 844},
#  {'AttackStrategy': 153,
#   'RetreatStrategy': 3,
#   'RetaliateStrategy': 1,
#   'ExploitStrategy': 843},
#  {'AttackStrategy': 150,
#   'RetreatStrategy': 3,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 847},
#  {'AttackStrategy': 146,
#   'RetreatStrategy': 3,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 851},
#  {'AttackStrategy': 147,
#   'RetreatStrategy': 3,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 850},
#  {'AttackStrategy': 144,
#   'RetreatStrategy': 2,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 854},
#  {'AttackStrategy': 139,
#   'RetreatStrategy': 2,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 859},
#  {'AttackStrategy': 145,
#   'RetreatStrategy': 2,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 853},
#  {'AttackStrategy': 146,
#   'RetreatStrategy': 3,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 851},
#  {'AttackStrategy': 150,
#   'RetreatStrategy': 3,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 847},
#  {'AttackStrategy': 153,
#   'RetreatStrategy': 3,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 844},
#  {'AttackStrategy': 156,
#   'RetreatStrategy': 3,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 841},
#  {'AttackStrategy': 152,
#   'RetreatStrategy': 3,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 845},
#  {'AttackStrategy': 152,
#   'RetreatStrategy': 2,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 846},
#  {'AttackStrategy': 153,
#   'RetreatStrategy': 1,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 846},
#  {'AttackStrategy': 152,
#   'RetreatStrategy': 1,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 847},
#  {'AttackStrategy': 143,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 857},
#  {'AttackStrategy': 146,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 854},
#  {'AttackStrategy': 144,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 856},
#  {'AttackStrategy': 144,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 856},
#  {'AttackStrategy': 158,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 842},
#  {'AttackStrategy': 163,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 837},
#  {'AttackStrategy': 159,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 841},
#  {'AttackStrategy': 153,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 847},
#  {'AttackStrategy': 149,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 851},
#  {'AttackStrategy': 149,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 851},
#  {'AttackStrategy': 152,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 848},
#  {'AttackStrategy': 146,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 854},
#  {'AttackStrategy': 151,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 849},
#  {'AttackStrategy': 153,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 847},
#  {'AttackStrategy': 156,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 844},
#  {'AttackStrategy': 157,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 843},
#  {'AttackStrategy': 163,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 837},
#  {'AttackStrategy': 162,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 838},
#  {'AttackStrategy': 156,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 844},
#  {'AttackStrategy': 163,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 837},
#  {'AttackStrategy': 166,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 834},
#  {'AttackStrategy': 171,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 829},
#  {'AttackStrategy': 172,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 828},
#  {'AttackStrategy': 171,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 829},
#  {'AttackStrategy': 167,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 833},
#  {'AttackStrategy': 161,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 839},
#  {'AttackStrategy': 163,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 837},
#  {'AttackStrategy': 162,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 838},
#  {'AttackStrategy': 167,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 833},
#  {'AttackStrategy': 171,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 829},
#  {'AttackStrategy': 174,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 826},
#  {'AttackStrategy': 169,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 831},
#  {'AttackStrategy': 165,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 835},
#  {'AttackStrategy': 166,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 834},
#  {'AttackStrategy': 173,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 827},
#  {'AttackStrategy': 175,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 825},
#  {'AttackStrategy': 164,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 836},
#  {'AttackStrategy': 161,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 839},
#  {'AttackStrategy': 158,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 842},
#  {'AttackStrategy': 161,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 839},
#  {'AttackStrategy': 159,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 841},
#  {'AttackStrategy': 160,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 840},
#  {'AttackStrategy': 162,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 838},
#  {'AttackStrategy': 163,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 837},
#  {'AttackStrategy': 158,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 842},
#  {'AttackStrategy': 167,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 833},
#  {'AttackStrategy': 166,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 834},
#  {'AttackStrategy': 167,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 833},
#  {'AttackStrategy': 161,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 839},
#  {'AttackStrategy': 166,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 834},
#  {'AttackStrategy': 160,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 840},
#  {'AttackStrategy': 164,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 836},
#  {'AttackStrategy': 164,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 836},
#  {'AttackStrategy': 170,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 830},
#  {'AttackStrategy': 171,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 829},
#  {'AttackStrategy': 169,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 831},
#  {'AttackStrategy': 165,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 835},
#  {'AttackStrategy': 173,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 827},
#  {'AttackStrategy': 180,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 820},
#  {'AttackStrategy': 176,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 824},
#  {'AttackStrategy': 178,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 822},
#  {'AttackStrategy': 176,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 824},
#  {'AttackStrategy': 173,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 827},
#  {'AttackStrategy': 167,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 833},
#  {'AttackStrategy': 159,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 841},
#  {'AttackStrategy': 161,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 839},
#  {'AttackStrategy': 163,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 837},
#  {'AttackStrategy': 160,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 840},
#  {'AttackStrategy': 151,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 849},
#  {'AttackStrategy': 152,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 848},
#  {'AttackStrategy': 156,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 844},
#  {'AttackStrategy': 163,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 837},
#  {'AttackStrategy': 167,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 833},
#  {'AttackStrategy': 163,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 837},
#  {'AttackStrategy': 157,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 843},
#  {'AttackStrategy': 163,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 837},
#  {'AttackStrategy': 163,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 837},
#  {'AttackStrategy': 157,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 843},
#  {'AttackStrategy': 157,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 843},
#  {'AttackStrategy': 158,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 842},
#  {'AttackStrategy': 170,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 830},
#  {'AttackStrategy': 167,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 833},
#  {'AttackStrategy': 164,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 836},
#  {'AttackStrategy': 161,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 839},
#  {'AttackStrategy': 161,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 839},
#  {'AttackStrategy': 162,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 838},
#  {'AttackStrategy': 161,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 839},
#  {'AttackStrategy': 158,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 842},
#  {'AttackStrategy': 152,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 848},
#  {'AttackStrategy': 149,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 851},
#  {'AttackStrategy': 149,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 851},
#  {'AttackStrategy': 147,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 853},
#  {'AttackStrategy': 148,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 852},
#  {'AttackStrategy': 149,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 851},
#  {'AttackStrategy': 149,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 851},
#  {'AttackStrategy': 148,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 852},
#  {'AttackStrategy': 145,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 855},
#  {'AttackStrategy': 146,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 854},
#  {'AttackStrategy': 152,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 848},
#  {'AttackStrategy': 147,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 853},
#  {'AttackStrategy': 141,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 859},
#  {'AttackStrategy': 147,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 853},
#  {'AttackStrategy': 151,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 849},
#  {'AttackStrategy': 142,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 858},
#  {'AttackStrategy': 142,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 858},
#  {'AttackStrategy': 144,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 856},
#  {'AttackStrategy': 142,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 858},
#  {'AttackStrategy': 139,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 861},
#  {'AttackStrategy': 140,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 860},
#  {'AttackStrategy': 143,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 857},
#  {'AttackStrategy': 145,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 855},
#  {'AttackStrategy': 160,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 840},
#  {'AttackStrategy': 157,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 843},
#  {'AttackStrategy': 164,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 836},
#  {'AttackStrategy': 165,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 835},
#  {'AttackStrategy': 163,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 837},
#  {'AttackStrategy': 167,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 833},
#  {'AttackStrategy': 173,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 827},
#  {'AttackStrategy': 167,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 833},
#  {'AttackStrategy': 165,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 835},
#  {'AttackStrategy': 169,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 831},
#  {'AttackStrategy': 164,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 836},
#  {'AttackStrategy': 168,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 832},
#  {'AttackStrategy': 179,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 821},
#  {'AttackStrategy': 182,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 818},
#  {'AttackStrategy': 182,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 818},
#  {'AttackStrategy': 176,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 824},
#  {'AttackStrategy': 181,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 819},
#  {'AttackStrategy': 177,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 823},
#  {'AttackStrategy': 182,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 818},
#  {'AttackStrategy': 183,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 817},
#  {'AttackStrategy': 188,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 812},
#  {'AttackStrategy': 200,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 800},
#  {'AttackStrategy': 197,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 803},
#  {'AttackStrategy': 193,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 807},
#  {'AttackStrategy': 198,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 802},
#  {'AttackStrategy': 197,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 803},
#  {'AttackStrategy': 193,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 807},
#  {'AttackStrategy': 187,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 813},
#  {'AttackStrategy': 194,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 806},
#  {'AttackStrategy': 204,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 796},
#  {'AttackStrategy': 203,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 797},
#  {'AttackStrategy': 196,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 804},
#  {'AttackStrategy': 192,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 808},
#  {'AttackStrategy': 188,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 812},
#  {'AttackStrategy': 189,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 811},
#  {'AttackStrategy': 181,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 819},
#  {'AttackStrategy': 182,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 818},
#  {'AttackStrategy': 185,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 815},
#  {'AttackStrategy': 177,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 823},
#  {'AttackStrategy': 173,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 827},
#  {'AttackStrategy': 172,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 828},
#  {'AttackStrategy': 171,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 829},
#  {'AttackStrategy': 166,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 834},
#  {'AttackStrategy': 162,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 838},
#  {'AttackStrategy': 162,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 838},
#  {'AttackStrategy': 163,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 837},
#  {'AttackStrategy': 163,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 837},
#  {'AttackStrategy': 167,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 833},
#  {'AttackStrategy': 159,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 841},
#  {'AttackStrategy': 154,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 846},
#  {'AttackStrategy': 153,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 847},
#  {'AttackStrategy': 155,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 845},
#  {'AttackStrategy': 157,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 843},
#  {'AttackStrategy': 154,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 846},
#  {'AttackStrategy': 163,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 837},
#  {'AttackStrategy': 163,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 837},
#  {'AttackStrategy': 161,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 839},
#  {'AttackStrategy': 164,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 836},
#  {'AttackStrategy': 164,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 836},
#  {'AttackStrategy': 162,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 838},
#  {'AttackStrategy': 160,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 840},
#  {'AttackStrategy': 166,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 834},
#  {'AttackStrategy': 155,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 845},
#  {'AttackStrategy': 159,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 841},
#  {'AttackStrategy': 173,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 827},
#  {'AttackStrategy': 182,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 818},
#  {'AttackStrategy': 189,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 811},
#  {'AttackStrategy': 193,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 807},
#  {'AttackStrategy': 186,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 814},
#  {'AttackStrategy': 187,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 813},
#  {'AttackStrategy': 188,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 812},
#  {'AttackStrategy': 190,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 810},
#  {'AttackStrategy': 182,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 818},
#  {'AttackStrategy': 183,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 817},
#  {'AttackStrategy': 182,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 818},
#  {'AttackStrategy': 184,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 816},
#  {'AttackStrategy': 180,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 820},
#  {'AttackStrategy': 187,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 813},
#  {'AttackStrategy': 196,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 804},
#  {'AttackStrategy': 198,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 802},
#  {'AttackStrategy': 192,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 808},
#  {'AttackStrategy': 199,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 801},
#  {'AttackStrategy': 197,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 803},
#  {'AttackStrategy': 196,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 804},
#  {'AttackStrategy': 191,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 809},
#  {'AttackStrategy': 188,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 812},
#  {'AttackStrategy': 186,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 814},
#  {'AttackStrategy': 182,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 818},
#  {'AttackStrategy': 188,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 812},
#  {'AttackStrategy': 200,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 800},
#  {'AttackStrategy': 201,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 799},
#  {'AttackStrategy': 198,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 802},
#  {'AttackStrategy': 200,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 800},
#  {'AttackStrategy': 202,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 798},
#  {'AttackStrategy': 197,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 803},
#  {'AttackStrategy': 194,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 806},
#  {'AttackStrategy': 191,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 809},
#  {'AttackStrategy': 190,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 810},
#  {'AttackStrategy': 189,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 811},
#  {'AttackStrategy': 184,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 816},
#  {'AttackStrategy': 181,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 819},
#  {'AttackStrategy': 185,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 815},
#  {'AttackStrategy': 178,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 822},
#  {'AttackStrategy': 180,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 820},
#  {'AttackStrategy': 184,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 816},
#  {'AttackStrategy': 182,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 818},
#  {'AttackStrategy': 178,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 822},
#  {'AttackStrategy': 173,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 827},
#  {'AttackStrategy': 173,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 827},
#  {'AttackStrategy': 168,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 832},
#  {'AttackStrategy': 169,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 831},
#  {'AttackStrategy': 168,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 832},
#  {'AttackStrategy': 162,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 838},
#  {'AttackStrategy': 170,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 830},
#  {'AttackStrategy': 170,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 830},
#  {'AttackStrategy': 166,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 834},
#  {'AttackStrategy': 158,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 842},
#  {'AttackStrategy': 161,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 839},
#  {'AttackStrategy': 157,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 843},
#  {'AttackStrategy': 151,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 849},
#  {'AttackStrategy': 152,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 848},
#  {'AttackStrategy': 147,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 853},
#  {'AttackStrategy': 152,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 848},
#  {'AttackStrategy': 157,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 843},
#  {'AttackStrategy': 162,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 838},
#  {'AttackStrategy': 159,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 841},
#  {'AttackStrategy': 157,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 843},
#  {'AttackStrategy': 151,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 849},
#  {'AttackStrategy': 158,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 842},
#  {'AttackStrategy': 147,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 853},
#  {'AttackStrategy': 144,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 856},
#  {'AttackStrategy': 145,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 855},
#  {'AttackStrategy': 143,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 857},
#  {'AttackStrategy': 142,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 858},
#  {'AttackStrategy': 145,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 855},
#  {'AttackStrategy': 143,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 857},
#  {'AttackStrategy': 147,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 853},
#  {'AttackStrategy': 149,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 851},
#  {'AttackStrategy': 147,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 853},
#  {'AttackStrategy': 144,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 856},
#  {'AttackStrategy': 149,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 851},
#  {'AttackStrategy': 146,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 854},
#  {'AttackStrategy': 145,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 855},
#  {'AttackStrategy': 145,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 855},
#  {'AttackStrategy': 141,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 859},
#  {'AttackStrategy': 147,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 853},
#  {'AttackStrategy': 155,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 845},
#  {'AttackStrategy': 151,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 849},
#  {'AttackStrategy': 148,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 852},
#  {'AttackStrategy': 144,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 856},
#  {'AttackStrategy': 140,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 860},
#  {'AttackStrategy': 140,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 860},
#  {'AttackStrategy': 143,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 857},
#  {'AttackStrategy': 139,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 861},
#  {'AttackStrategy': 147,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 853},
#  {'AttackStrategy': 143,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 857},
#  {'AttackStrategy': 142,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 858},
#  {'AttackStrategy': 148,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 852},
#  {'AttackStrategy': 148,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 852},
#  {'AttackStrategy': 152,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 848},
#  {'AttackStrategy': 150,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 850},
#  {'AttackStrategy': 150,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 850},
#  {'AttackStrategy': 145,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 855},
#  {'AttackStrategy': 146,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 854},
#  {'AttackStrategy': 147,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 853},
#  {'AttackStrategy': 152,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 848},
#  {'AttackStrategy': 151,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 849},
#  {'AttackStrategy': 156,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 844},
#  {'AttackStrategy': 155,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 845},
#  {'AttackStrategy': 156,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 844},
#  {'AttackStrategy': 164,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 836},
#  {'AttackStrategy': 167,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 833},
#  {'AttackStrategy': 176,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 824},
#  {'AttackStrategy': 174,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 826},
#  {'AttackStrategy': 174,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 826},
#  {'AttackStrategy': 179,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 821},
#  {'AttackStrategy': 175,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 825},
#  {'AttackStrategy': 178,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 822},
#  {'AttackStrategy': 170,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 830},
#  {'AttackStrategy': 169,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 831},
#  {'AttackStrategy': 170,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 830},
#  {'AttackStrategy': 168,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 832},
#  {'AttackStrategy': 166,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 834},
#  {'AttackStrategy': 166,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 834},
#  {'AttackStrategy': 163,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 837},
#  {'AttackStrategy': 163,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 837},
#  {'AttackStrategy': 160,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 840},
#  {'AttackStrategy': 153,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 847},
#  {'AttackStrategy': 160,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 840},
#  {'AttackStrategy': 160,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 840},
#  {'AttackStrategy': 158,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 842},
#  {'AttackStrategy': 156,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 844},
#  {'AttackStrategy': 151,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 849},
#  {'AttackStrategy': 155,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 845},
#  {'AttackStrategy': 160,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 840},
#  {'AttackStrategy': 157,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 843},
#  {'AttackStrategy': 156,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 844},
#  {'AttackStrategy': 159,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 841},
#  {'AttackStrategy': 161,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 839},
#  {'AttackStrategy': 163,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 837},
#  {'AttackStrategy': 161,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 839},
#  {'AttackStrategy': 155,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 845},
#  {'AttackStrategy': 156,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 844},
#  {'AttackStrategy': 153,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 847},
#  {'AttackStrategy': 152,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 848},
#  {'AttackStrategy': 144,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 856},
#  {'AttackStrategy': 149,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 851},
#  {'AttackStrategy': 139,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 861},
#  {'AttackStrategy': 135,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 865},
#  {'AttackStrategy': 134,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 866},
#  {'AttackStrategy': 128,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 872},
#  {'AttackStrategy': 127,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 873},
#  {'AttackStrategy': 130,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 870},
#  {'AttackStrategy': 127,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 873},
#  {'AttackStrategy': 128,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 872},
#  {'AttackStrategy': 129,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 871},
#  {'AttackStrategy': 129,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 871},
#  {'AttackStrategy': 136,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 864},
#  {'AttackStrategy': 141,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 859},
#  {'AttackStrategy': 143,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 857},
#  {'AttackStrategy': 140,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 860},
#  {'AttackStrategy': 144,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 856},
#  {'AttackStrategy': 136,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 864},
#  {'AttackStrategy': 140,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 860},
#  {'AttackStrategy': 142,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 858},
#  {'AttackStrategy': 141,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 859},
#  {'AttackStrategy': 143,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 857},
#  {'AttackStrategy': 144,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 856},
#  {'AttackStrategy': 149,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 851},
#  {'AttackStrategy': 144,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 856},
#  {'AttackStrategy': 149,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 851},
#  {'AttackStrategy': 155,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 845},
#  {'AttackStrategy': 154,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 846},
#  {'AttackStrategy': 152,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 848},
#  {'AttackStrategy': 152,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 848},
#  {'AttackStrategy': 145,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 855},
#  {'AttackStrategy': 142,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 858},
#  {'AttackStrategy': 138,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 862},
#  {'AttackStrategy': 143,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 857},
#  {'AttackStrategy': 147,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 853},
#  {'AttackStrategy': 155,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 845},
#  {'AttackStrategy': 157,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 843},
#  {'AttackStrategy': 155,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 845},
#  {'AttackStrategy': 160,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 840},
#  {'AttackStrategy': 161,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 839},
#  {'AttackStrategy': 162,
#   'RetreatStrategy': 0,
# ...
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 846},
#  {'AttackStrategy': 151,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 849},
#  {'AttackStrategy': 149,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 851},
#  {'AttackStrategy': 144,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 856},
#  {'AttackStrategy': 146,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 854},
#  {'AttackStrategy': 144,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 856},
#  {'AttackStrategy': 156,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 844},
#  {'AttackStrategy': 157,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 843},
#  {'AttackStrategy': 152,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 848},
#  {'AttackStrategy': 149,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 851},
#  {'AttackStrategy': 151,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 849},
#  {'AttackStrategy': 158,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 842},
#  {'AttackStrategy': 160,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 840},
#  {'AttackStrategy': 162,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 838},
#  {'AttackStrategy': 154,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 846},
#  {'AttackStrategy': 155,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 845},
#  {'AttackStrategy': 163,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 837},
#  {'AttackStrategy': 171,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 829},
#  {'AttackStrategy': 176,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 824},
#  {'AttackStrategy': 168,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 832},
#  {'AttackStrategy': 163,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 837},
#  {'AttackStrategy': 172,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 828},
#  {'AttackStrategy': 178,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 822},
#  {'AttackStrategy': 168,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 832},
#  {'AttackStrategy': 168,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 832},
#  {'AttackStrategy': 172,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 828},
#  {'AttackStrategy': 182,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 818},
#  {'AttackStrategy': 178,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 822},
#  {'AttackStrategy': 180,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 820},
#  {'AttackStrategy': 175,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 825},
#  {'AttackStrategy': 163,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 837},
#  {'AttackStrategy': 169,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 831},
#  {'AttackStrategy': 171,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 829},
#  {'AttackStrategy': 173,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 827},
#  {'AttackStrategy': 173,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 827},
#  {'AttackStrategy': 171,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 829},
#  {'AttackStrategy': 173,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 827},
#  {'AttackStrategy': 170,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 830},
#  {'AttackStrategy': 173,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 827},
#  {'AttackStrategy': 171,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 829},
#  {'AttackStrategy': 168,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 832},
#  {'AttackStrategy': 164,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 836},
#  {'AttackStrategy': 162,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 838},
#  {'AttackStrategy': 166,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 834},
#  {'AttackStrategy': 172,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 828},
#  {'AttackStrategy': 174,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 826},
#  {'AttackStrategy': 176,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 824},
#  {'AttackStrategy': 173,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 827},
#  {'AttackStrategy': 172,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 828},
#  {'AttackStrategy': 167,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 833},
#  {'AttackStrategy': 175,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 825},
#  {'AttackStrategy': 179,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 821},
#  {'AttackStrategy': 174,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 826},
#  {'AttackStrategy': 178,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 822},
#  {'AttackStrategy': 176,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 824},
#  {'AttackStrategy': 174,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 826},
#  {'AttackStrategy': 167,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 833},
#  {'AttackStrategy': 172,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 828},
#  {'AttackStrategy': 169,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 831},
#  {'AttackStrategy': 169,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 831},
#  {'AttackStrategy': 175,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 825},
#  {'AttackStrategy': 172,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 828},
#  {'AttackStrategy': 176,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 824},
#  {'AttackStrategy': 176,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 824},
#  {'AttackStrategy': 181,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 819},
#  {'AttackStrategy': 183,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 817},
#  {'AttackStrategy': 186,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 814},
#  {'AttackStrategy': 185,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 815},
#  {'AttackStrategy': 179,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 821},
#  {'AttackStrategy': 170,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 830},
#  {'AttackStrategy': 168,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 832},
#  {'AttackStrategy': 157,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 843},
#  {'AttackStrategy': 159,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 841},
#  {'AttackStrategy': 158,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 842},
#  {'AttackStrategy': 160,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 840},
#  {'AttackStrategy': 167,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 833},
#  {'AttackStrategy': 161,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 839},
#  {'AttackStrategy': 159,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 841},
#  {'AttackStrategy': 158,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 842},
#  {'AttackStrategy': 163,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 837},
#  {'AttackStrategy': 163,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 837},
#  {'AttackStrategy': 157,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 843},
#  {'AttackStrategy': 156,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 844},
#  {'AttackStrategy': 154,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 846},
#  {'AttackStrategy': 155,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 845},
#  {'AttackStrategy': 159,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 841},
#  {'AttackStrategy': 154,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 846},
#  {'AttackStrategy': 159,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 841},
#  {'AttackStrategy': 164,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 836},
#  {'AttackStrategy': 156,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 844},
#  {'AttackStrategy': 153,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 847},
#  {'AttackStrategy': 158,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 842},
#  {'AttackStrategy': 163,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 837},
#  {'AttackStrategy': 153,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 847},
#  {'AttackStrategy': 158,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 842},
#  {'AttackStrategy': 163,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 837},
#  {'AttackStrategy': 176,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 824},
#  {'AttackStrategy': 176,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 824},
#  {'AttackStrategy': 181,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 819},
#  {'AttackStrategy': 180,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 820},
#  {'AttackStrategy': 179,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 821},
#  {'AttackStrategy': 175,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 825},
#  {'AttackStrategy': 179,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 821},
#  {'AttackStrategy': 180,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 820},
#  {'AttackStrategy': 181,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 819},
#  {'AttackStrategy': 181,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 819},
#  {'AttackStrategy': 180,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 820},
#  {'AttackStrategy': 177,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 823},
#  {'AttackStrategy': 177,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 823},
#  {'AttackStrategy': 185,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 815},
#  {'AttackStrategy': 180,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 820},
#  {'AttackStrategy': 180,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 820},
#  {'AttackStrategy': 178,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 822},
#  {'AttackStrategy': 176,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 824},
#  {'AttackStrategy': 174,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 826},
#  {'AttackStrategy': 178,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 822},
#  {'AttackStrategy': 171,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 829},
#  {'AttackStrategy': 179,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 821},
#  {'AttackStrategy': 176,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 824},
#  {'AttackStrategy': 171,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 829},
#  {'AttackStrategy': 171,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 829},
#  {'AttackStrategy': 176,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 824},
#  {'AttackStrategy': 174,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 826},
#  {'AttackStrategy': 173,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 827},
#  {'AttackStrategy': 164,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 836},
#  {'AttackStrategy': 169,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 831},
#  {'AttackStrategy': 175,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 825},
#  {'AttackStrategy': 173,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 827},
#  {'AttackStrategy': 174,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 826},
#  {'AttackStrategy': 178,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 822},
#  {'AttackStrategy': 175,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 825},
#  {'AttackStrategy': 172,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 828},
#  {'AttackStrategy': 178,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 822},
#  {'AttackStrategy': 186,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 814},
#  {'AttackStrategy': 192,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 808},
#  {'AttackStrategy': 190,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 810},
#  {'AttackStrategy': 192,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 808},
#  {'AttackStrategy': 195,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 805},
#  {'AttackStrategy': 201,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 799},
#  {'AttackStrategy': 191,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 809},
#  {'AttackStrategy': 191,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 809},
#  {'AttackStrategy': 191,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 809},
#  {'AttackStrategy': 188,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 812},
#  {'AttackStrategy': 192,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 808},
#  {'AttackStrategy': 185,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 815},
#  {'AttackStrategy': 189,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 811},
#  {'AttackStrategy': 196,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 804},
#  {'AttackStrategy': 189,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 811},
#  {'AttackStrategy': 190,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 810},
#  {'AttackStrategy': 192,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 808},
#  {'AttackStrategy': 194,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 806},
#  {'AttackStrategy': 192,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 808},
#  {'AttackStrategy': 184,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 816},
#  {'AttackStrategy': 178,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 822},
#  {'AttackStrategy': 170,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 830},
#  {'AttackStrategy': 167,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 833},
#  {'AttackStrategy': 170,
#   'RetreatStrategy': 0,
#   'RetaliateStrategy': 0,
#   'ExploitStrategy': 830}]

# %%
# %matplotlib inline
import matplotlib.pyplot as plt


def plot_strategy_counts(data):
    """Plot strategy counts for each iteration."""

    # Extract strategy names
    strategy_names = list(data[0].keys())

    # Create a color map for each strategy
    colors = ["blue", "orange", "green", "red"]
    color_map = dict(zip(strategy_names, colors))

    # Create lists to store data for each strategy
    strategy_counts = {}
    for strategy in strategy_names:
        strategy_counts[strategy] = []

    # Extract counts for each strategy for each iteration
    for iteration in data:
        for strategy in strategy_names:
            strategy_counts[strategy].append(iteration[strategy])

    # Create plot
    plt.figure(figsize=(10, 6))
    for strategy in strategy_names:
        plt.plot(
            range(len(data)),
            strategy_counts[strategy],
            label=strategy,
            color=color_map[strategy],
        )
    plt.xlabel("Iterations")
    plt.ylabel("Strategy Count")
    plt.legend()
    plt.show()

# %%
plot_strategy_counts(env.state.population_by_strategy)

# %%
plot_strategy_counts(env.state.hp_by_strategy)

# %%
plot_strategy_counts(env.state.xp_by_strategy)

# %%
len(env.state.agents_fallen[0])
# Out:
# 119

# %%
from collections import Counter

# %%
for i in range(env.num_rounds):
    print(
        "agents_fallen: "
        + str(Counter([a.strategy.__name__ for a in env.state.agents_fallen[i]]))
    )
    print(
        "agents_respawned: "
        + str(Counter([a.strategy.__name__ for a in env.state.agents_respawned[i]]))
    )
